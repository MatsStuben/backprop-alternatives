# %% [markdown]
# # California Housing Hyperparameter Search in Colab
#
# This notebook is self-contained and includes:
# - `MLP`
# - `backprop_step`
# - `node_perturbation_step`
# - `node_perturbation_step_fan_in_scaled`
# - `node_perturbation_step_fixed_sigma`
# - `weight_perturb_step`
# - California Housing loading and standardization
# - a modest default hyperparameter sweep seeded from the current local script
# - a deeper follow-up run on the best config per method
# - an optional single-config runner at the end
# - a frozen-backprop repeated-perturbation estimator analysis section
#
# It is set up for Google Colab and uses GPU automatically when available.
#
# Notes:
# - The notebook mirrors the current local California Housing setup: sigmoid hidden units, standardized inputs/targets, and MSE loss.
# - The default search space is centered on the current `test_house_cali.py` values.
# - `num_workers=0` is used by default to avoid Colab/Jupyter multiprocessing cleanup issues.
# - In Colab, enable GPU via `Runtime -> Change runtime type -> GPU`.

# %%
import itertools
import math
import random
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from IPython.display import display
from torch.utils.data import DataLoader, TensorDataset, Subset

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if hasattr(torch, "set_float32_matmul_precision"):
    torch.set_float32_matmul_precision("high")


def set_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


set_seed(0)
print(f"device={device}")
if device.type == "cuda":
    print(torch.cuda.get_device_name(0))

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Out:
# device=cuda
# NVIDIA RTX PRO 6000 Blackwell Server Edition

# %%
METHODS = ["bp", "np", "np_fan_in", "np_fixed", "wp"]
METHOD_LABELS = {
    "bp": "Backprop",
    "np": "Node Perturbation",
    "np_fan_in": "Node Perturbation Fan-In",
    "np_fixed": "Node Perturbation Fixed Sigma",
    "wp": "Weight Perturbation",
}
METHOD_COLORS = {
    "bp": "C0",
    "np": "C1",
    "np_fan_in": "C4",
    "np_fixed": "C3",
    "wp": "C2",
}


class MLP(nn.Module):
    def __init__(self, dimensions, activation=torch.sigmoid, output_activation=None, require_grad=False):
        super().__init__()
        self.layers = nn.ModuleList(
            [nn.Linear(dimensions[i], dimensions[i + 1], bias=True) for i in range(len(dimensions) - 1)]
        )
        self.activation = activation
        self.output_activation = output_activation
        if not require_grad:
            for p in self.parameters():
                p.requires_grad_(False)

    def forward(self, x):
        final_layer = len(self.layers) - 1
        h = x
        for i, layer in enumerate(self.layers):
            u = layer(h)
            if i == final_layer:
                h = self.output_activation(u) if self.output_activation else u
            else:
                h = self.activation(u)
        return h

    def forward_weight_perturb(self, x, sigma):
        batch_size = x.shape[0]
        xs = [x]
        ys = []
        noises = []
        h = x
        for i, layer in enumerate(self.layers):
            w = layer.weight
            b = layer.bias
            eps_w = torch.randn(batch_size, *w.shape, device=w.device, dtype=w.dtype) * sigma
            eps_b = torch.randn(batch_size, *b.shape, device=b.device, dtype=b.dtype) * sigma
            w_used = w.unsqueeze(0) + eps_w
            b_used = b.unsqueeze(0) + eps_b
            u = torch.bmm(h.unsqueeze(1), w_used.transpose(1, 2)).squeeze(1) + b_used
            final_layer = len(self.layers) - 1
            if i == final_layer:
                h = self.output_activation(u) if self.output_activation else u
                ys.append(h)
            else:
                h = self.activation(u)
                ys.append(h)
                xs.append(h)
            noises.append((eps_w, eps_b))
        return ys, xs, noises

    def forward_node_perturb(self, x, sigma):
        acts = [x]
        noises = []
        noise_scales = []
        last = len(self.layers) - 1
        a_noisy = x
        for i, layer in enumerate(self.layers):
            x_in = a_noisy
            z_noisy = layer(a_noisy)
            eps = torch.randn_like(z_noisy)
            noise_scale = sigma * torch.sqrt(1.0 + x_in.pow(2).sum(dim=1, keepdim=True))
            noises.append(eps)
            noise_scales.append(noise_scale)
            z_noisy = z_noisy + noise_scale * eps
            if i == last:
                a_noisy = self.output_activation(z_noisy) if self.output_activation else z_noisy
            else:
                a_noisy = self.activation(z_noisy)
            acts.append(a_noisy)
        return acts, noises, noise_scales, a_noisy

    def forward_node_perturb_fan_in_scaled(self, x, sigma):
        acts = [x]
        noises = []
        noise_scales = []
        last = len(self.layers) - 1
        a_noisy = x
        for i, layer in enumerate(self.layers):
            z_noisy = layer(a_noisy)
            eps = torch.randn_like(z_noisy)
            fan_in_with_bias = layer.in_features + 1
            noise_scale_value = sigma * math.sqrt(fan_in_with_bias)
            noise_scale = torch.full_like(z_noisy, noise_scale_value)
            noises.append(eps)
            noise_scales.append(noise_scale)
            z_noisy = z_noisy + noise_scale * eps
            if i == last:
                a_noisy = self.output_activation(z_noisy) if self.output_activation else z_noisy
            else:
                a_noisy = self.activation(z_noisy)
            acts.append(a_noisy)
        return acts, noises, noise_scales, a_noisy

    def forward_node_perturb_fixed_sigma(self, x, sigma):
        acts = [x]
        noises = []
        noise_scales = []
        last = len(self.layers) - 1
        a_noisy = x
        for i, layer in enumerate(self.layers):
            z_noisy = layer(a_noisy)
            eps = torch.randn_like(z_noisy)
            noise_scale = torch.full_like(z_noisy, sigma)
            noises.append(eps)
            noise_scales.append(noise_scale)
            z_noisy = z_noisy + noise_scale * eps
            if i == last:
                a_noisy = self.output_activation(z_noisy) if self.output_activation else z_noisy
            else:
                a_noisy = self.activation(z_noisy)
            acts.append(a_noisy)
        return acts, noises, noise_scales, a_noisy


def _mean_loss_per_sample(prediction, target):
    loss = F.mse_loss(prediction, target, reduction="none")
    if loss.dim() > 1:
        loss = loss.mean(dim=1)
    return loss.view(-1)


def _centered_reward_signal(loss_per_sample):
    reward = -loss_per_sample
    return reward - reward.mean()


def _flatten_parameter_tensors(weight_tensors, bias_tensors):
    pieces = []
    for weight_tensor, bias_tensor in zip(weight_tensors, bias_tensors):
        pieces.append(weight_tensor.reshape(-1))
        pieces.append(bias_tensor.reshape(-1))
    return torch.cat(pieces)


def node_perturbation_step(model, X, target, eta=0.5, sigma=0.1, return_unscaled_parameter_update_vector=False):
    model.train()
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb(X, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, target)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    with torch.no_grad():
        for layer, x_in, noise, noise_scale in zip(model.layers, activations, noises, noise_scales):
            scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
            raw_weight_update = torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0)
            raw_bias_update = scaled_noise.mean(dim=0)
            raw_weight_updates.append(raw_weight_update)
            raw_bias_updates.append(raw_bias_update)
            layer.weight += eta * raw_weight_update
            layer.bias += eta * raw_bias_update
    mean_loss = loss_per_sample.mean().item()
    if return_unscaled_parameter_update_vector:
        return mean_loss, _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)
    return mean_loss


def node_perturbation_step_fixed_sigma(model, X, target, eta=0.5, sigma=0.1, return_unscaled_parameter_update_vector=False):
    model.train()
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb_fixed_sigma(X, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, target)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    with torch.no_grad():
        for layer, x_in, noise, noise_scale in zip(model.layers, activations, noises, noise_scales):
            scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
            raw_weight_update = torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0)
            raw_bias_update = scaled_noise.mean(dim=0)
            raw_weight_updates.append(raw_weight_update)
            raw_bias_updates.append(raw_bias_update)
            layer.weight += eta * raw_weight_update
            layer.bias += eta * raw_bias_update
    mean_loss = loss_per_sample.mean().item()
    if return_unscaled_parameter_update_vector:
        return mean_loss, _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)
    return mean_loss


def node_perturbation_step_fan_in_scaled(model, X, target, eta=0.5, sigma=0.1, return_unscaled_parameter_update_vector=False):
    model.train()
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb_fan_in_scaled(X, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, target)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    with torch.no_grad():
        for layer, x_in, noise, noise_scale in zip(model.layers, activations, noises, noise_scales):
            scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
            raw_weight_update = torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0)
            raw_bias_update = scaled_noise.mean(dim=0)
            raw_weight_updates.append(raw_weight_update)
            raw_bias_updates.append(raw_bias_update)
            layer.weight += eta * raw_weight_update
            layer.bias += eta * raw_bias_update
    mean_loss = loss_per_sample.mean().item()
    if return_unscaled_parameter_update_vector:
        return mean_loss, _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)
    return mean_loss


def weight_perturb_step(model, X, target, eta=0.5, sigma=0.1, return_unscaled_parameter_update_vector=False):
    model.train()
    layer_outputs, _, noises = model.forward_weight_perturb(X, sigma)
    prediction_noisy = layer_outputs[-1]
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, target)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    noise_scale = sigma ** 2 + 1e-12
    raw_weight_updates = []
    raw_bias_updates = []
    with torch.no_grad():
        for layer, (weight_noise, bias_noise) in zip(model.layers, noises):
            scaled_weight_noise = scalar_signal.view(-1, 1, 1) * weight_noise / noise_scale
            scaled_bias_noise = scalar_signal.view(-1, 1) * bias_noise / noise_scale
            raw_weight_update = scaled_weight_noise.mean(dim=0)
            raw_bias_update = scaled_bias_noise.mean(dim=0)
            raw_weight_updates.append(raw_weight_update)
            raw_bias_updates.append(raw_bias_update)
            layer.weight += eta * raw_weight_update
            layer.bias += eta * raw_bias_update
    mean_loss = loss_per_sample.mean().item()
    if return_unscaled_parameter_update_vector:
        return mean_loss, _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)
    return mean_loss


def backprop_step(model, X, target, optimizer, loss_fn=F.mse_loss, return_unscaled_parameter_update_vector=False):
    model.train()
    for p in model.parameters():
        p.requires_grad_(True)
    optimizer.zero_grad()
    y_pred = model(X)
    loss = loss_fn(y_pred, target, reduction="mean")
    loss.backward()
    weight_grads = [layer.weight.grad.detach().clone() for layer in model.layers]
    bias_grads = [layer.bias.grad.detach().clone() for layer in model.layers]
    optimizer.step()
    if return_unscaled_parameter_update_vector:
        return loss.item(), -_flatten_parameter_tensors(weight_grads, bias_grads)
    return loss.item()


def model_weight_norm(model):
    total = torch.tensor(0.0, device=next(model.parameters()).device)
    for layer in model.layers:
        total = total + layer.weight.detach().pow(2).sum()
    return float(torch.sqrt(total))


def mean_normalized_layer_output_norms(model, loader, device):
    model.eval()
    summed_norms = [0.0 for _ in model.layers]
    total_examples = 0

    with torch.no_grad():
        for batch in loader:
            if len(batch) == 3:
                xb, _, _ = batch
            else:
                xb, _ = batch
            xb = xb.to(device, non_blocking=True)
            h = xb
            batch_size = xb.size(0)

            for layer_idx, layer in enumerate(model.layers):
                h_for_norm = h if h.dim() > 1 else h.unsqueeze(1)
                normalized_norm = torch.norm(h_for_norm, dim=1) / math.sqrt(h_for_norm.shape[1] + 1)
                summed_norms[layer_idx] += normalized_norm.sum().item()
                u = layer(h)
                if layer_idx == len(model.layers) - 1:
                    h = model.output_activation(u) if model.output_activation else u
                else:
                    h = model.activation(u)

            total_examples += batch_size

    return [value / max(total_examples, 1) for value in summed_norms]


def _random_subset_indices(n, limit, seed):
    if limit is None or limit >= n:
        return torch.arange(n)
    g = torch.Generator().manual_seed(seed)
    return torch.randperm(n, generator=g)[:limit]


def _maybe_subset_dataset(dataset, limit, seed):
    if limit is None or limit >= len(dataset):
        return dataset
    indices = _random_subset_indices(len(dataset), limit, seed)
    return Subset(dataset, indices.tolist())


def regression_r2_score(y_true, y_pred):
    ss_res = torch.sum((y_true - y_pred) ** 2)
    target_mean = torch.mean(y_true, dim=0, keepdim=True)
    ss_tot = torch.sum((y_true - target_mean) ** 2)
    if float(ss_tot) < 1e-12:
        return 0.0
    return float(1.0 - ss_res / (ss_tot + 1e-12))


def evaluate_model(model, loader, device):
    model.eval()
    total_loss = 0.0
    total_examples = 0
    predictions = []
    targets = []
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)
            pred = model(xb)
            loss = F.mse_loss(pred, yb, reduction="mean")
            total_loss += loss.item() * xb.size(0)
            total_examples += xb.size(0)
            predictions.append(pred.detach().cpu())
            targets.append(yb.detach().cpu())
    mean_loss = total_loss / max(total_examples, 1)
    y_pred = torch.cat(predictions, dim=0)
    y_true = torch.cat(targets, dim=0)
    r2 = regression_r2_score(y_true, y_pred)
    return mean_loss, r2


def predict_tensor(model, x, device):
    model.eval()
    with torch.no_grad():
        return model(x.to(device)).detach().cpu()


def make_model(dimensions, require_grad, device):
    return MLP(dimensions, activation=torch.sigmoid, require_grad=require_grad).to(device)


def train_one_run(
    method,
    run_config,
    data,
    dimensions,
    epochs,
    seed,
    device,
    print_every_epoch=1,
    divergence_loss_threshold=5.0,
):
    set_seed(seed)

    base_model = make_model(dimensions, require_grad=True, device=device)
    base_state = {name: tensor.detach().clone() for name, tensor in base_model.state_dict().items()}

    require_grad = method == "bp"
    model = make_model(dimensions, require_grad=require_grad, device=device)
    model.load_state_dict(base_state)

    optimizer = None
    if method == "bp":
        optimizer = torch.optim.SGD(model.parameters(), lr=run_config["lr"])

    history = {
        "epoch": [],
        "train_loss": [],
        "train_r2": [],
        "test_loss": [],
        "test_r2": [],
        "weight_norm": [],
        "layer_output_norms": [],
    }

    diverged = False
    best_test_loss = float("inf")
    best_test_r2 = -float("inf")
    start_time = time.time()

    train_loader = data["train_loader"]
    train_eval_loader = data["train_eval_loader"]
    test_loader = data["test_loader"]

    for epoch in range(1, epochs + 1):
        model.train()
        for xb, yb in train_loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)

            if method == "bp":
                backprop_step(model, xb, yb, optimizer=optimizer)
            elif method == "np":
                node_perturbation_step(model, xb, yb, eta=run_config["lr"], sigma=run_config["sigma"])
            elif method == "np_fan_in":
                node_perturbation_step_fan_in_scaled(model, xb, yb, eta=run_config["lr"], sigma=run_config["sigma"])
            elif method == "np_fixed":
                node_perturbation_step_fixed_sigma(model, xb, yb, eta=run_config["lr"], sigma=run_config["sigma"])
            elif method == "wp":
                weight_perturb_step(model, xb, yb, eta=run_config["lr"], sigma=run_config["sigma"])
            else:
                raise ValueError(f"Unknown method: {method}")

        train_loss, train_r2 = evaluate_model(model, train_eval_loader, device)
        test_loss, test_r2 = evaluate_model(model, test_loader, device)

        history["epoch"].append(epoch)
        history["train_loss"].append(train_loss)
        history["train_r2"].append(train_r2)
        history["test_loss"].append(test_loss)
        history["test_r2"].append(test_r2)
        history["weight_norm"].append(model_weight_norm(model))
        history["layer_output_norms"].append(mean_normalized_layer_output_norms(model, train_eval_loader, device))

        best_test_loss = min(best_test_loss, test_loss)
        best_test_r2 = max(best_test_r2, test_r2)

        if (not math.isfinite(train_loss)) or (not math.isfinite(test_loss)) or test_loss > divergence_loss_threshold:
            diverged = True
            print(
                f"    diverged at epoch {epoch}/{epochs} | "
                f"train_loss={train_loss:.4f}, test_loss={test_loss:.4f}, test_r2={test_r2:.4f}"
            )
            break

        if epoch % print_every_epoch == 0 or epoch == 1 or epoch == epochs:
            sigma_str = f", sigma={run_config['sigma']:.4g}" if "sigma" in run_config else ""
            print(
                f"    epoch {epoch:2d}/{epochs} | {method} | lr={run_config['lr']:.4g}{sigma_str} | "
                f"train_loss={train_loss:.4f}, train_r2={train_r2:.4f}, "
                f"test_loss={test_loss:.4f}, test_r2={test_r2:.4f}"
            )

    duration_sec = time.time() - start_time
    state_dict_cpu = {name: tensor.detach().cpu().clone() for name, tensor in model.state_dict().items()}
    result = {
        "method": method,
        "lr": float(run_config["lr"]),
        "sigma": float(run_config["sigma"]) if "sigma" in run_config else np.nan,
        "epochs_completed": len(history["epoch"]),
        "final_train_loss": history["train_loss"][-1] if history["train_loss"] else np.nan,
        "final_train_r2": history["train_r2"][-1] if history["train_r2"] else np.nan,
        "final_test_loss": history["test_loss"][-1] if history["test_loss"] else np.nan,
        "final_test_r2": history["test_r2"][-1] if history["test_r2"] else np.nan,
        "best_test_loss": best_test_loss,
        "best_test_r2": best_test_r2,
        "diverged": diverged,
        "duration_sec": duration_sec,
        "history": history,
        "state_dict": state_dict_cpu,
    }
    del model
    if device.type == "cuda":
        torch.cuda.empty_cache()
    return result


def true_gradient_vector(model, xb, yb):
    requires_grad_state = [parameter.requires_grad for parameter in model.parameters()]
    for parameter in model.parameters():
        parameter.requires_grad_(True)
    model.zero_grad(set_to_none=True)
    prediction = model(xb)
    loss = F.mse_loss(prediction, yb, reduction="mean")
    loss.backward()
    weight_grads = [layer.weight.grad.detach().clone() for layer in model.layers]
    bias_grads = [layer.bias.grad.detach().clone() for layer in model.layers]
    flat_grad = _flatten_parameter_tensors(weight_grads, bias_grads)
    model.zero_grad(set_to_none=True)
    for parameter, old_value in zip(model.parameters(), requires_grad_state):
        parameter.requires_grad_(old_value)
    return -flat_grad


def cosine_similarity_safe(a, b, eps=1e-12):
    a_norm = torch.norm(a)
    b_norm = torch.norm(b)
    if a_norm.item() < eps or b_norm.item() < eps:
        return 0.0
    return float(torch.dot(a, b) / (a_norm * b_norm + eps))


def node_perturbation_gradient_estimate_vector(model, xb, yb, sigma):
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb(xb, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, yb)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    for x_in, noise, noise_scale in zip(activations, noises, noise_scales):
        scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
        raw_weight_updates.append(torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0))
        raw_bias_updates.append(scaled_noise.mean(dim=0))
    return _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)


def node_perturbation_fan_in_gradient_estimate_vector(model, xb, yb, sigma):
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb_fan_in_scaled(xb, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, yb)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    for x_in, noise, noise_scale in zip(activations, noises, noise_scales):
        scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
        raw_weight_updates.append(torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0))
        raw_bias_updates.append(scaled_noise.mean(dim=0))
    return _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)


def node_perturbation_fixed_sigma_gradient_estimate_vector(model, xb, yb, sigma):
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb_fixed_sigma(xb, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, yb)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    for x_in, noise, noise_scale in zip(activations, noises, noise_scales):
        scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
        raw_weight_updates.append(torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0))
        raw_bias_updates.append(scaled_noise.mean(dim=0))
    return _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)


def weight_perturbation_gradient_estimate_vector(model, xb, yb, sigma):
    layer_outputs, _, noises = model.forward_weight_perturb(xb, sigma)
    prediction_noisy = layer_outputs[-1]
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, yb)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    noise_scale = sigma ** 2 + 1e-12
    raw_weight_updates = []
    raw_bias_updates = []
    for weight_noise, bias_noise in noises:
        scaled_weight_noise = scalar_signal.view(-1, 1, 1) * weight_noise / noise_scale
        scaled_bias_noise = scalar_signal.view(-1, 1) * bias_noise / noise_scale
        raw_weight_updates.append(scaled_weight_noise.mean(dim=0))
        raw_bias_updates.append(scaled_bias_noise.mean(dim=0))
    return _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)


def perturbation_gradient_estimate_vector(method, model, xb, yb, sigma):
    if method == "np":
        return node_perturbation_gradient_estimate_vector(model, xb, yb, sigma)
    if method == "np_fan_in":
        return node_perturbation_fan_in_gradient_estimate_vector(model, xb, yb, sigma)
    if method == "np_fixed":
        return node_perturbation_fixed_sigma_gradient_estimate_vector(model, xb, yb, sigma)
    if method == "wp":
        return weight_perturbation_gradient_estimate_vector(model, xb, yb, sigma)
    raise ValueError(f"Unknown perturbation method: {method}")


def variance_against_true_gradient(estimate_matrix, true_update):
    num_samples = estimate_matrix.shape[0]
    if num_samples == 0:
        return 0.0, 0.0

    squared_errors = (estimate_matrix - true_update.unsqueeze(0)).pow(2)
    per_sample_variance = float(squared_errors.mean(dim=1).mean())
    mean_estimate = estimate_matrix.mean(dim=0)
    batch_variance = float((mean_estimate - true_update).pow(2).mean())
    return per_sample_variance, batch_variance


def train_backprop_checkpoint_states(data, dimensions, epochs, seed, device, lr, checkpoint_epochs, print_every_epoch=100):
    checkpoint_epochs = sorted(set(int(epoch) for epoch in checkpoint_epochs))
    set_seed(seed)
    model = make_model(dimensions, require_grad=True, device=device)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)
    checkpoint_states = {}

    for epoch in range(1, epochs + 1):
        model.train()
        for xb, yb in data["train_loader"]:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)
            backprop_step(model, xb, yb, optimizer=optimizer)

        if epoch in checkpoint_epochs:
            checkpoint_states[epoch] = {name: tensor.detach().cpu().clone() for name, tensor in model.state_dict().items()}

        if epoch % print_every_epoch == 0 or epoch == 1 or epoch == epochs or epoch in checkpoint_epochs:
            train_loss, train_r2 = evaluate_model(model, data["train_eval_loader"], device)
            test_loss, test_r2 = evaluate_model(model, data["test_loader"], device)
            print(
                f"    bp checkpoint training epoch {epoch:4d}/{epochs} | "
                f"train_loss={train_loss:.4f}, train_r2={train_r2:.4f}, "
                f"test_loss={test_loss:.4f}, test_r2={test_r2:.4f}"
            )

    return checkpoint_states


def layer_parameter_slices(model):
    layer_slices = []
    start = 0
    for layer_idx, layer in enumerate(model.layers):
        layer_parameter_count = layer.weight.numel() + layer.bias.numel()
        layer_slices.append((layer_idx, slice(start, start + layer_parameter_count), f"Layer {layer_idx + 1}"))
        start += layer_parameter_count
    return layer_slices


def analyze_frozen_backprop_estimators(
    checkpoint_states,
    data,
    dimensions,
    device,
    method_sigmas,
    num_perturbations=50,
    batch_size=128,
):
    analysis_dataset = TensorDataset(data["x_train"], data["y_train"])
    analysis_loader = DataLoader(
        analysis_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=0,
        pin_memory=(device.type == "cuda"),
    )

    rows = []
    perturbation_methods = list(method_sigmas.keys())

    for checkpoint_epoch, state_dict in checkpoint_states.items():
        model = make_model(dimensions, require_grad=True, device=device)
        model.load_state_dict(state_dict)
        component_specs = [(-1, slice(None), "All layers")] + layer_parameter_slices(model)

        batch_metrics = {
            method: {
                layer_index: {
                    "component": "all" if layer_index == -1 else f"layer_{layer_index + 1}",
                    "component_label": component_label,
                    "avg_sample_cosine": [],
                    "mean_estimate_cosine": [],
                    "sample_variance": [],
                    "batch_variance": [],
                }
                for layer_index, _, component_label in component_specs
            }
            for method in perturbation_methods
        }

        for xb, yb in analysis_loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)
            true_update = true_gradient_vector(model, xb, yb)

            for method in perturbation_methods:
                sigma = method_sigmas[method]
                estimates = [
                    perturbation_gradient_estimate_vector(method, model, xb, yb, sigma)
                    for _ in range(num_perturbations)
                ]
                estimate_matrix = torch.stack(estimates, dim=0)
                mean_estimate = estimate_matrix.mean(dim=0)

                for layer_index, component_slice, _ in component_specs:
                    component_true_update = true_update[component_slice]
                    component_estimate_matrix = estimate_matrix[:, component_slice]
                    component_mean_estimate = mean_estimate[component_slice]

                    avg_sample_cosine = float(
                        np.mean(
                            [
                                cosine_similarity_safe(component_estimate, component_true_update)
                                for component_estimate in component_estimate_matrix
                            ]
                        )
                    )
                    mean_estimate_cosine = cosine_similarity_safe(component_mean_estimate, component_true_update)
                    sample_variance, batch_variance = variance_against_true_gradient(
                        component_estimate_matrix,
                        component_true_update,
                    )

                    metrics = batch_metrics[method][layer_index]
                    metrics["avg_sample_cosine"].append(avg_sample_cosine)
                    metrics["mean_estimate_cosine"].append(mean_estimate_cosine)
                    metrics["sample_variance"].append(sample_variance)
                    metrics["batch_variance"].append(batch_variance)

        checkpoint_fraction = checkpoint_epoch / max(checkpoint_states.keys())
        for method in perturbation_methods:
            for layer_index, _, component_label in component_specs:
                metrics = batch_metrics[method][layer_index]
                rows.append({
                    "checkpoint_epoch": checkpoint_epoch,
                    "checkpoint_fraction": checkpoint_fraction,
                    "method": method,
                    "sigma": method_sigmas[method],
                    "component": metrics["component"],
                    "component_label": component_label,
                    "layer_index": layer_index,
                    "avg_sample_cosine": float(np.mean(metrics["avg_sample_cosine"])),
                    "mean_estimate_cosine": float(np.mean(metrics["mean_estimate_cosine"])),
                    "sample_variance": float(np.mean(metrics["sample_variance"])),
                    "batch_variance": float(np.mean(metrics["batch_variance"])),
                })

    return pd.DataFrame(rows)


def plot_frozen_estimator_statistics(stats_df):
    metrics = [
        ("avg_sample_cosine", "Average Sample Cosine", "Cosine"),
        ("mean_estimate_cosine", "Cosine of Mean Estimator", "Cosine"),
        ("sample_variance", "Per-Sample Variance to True Gradient", "Mean squared distance per parameter"),
        ("batch_variance", "Batch-Average Variance to True Gradient", "Mean squared distance per parameter"),
    ]
    perturbation_methods = [method for method in METHODS if method in {"np", "np_fan_in", "np_fixed", "wp"}]

    overall_df = stats_df[stats_df["layer_index"] == -1] if "layer_index" in stats_df.columns else stats_df
    fig, axes = plt.subplots(1, len(metrics), figsize=(24, 4), sharex=True)

    for method in perturbation_methods:
        method_df = overall_df[overall_df["method"] == method].sort_values("checkpoint_epoch")
        if len(method_df) == 0:
            continue
        x = method_df["checkpoint_epoch"].to_numpy()
        for axis, (column, title, ylabel) in zip(axes, metrics):
            axis.plot(x, method_df[column].to_numpy(), marker="o", color=METHOD_COLORS[method], label=METHOD_LABELS[method])
            axis.set_title(f"All layers | {title}")
            axis.set_xlabel("Checkpoint epoch")
            axis.set_ylabel(ylabel)
            axis.legend()

    fig.tight_layout()
    plt.show()

    if "layer_index" not in stats_df.columns:
        return

    layer_indices = sorted(layer_index for layer_index in stats_df["layer_index"].unique() if layer_index >= 0)
    if len(layer_indices) == 0:
        return

    fig, axes = plt.subplots(
        len(layer_indices),
        len(metrics),
        figsize=(6 * len(metrics), 3.8 * len(layer_indices)),
        sharex=True,
        squeeze=False,
    )

    for row, layer_index in enumerate(layer_indices):
        layer_df = stats_df[stats_df["layer_index"] == layer_index]
        component_label = layer_df["component_label"].iloc[0]

        for col, (column, title, ylabel) in enumerate(metrics):
            axis = axes[row, col]
            for method in perturbation_methods:
                method_df = layer_df[layer_df["method"] == method].sort_values("checkpoint_epoch")
                if len(method_df) == 0:
                    continue
                axis.plot(
                    method_df["checkpoint_epoch"].to_numpy(),
                    method_df[column].to_numpy(),
                    marker="o",
                    color=METHOD_COLORS[method],
                    label=METHOD_LABELS[method],
                )
            axis.set_title(f"{component_label} | {title}")
            axis.set_xlabel("Checkpoint epoch")
            axis.set_ylabel(ylabel)
            if col == len(metrics) - 1:
                axis.legend(fontsize=8)

    fig.tight_layout()
    plt.show()


def analyze_frozen_backprop_sigma_grid(
    checkpoint_states,
    data,
    dimensions,
    device,
    method_sigma_grid,
    num_perturbations=50,
    batch_size=128,
):
    analysis_dataset = TensorDataset(data["x_train"], data["y_train"])
    analysis_loader = DataLoader(
        analysis_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=0,
        pin_memory=(device.type == "cuda"),
    )

    rows = []
    methods = list(method_sigma_grid.keys())

    for checkpoint_epoch, state_dict in checkpoint_states.items():
        model = make_model(dimensions, require_grad=True, device=device)
        model.load_state_dict(state_dict)

        batch_metrics = {
            (method, sigma): {
                "avg_sample_cosine": [],
                "mean_estimate_cosine": [],
                "sample_variance": [],
                "batch_variance": [],
            }
            for method in methods
            for sigma in method_sigma_grid[method]
        }

        for batch in analysis_loader:
            if len(batch) == 3:
                xb, yb, _ = batch
            else:
                xb, yb = batch
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)
            true_update = true_gradient_vector(model, xb, yb)

            for method in methods:
                for sigma in method_sigma_grid[method]:
                    estimates = [
                        perturbation_gradient_estimate_vector(method, model, xb, yb, sigma)
                        for _ in range(num_perturbations)
                    ]
                    estimate_matrix = torch.stack(estimates, dim=0)
                    mean_estimate = estimate_matrix.mean(dim=0)

                    avg_sample_cosine = float(
                        sum(cosine_similarity_safe(estimate, true_update) for estimate in estimates) / num_perturbations
                    )
                    mean_estimate_cosine = cosine_similarity_safe(mean_estimate, true_update)
                    sample_variance, batch_variance = variance_against_true_gradient(estimate_matrix, true_update)

                    metrics = batch_metrics[(method, sigma)]
                    metrics["avg_sample_cosine"].append(avg_sample_cosine)
                    metrics["mean_estimate_cosine"].append(mean_estimate_cosine)
                    metrics["sample_variance"].append(sample_variance)
                    metrics["batch_variance"].append(batch_variance)

        checkpoint_fraction = checkpoint_epoch / max(checkpoint_states.keys())
        for method in methods:
            for sigma in method_sigma_grid[method]:
                metrics = batch_metrics[(method, sigma)]
                rows.append({
                    "checkpoint_epoch": checkpoint_epoch,
                    "checkpoint_fraction": checkpoint_fraction,
                    "method": method,
                    "sigma": float(sigma),
                    "avg_sample_cosine": float(np.mean(metrics["avg_sample_cosine"])),
                    "mean_estimate_cosine": float(np.mean(metrics["mean_estimate_cosine"])),
                    "sample_variance": float(np.mean(metrics["sample_variance"])),
                    "batch_variance": float(np.mean(metrics["batch_variance"])),
                })

    return pd.DataFrame(rows)


def plot_frozen_sigma_search_results(stats_df):
    metrics = [
        ("avg_sample_cosine", "Average Sample Cosine", "Cosine"),
        ("mean_estimate_cosine", "Cosine of Mean Estimator", "Cosine"),
        ("sample_variance", "Per-Sample Variance to True Gradient", "Mean squared distance per parameter"),
        ("batch_variance", "Batch-Average Variance to True Gradient", "Mean squared distance per parameter"),
    ]
    checkpoint_epochs = sorted(stats_df["checkpoint_epoch"].unique())

    for method in [method for method in METHODS if method in set(stats_df["method"])] :
        method_df = stats_df[stats_df["method"] == method]
        fig, axes = plt.subplots(
            len(checkpoint_epochs),
            len(metrics),
            figsize=(5 * len(metrics), 3.8 * len(checkpoint_epochs)),
            squeeze=False,
        )

        for row, checkpoint_epoch in enumerate(checkpoint_epochs):
            subset = method_df[method_df["checkpoint_epoch"] == checkpoint_epoch].sort_values("sigma")
            sigma_labels = [f"{sigma:.4g}" for sigma in subset["sigma"].to_numpy()]

            for col, (column, title, ylabel) in enumerate(metrics):
                axis = axes[row, col]
                axis.bar(sigma_labels, subset[column].to_numpy(), color=METHOD_COLORS[method])
                axis.set_title(f"epoch {checkpoint_epoch} | {title}")
                axis.set_xlabel("sigma")
                axis.set_ylabel(ylabel)
                axis.tick_params(axis="x", rotation=45)

        fig.suptitle(f"{METHOD_LABELS[method]} sigma search", y=1.02)
        fig.tight_layout()
        plt.show()


def build_grid(space):
    keys = list(space.keys())
    values = [space[key] for key in keys]
    return [dict(zip(keys, combo)) for combo in itertools.product(*values)]


def run_sweep(search_spaces, data, dimensions, sweep_epochs, seeds, device):
    results = []
    flat_records = []
    total_runs = sum(len(configs) * len(seeds) for configs in search_spaces.values())
    run_idx = 0

    print(f"Starting sweep with total_runs={total_runs}, device={device}")
    for method in METHODS:
        configs = search_spaces[method]
        for config in configs:
            for seed in seeds:
                run_idx += 1
                sigma_str = f", sigma={config['sigma']:.4g}" if "sigma" in config else ""
                print()
                print(f"=== Run {run_idx}/{total_runs} | {method} | lr={config['lr']:.4g}{sigma_str} | seed={seed} ===")
                result = train_one_run(
                    method=method,
                    run_config=config,
                    data=data,
                    dimensions=dimensions,
                    epochs=sweep_epochs,
                    seed=seed,
                    device=device,
                    print_every_epoch=1,
                )
                results.append(result)
                flat_record = {k: v for k, v in result.items() if k not in {"history", "state_dict"}}
                flat_record["seed"] = seed
                flat_records.append(flat_record)

    df = pd.DataFrame(flat_records)
    if len(df) > 0:
        df = df.sort_values(
            ["method", "final_test_loss", "best_test_loss", "final_test_r2"],
            ascending=[True, True, True, False],
        ).reset_index(drop=True)
    return results, df


def summarize_top_configs(df, top_k=5):
    if len(df) == 0:
        return df
    frames = []
    for method, group in df.groupby("method"):
        frames.append(group.head(top_k))
    return pd.concat(frames, ignore_index=True)


def select_best_configs(df):
    rows = []
    good = df[df["diverged"] == False]
    for method, group in good.groupby("method"):
        best = group.sort_values(
            ["final_test_loss", "best_test_loss", "final_test_r2"],
            ascending=[True, True, False],
        ).iloc[0]
        rows.append(best)
    return pd.DataFrame(rows).reset_index(drop=True)


def run_best_config_comparison(best_df, data, dimensions, final_epochs, seed, device):
    comparison_results = {}
    for row in best_df.itertuples(index=False):
        config = {"lr": float(row.lr)}
        if not pd.isna(row.sigma):
            config["sigma"] = float(row.sigma)
        print(
            f"### Final run | {row.method} | lr={config['lr']:.4g}" +
            (f", sigma={config['sigma']:.4g}" if 'sigma' in config else "")
        )
        comparison_results[row.method] = train_one_run(
            method=row.method,
            run_config=config,
            data=data,
            dimensions=dimensions,
            epochs=final_epochs,
            seed=seed,
            device=device,
            print_every_epoch=1,
        )
    return comparison_results


def results_table(results_by_method):
    rows = []
    for method in METHODS:
        if method not in results_by_method:
            continue
        result = results_by_method[method]
        rows.append(
            {
                "method": method,
                "final_train_loss": result["final_train_loss"],
                "final_train_r2": result["final_train_r2"],
                "final_test_loss": result["final_test_loss"],
                "final_test_r2": result["final_test_r2"],
                "best_test_loss": result["best_test_loss"],
                "best_test_r2": result["best_test_r2"],
                "diverged": result["diverged"],
                "duration_sec": result["duration_sec"],
            }
        )
    return pd.DataFrame(rows)


def plot_training_histories(results_by_method):
    fig, axes = plt.subplots(3, 1, figsize=(10, 11), sharex=True)
    for method in METHODS:
        if method not in results_by_method:
            continue
        result = results_by_method[method]
        history = result["history"]
        axes[0].plot(history["epoch"], history["train_loss"], label=f"{METHOD_LABELS[method]} train", color=METHOD_COLORS[method])
        axes[0].plot(history["epoch"], history["test_loss"], linestyle="--", label=f"{METHOD_LABELS[method]} test", color=METHOD_COLORS[method])
        axes[1].plot(history["epoch"], history["train_r2"], label=f"{METHOD_LABELS[method]} train", color=METHOD_COLORS[method])
        axes[1].plot(history["epoch"], history["test_r2"], linestyle="--", label=f"{METHOD_LABELS[method]} test", color=METHOD_COLORS[method])
        axes[2].plot(history["epoch"], history["weight_norm"], label=METHOD_LABELS[method], color=METHOD_COLORS[method])
    axes[0].set_title("Loss")
    axes[0].set_ylabel("MSE")
    axes[0].legend(ncol=2)
    axes[1].set_title("R^2")
    axes[1].set_ylabel("R^2")
    axes[1].legend(ncol=2)
    axes[2].set_title("Weight Norm")
    axes[2].set_ylabel("L2 norm")
    axes[2].set_xlabel("Epoch")
    axes[2].legend(ncol=2)
    fig.tight_layout()
    plt.show()

def plot_layer_output_norm_histories(results_by_method):
    first_result = next((results_by_method[method] for method in METHODS if method in results_by_method), None)
    if first_result is None:
        return

    layer_output_history = first_result["history"].get("layer_output_norms", [])
    if len(layer_output_history) == 0:
        return

    num_layers = len(layer_output_history[0])
    fig, axes = plt.subplots(num_layers, 1, figsize=(10, 3.4 * num_layers), sharex=True, squeeze=False)
    axes = axes.flatten()

    for layer_idx in range(num_layers):
        fan_in = int(first_result["state_dict"][f"layers.{layer_idx}.weight"].shape[1])
        layer_label = "Input layer" if layer_idx == 0 else f"Hidden layer {layer_idx} output"
        axis = axes[layer_idx]
        for method in METHODS:
            if method not in results_by_method:
                continue
            history = results_by_method[method]["history"]
            values = [epoch_values[layer_idx] for epoch_values in history.get("layer_output_norms", [])]
            if len(values) == 0:
                continue
            axis.plot(history["epoch"], values, label=METHOD_LABELS[method], color=METHOD_COLORS[method])
        axis.set_title(f"{layer_label} norm / sqrt({fan_in} + 1)")
        axis.set_ylabel("Average norm")
        axis.legend(ncol=2)

    axes[-1].set_xlabel("Epoch")
    fig.tight_layout()
    plt.show()


def load_california_housing(
    test_size=0.2,
    batch_size=256,
    eval_batch_size=4096,
    seed=0,
    num_workers=0,
    data_home=None,
):
    dataset = fetch_california_housing(data_home=data_home)
    x_train, x_test, y_train, y_test = train_test_split(
        dataset.data,
        dataset.target,
        test_size=test_size,
        random_state=seed,
    )

    x_scaler = StandardScaler()
    y_scaler = StandardScaler()

    x_train = x_scaler.fit_transform(x_train)
    x_test = x_scaler.transform(x_test)
    y_train = y_scaler.fit_transform(y_train.reshape(-1, 1))
    y_test = y_scaler.transform(y_test.reshape(-1, 1))

    x_train = torch.tensor(x_train, dtype=torch.float32)
    y_train = torch.tensor(y_train, dtype=torch.float32)
    x_test = torch.tensor(x_test, dtype=torch.float32)
    y_test = torch.tensor(y_test, dtype=torch.float32)

    train_dataset = TensorDataset(x_train, y_train)
    test_dataset = TensorDataset(x_test, y_test)

    pin_memory = device.type == "cuda"
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
    train_eval_loader = DataLoader(train_dataset, batch_size=eval_batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
    test_loader = DataLoader(test_dataset, batch_size=eval_batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)

    return {
        "train_loader": train_loader,
        "train_eval_loader": train_eval_loader,
        "test_loader": test_loader,
        "train_size": len(train_dataset),
        "train_eval_size": len(train_dataset),
        "test_size": len(test_dataset),
        "x_train": x_train,
        "y_train": y_train,
        "x_test": x_test,
        "y_test": y_test,
    }


def plot_prediction_diagnostics(results_by_method, data, dimensions, device):
    y_true = data["y_test"].squeeze().numpy()
    min_val = float(np.min(y_true))
    max_val = float(np.max(y_true))

    plt.figure(figsize=(8, 8))
    plt.plot([min_val, max_val], [min_val, max_val], color="black", linestyle="--", label="Perfect prediction")

    for method in METHODS:
        if method not in results_by_method:
            continue
        model = make_model(dimensions, require_grad=(method == "bp"), device=device)
        model.load_state_dict(results_by_method[method]["state_dict"])
        prediction = predict_tensor(model, data["x_test"], device).squeeze().numpy()
        plt.scatter(y_true, prediction, s=10, alpha=0.25, color=METHOD_COLORS[method], label=METHOD_LABELS[method])

    plt.title("California Housing Test Predictions")
    plt.xlabel("True standardized target")
    plt.ylabel("Predicted standardized target")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Default Colab-friendly setup.
# The sweep is centered on the current local California Housing settings.


DIMENSIONS = (8, 128, 64, 1)
BATCH_SIZE = 256
EVAL_BATCH_SIZE = 4096
TEST_SIZE = 0.2
SWEEP_EPOCHS = 30
FINAL_EPOCHS = 200
SWEEP_SEEDS = [0]
NUM_WORKERS = 0


SEARCH_SPACES = {
    "bp": build_grid({"lr": [0.075, 0.1, 0.15]}),
    "np": build_grid({"lr": [0.02, 0.03, 0.04], "sigma": [0.08, 0.1, 0.12]}),
    "np_fan_in": build_grid({"lr": [0.015, 0.02, 0.025], "sigma": [0.045, 0.0525, 0.06]}),
    "np_fixed": build_grid({"lr": [0.02, 0.025, 0.03], "sigma": [0.4, 0.45, 0.5]}),
    "wp": build_grid({"lr": [0.01, 0.0125, 0.015], "sigma": [0.08, 0.1, 0.12]}),
}



data = load_california_housing(
    test_size=TEST_SIZE,
    batch_size=BATCH_SIZE,
    eval_batch_size=EVAL_BATCH_SIZE,
    seed=0,
    num_workers=NUM_WORKERS,
)

print(
    f"train_size={data['train_size']}, train_eval_size={data['train_eval_size']}, "
    f"test_size={data['test_size']}, dims={DIMENSIONS}, batch_size={BATCH_SIZE}, device={device}"
)
print({method: len(configs) for method, configs in SEARCH_SPACES.items()})
# Out:
# train_size=16512, train_eval_size=16512, test_size=4128, dims=(8, 128, 64, 1), batch_size=256, device=cuda
# {'bp': 3, 'np': 9, 'np_fan_in': 9, 'np_fixed': 9, 'wp': 9}

# %%
# Run the modest default sweep.
# This should be manageable on a Colab GPU, but you can always reduce SWEEP_EPOCHS or the search spaces.

#METHODS = ["bp", "np", "np_fan_in", "np_fixed", "wp"]
METHODS = ["wp"]


sweep_results, sweep_df = run_sweep(
    search_spaces=SEARCH_SPACES,
    data=data,
    dimensions=DIMENSIONS,
    sweep_epochs=20,
    seeds=SWEEP_SEEDS,
    device=device,
)

display(summarize_top_configs(sweep_df, top_k=5))

best_configs_df = select_best_configs(sweep_df)
display(best_configs_df)
# Out:
# Starting sweep with total_runs=39, device=cuda
#
# === Run 1/39 | wp | lr=0.01, sigma=0.08 | seed=0 ===
#     epoch  1/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.9019, train_r2=0.0981, test_loss=0.8852, test_r2=0.0914
#     epoch  2/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.9005, train_r2=0.0995, test_loss=0.8796, test_r2=0.0972
#     epoch  3/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.8663, train_r2=0.1337, test_loss=0.8453, test_r2=0.1323
#     epoch  4/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.7882, train_r2=0.2118, test_loss=0.7818, test_r2=0.1975
#     epoch  5/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.6665, train_r2=0.3335, test_loss=0.6595, test_r2=0.3231
#     epoch  6/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.6019, train_r2=0.3981, test_loss=0.6026, test_r2=0.3815
#     epoch  7/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.5276, train_r2=0.4724, test_loss=0.5301, test_r2=0.4559
#     epoch  8/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.5056, train_r2=0.4944, test_loss=0.5118, test_r2=0.4747
#     epoch  9/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.5192, train_r2=0.4808, test_loss=0.5232, test_r2=0.4630
#     epoch 10/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.4578, train_r2=0.5422, test_loss=0.4661, test_r2=0.5216
#     epoch 11/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.4202, train_r2=0.5798, test_loss=0.4322, test_r2=0.5564
#     epoch 12/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.4391, train_r2=0.5609, test_loss=0.4465, test_r2=0.5417
#     epoch 13/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.4325, train_r2=0.5675, test_loss=0.4379, test_r2=0.5506
#     epoch 14/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.4380, train_r2=0.5620, test_loss=0.4458, test_r2=0.5424
#     epoch 15/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.4144, train_r2=0.5856, test_loss=0.4217, test_r2=0.5672
#     epoch 16/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.4035, train_r2=0.5965, test_loss=0.4115, test_r2=0.5776
#     epoch 17/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.4023, train_r2=0.5977, test_loss=0.4137, test_r2=0.5754
#     epoch 18/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.4023, train_r2=0.5977, test_loss=0.4150, test_r2=0.5740
#     epoch 19/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.4067, train_r2=0.5933, test_loss=0.4206, test_r2=0.5683
#     epoch 20/20 | wp | lr=0.01, sigma=0.08 | train_loss=0.3941, train_r2=0.6059, test_loss=0.4073, test_r2=0.5820
#
# === Run 2/39 | wp | lr=0.01, sigma=0.1 | seed=0 ===
#     epoch  1/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.9211, train_r2=0.0789, test_loss=0.9028, test_r2=0.0734
#     epoch  2/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.9257, train_r2=0.0743, test_loss=0.9028, test_r2=0.0734
#     epoch  3/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.9019, train_r2=0.0981, test_loss=0.8792, test_r2=0.0976
#     epoch  4/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.8512, train_r2=0.1488, test_loss=0.8404, test_r2=0.1374
#     epoch  5/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.7406, train_r2=0.2594, test_loss=0.7288, test_r2=0.2520
#     epoch  6/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.6621, train_r2=0.3379, test_loss=0.6591, test_r2=0.3235
#     epoch  7/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.5891, train_r2=0.4109, test_loss=0.5874, test_r2=0.3971
#     epoch  8/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.5529, train_r2=0.4471, test_loss=0.5549, test_r2=0.4304
#     epoch  9/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.5410, train_r2=0.4590, test_loss=0.5438, test_r2=0.4419
#     epoch 10/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.4899, train_r2=0.5101, test_loss=0.4961, test_r2=0.4908
#     epoch 11/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.4448, train_r2=0.5552, test_loss=0.4544, test_r2=0.5336
#     epoch 12/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.4551, train_r2=0.5449, test_loss=0.4617, test_r2=0.5261
#     epoch 13/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.4326, train_r2=0.5674, test_loss=0.4402, test_r2=0.5482
#     epoch 14/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.4488, train_r2=0.5512, test_loss=0.4575, test_r2=0.5304
#     epoch 15/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.4241, train_r2=0.5759, test_loss=0.4330, test_r2=0.5556
#     epoch 16/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.4176, train_r2=0.5824, test_loss=0.4268, test_r2=0.5619
#     epoch 17/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.4111, train_r2=0.5889, test_loss=0.4230, test_r2=0.5658
#     epoch 18/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.4132, train_r2=0.5868, test_loss=0.4270, test_r2=0.5618
#     epoch 19/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.4128, train_r2=0.5872, test_loss=0.4271, test_r2=0.5617
#     epoch 20/20 | wp | lr=0.01, sigma=0.1 | train_loss=0.4017, train_r2=0.5983, test_loss=0.4146, test_r2=0.5745
#
# === Run 3/39 | wp | lr=0.01, sigma=0.12 | seed=0 ===
#     epoch  1/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.9326, train_r2=0.0674, test_loss=0.9133, test_r2=0.0626
#     epoch  2/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.9407, train_r2=0.0593, test_loss=0.9165, test_r2=0.0594
#     epoch  3/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.9204, train_r2=0.0796, test_loss=0.8968, test_r2=0.0795
#     epoch  4/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.8852, train_r2=0.1148, test_loss=0.8714, test_r2=0.1056
#     epoch  5/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.7927, train_r2=0.2073, test_loss=0.7775, test_r2=0.2020
#     epoch  6/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.7148, train_r2=0.2852, test_loss=0.7083, test_r2=0.2730
#     epoch  7/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.6554, train_r2=0.3446, test_loss=0.6492, test_r2=0.3337
#     epoch  8/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.6137, train_r2=0.3863, test_loss=0.6111, test_r2=0.3728
#     epoch  9/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.5826, train_r2=0.4174, test_loss=0.5825, test_r2=0.4022
#     epoch 10/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.5299, train_r2=0.4701, test_loss=0.5334, test_r2=0.4525
#     epoch 11/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.4836, train_r2=0.5164, test_loss=0.4905, test_r2=0.4965
#     epoch 12/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.4774, train_r2=0.5226, test_loss=0.4835, test_r2=0.5037
#     epoch 13/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.4455, train_r2=0.5545, test_loss=0.4537, test_r2=0.5343
#     epoch 14/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.4676, train_r2=0.5324, test_loss=0.4766, test_r2=0.5109
#     epoch 15/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.4403, train_r2=0.5597, test_loss=0.4501, test_r2=0.5380
#     epoch 16/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.4380, train_r2=0.5620, test_loss=0.4483, test_r2=0.5399
#     epoch 17/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.4255, train_r2=0.5745, test_loss=0.4385, test_r2=0.5499
#     epoch 18/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.4282, train_r2=0.5718, test_loss=0.4433, test_r2=0.5450
#     epoch 19/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.4212, train_r2=0.5788, test_loss=0.4366, test_r2=0.5519
#     epoch 20/20 | wp | lr=0.01, sigma=0.12 | train_loss=0.4174, train_r2=0.5826, test_loss=0.4311, test_r2=0.5576
#
# === Run 4/39 | wp | lr=0.0125, sigma=0.08 | seed=0 ===
#     epoch  1/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.8548, train_r2=0.1452, test_loss=0.8415, test_r2=0.1363
#     epoch  2/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.8226, train_r2=0.1774, test_loss=0.8069, test_r2=0.1718
#     epoch  3/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.7314, train_r2=0.2686, test_loss=0.7195, test_r2=0.2615
#     epoch  4/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.6429, train_r2=0.3571, test_loss=0.6464, test_r2=0.3366
#     epoch  5/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.5493, train_r2=0.4507, test_loss=0.5508, test_r2=0.4347
#     epoch  6/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.5094, train_r2=0.4906, test_loss=0.5172, test_r2=0.4692
#     epoch  7/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.4746, train_r2=0.5254, test_loss=0.4811, test_r2=0.5062
#     epoch  8/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.4658, train_r2=0.5342, test_loss=0.4749, test_r2=0.5126
#     epoch  9/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.4921, train_r2=0.5079, test_loss=0.4971, test_r2=0.4898
#     epoch 10/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.4159, train_r2=0.5841, test_loss=0.4274, test_r2=0.5613
#     epoch 11/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.4120, train_r2=0.5880, test_loss=0.4265, test_r2=0.5622
#     epoch 12/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.4280, train_r2=0.5720, test_loss=0.4360, test_r2=0.5525
#     epoch 13/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.4416, train_r2=0.5584, test_loss=0.4436, test_r2=0.5447
#     epoch 14/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.4201, train_r2=0.5799, test_loss=0.4287, test_r2=0.5600
#     epoch 15/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.4072, train_r2=0.5928, test_loss=0.4134, test_r2=0.5757
#     epoch 16/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.3886, train_r2=0.6114, test_loss=0.3957, test_r2=0.5939
#     epoch 17/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.3973, train_r2=0.6027, test_loss=0.4085, test_r2=0.5808
#     epoch 18/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.3938, train_r2=0.6062, test_loss=0.4072, test_r2=0.5821
#     epoch 19/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.4228, train_r2=0.5772, test_loss=0.4410, test_r2=0.5474
#     epoch 20/20 | wp | lr=0.0125, sigma=0.08 | train_loss=0.3811, train_r2=0.6189, test_loss=0.3965, test_r2=0.5930
#
# === Run 5/39 | wp | lr=0.0125, sigma=0.1 | seed=0 ===
#     epoch  1/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.8839, train_r2=0.1161, test_loss=0.8682, test_r2=0.1089
#     epoch  2/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.8696, train_r2=0.1304, test_loss=0.8504, test_r2=0.1272
#     epoch  3/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.8047, train_r2=0.1953, test_loss=0.7884, test_r2=0.1908
#     epoch  4/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.7253, train_r2=0.2747, test_loss=0.7226, test_r2=0.2583
#     epoch  5/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.6105, train_r2=0.3895, test_loss=0.6077, test_r2=0.3763
#     epoch  6/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.5419, train_r2=0.4581, test_loss=0.5469, test_r2=0.4387
#     epoch  7/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.5030, train_r2=0.4970, test_loss=0.5077, test_r2=0.4789
#     epoch  8/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.4828, train_r2=0.5172, test_loss=0.4900, test_r2=0.4971
#     epoch  9/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.4909, train_r2=0.5091, test_loss=0.4971, test_r2=0.4897
#     epoch 10/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.4372, train_r2=0.5628, test_loss=0.4469, test_r2=0.5413
#     epoch 11/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.4128, train_r2=0.5872, test_loss=0.4249, test_r2=0.5639
#     epoch 12/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.4428, train_r2=0.5572, test_loss=0.4489, test_r2=0.5392
#     epoch 13/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.4276, train_r2=0.5724, test_loss=0.4321, test_r2=0.5565
#     epoch 14/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.4294, train_r2=0.5706, test_loss=0.4371, test_r2=0.5514
#     epoch 15/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.4091, train_r2=0.5909, test_loss=0.4165, test_r2=0.5725
#     epoch 16/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.3979, train_r2=0.6021, test_loss=0.4051, test_r2=0.5842
#     epoch 17/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.3946, train_r2=0.6054, test_loss=0.4065, test_r2=0.5828
#     epoch 18/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.3958, train_r2=0.6042, test_loss=0.4093, test_r2=0.5799
#     epoch 19/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.4034, train_r2=0.5966, test_loss=0.4172, test_r2=0.5718
#     epoch 20/20 | wp | lr=0.0125, sigma=0.1 | train_loss=0.3853, train_r2=0.6147, test_loss=0.3980, test_r2=0.5915
#
# === Run 6/39 | wp | lr=0.0125, sigma=0.12 | seed=0 ===
#     epoch  1/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.9012, train_r2=0.0988, test_loss=0.8841, test_r2=0.0925
#     epoch  2/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.8982, train_r2=0.1018, test_loss=0.8768, test_r2=0.1001
#     epoch  3/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.8477, train_r2=0.1523, test_loss=0.8288, test_r2=0.1493
#     epoch  4/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.7838, train_r2=0.2162, test_loss=0.7765, test_r2=0.2030
#     epoch  5/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.6713, train_r2=0.3287, test_loss=0.6645, test_r2=0.3180
#     epoch  6/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.5844, train_r2=0.4156, test_loss=0.5863, test_r2=0.3982
#     epoch  7/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.5420, train_r2=0.4580, test_loss=0.5442, test_r2=0.4415
#     epoch  8/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.5126, train_r2=0.4874, test_loss=0.5176, test_r2=0.4688
#     epoch  9/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.5061, train_r2=0.4939, test_loss=0.5125, test_r2=0.4740
#     epoch 10/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.4617, train_r2=0.5383, test_loss=0.4705, test_r2=0.5171
#     epoch 11/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.4301, train_r2=0.5699, test_loss=0.4411, test_r2=0.5473
#     epoch 12/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.4608, train_r2=0.5392, test_loss=0.4667, test_r2=0.5210
#     epoch 13/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.4289, train_r2=0.5711, test_loss=0.4351, test_r2=0.5534
#     epoch 14/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.4425, train_r2=0.5575, test_loss=0.4503, test_r2=0.5378
#     epoch 15/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.4166, train_r2=0.5834, test_loss=0.4255, test_r2=0.5632
#     epoch 16/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.4145, train_r2=0.5855, test_loss=0.4226, test_r2=0.5663
#     epoch 17/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.4047, train_r2=0.5953, test_loss=0.4165, test_r2=0.5726
#     epoch 18/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.4054, train_r2=0.5946, test_loss=0.4194, test_r2=0.5695
#     epoch 19/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.4042, train_r2=0.5958, test_loss=0.4175, test_r2=0.5715
#     epoch 20/20 | wp | lr=0.0125, sigma=0.12 | train_loss=0.3985, train_r2=0.6015, test_loss=0.4101, test_r2=0.5791
#
# === Run 7/39 | wp | lr=0.015, sigma=0.08 | seed=0 ===
#     epoch  1/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.7971, train_r2=0.2029, test_loss=0.7871, test_r2=0.1921
#     epoch  2/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.7276, train_r2=0.2724, test_loss=0.7182, test_r2=0.2628
#     epoch  3/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.6020, train_r2=0.3980, test_loss=0.6002, test_r2=0.3840
#     epoch  4/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.5506, train_r2=0.4494, test_loss=0.5626, test_r2=0.4226
#     epoch  5/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.5060, train_r2=0.4940, test_loss=0.5111, test_r2=0.4754
#     epoch  6/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.4931, train_r2=0.5069, test_loss=0.5041, test_r2=0.4826
#     epoch  7/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.4514, train_r2=0.5486, test_loss=0.4595, test_r2=0.5283
#     epoch  8/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.4525, train_r2=0.5475, test_loss=0.4624, test_r2=0.5254
#     epoch  9/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.4790, train_r2=0.5210, test_loss=0.4842, test_r2=0.5030
#     epoch 10/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.3971, train_r2=0.6029, test_loss=0.4112, test_r2=0.5780
#     epoch 11/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.4157, train_r2=0.5843, test_loss=0.4327, test_r2=0.5559
#     epoch 12/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.4190, train_r2=0.5810, test_loss=0.4281, test_r2=0.5606
#     epoch 13/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.4323, train_r2=0.5677, test_loss=0.4340, test_r2=0.5545
#     epoch 14/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.4082, train_r2=0.5918, test_loss=0.4187, test_r2=0.5702
#     epoch 15/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.4211, train_r2=0.5789, test_loss=0.4255, test_r2=0.5633
#     epoch 16/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.3853, train_r2=0.6147, test_loss=0.3910, test_r2=0.5987
#     epoch 17/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.4004, train_r2=0.5996, test_loss=0.4115, test_r2=0.5777
#     epoch 18/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.3854, train_r2=0.6146, test_loss=0.4005, test_r2=0.5889
#     epoch 19/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.4625, train_r2=0.5375, test_loss=0.4865, test_r2=0.5006
#     epoch 20/20 | wp | lr=0.015, sigma=0.08 | train_loss=0.3842, train_r2=0.6158, test_loss=0.3959, test_r2=0.5936
#
# === Run 8/39 | wp | lr=0.015, sigma=0.1 | seed=0 ===
#     epoch  1/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.8377, train_r2=0.1623, test_loss=0.8250, test_r2=0.1533
#     epoch  2/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.7957, train_r2=0.2043, test_loss=0.7816, test_r2=0.1978
#     epoch  3/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.6871, train_r2=0.3129, test_loss=0.6791, test_r2=0.3030
#     epoch  4/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.6029, train_r2=0.3971, test_loss=0.6092, test_r2=0.3747
#     epoch  5/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.5262, train_r2=0.4738, test_loss=0.5299, test_r2=0.4561
#     epoch  6/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.4890, train_r2=0.5110, test_loss=0.4986, test_r2=0.4882
#     epoch  7/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.4706, train_r2=0.5294, test_loss=0.4774, test_r2=0.5100
#     epoch  8/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.4639, train_r2=0.5361, test_loss=0.4725, test_r2=0.5150
#     epoch  9/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.4707, train_r2=0.5293, test_loss=0.4776, test_r2=0.5098
#     epoch 10/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.4128, train_r2=0.5872, test_loss=0.4239, test_r2=0.5649
#     epoch 11/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.4009, train_r2=0.5991, test_loss=0.4144, test_r2=0.5747
#     epoch 12/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.4311, train_r2=0.5689, test_loss=0.4380, test_r2=0.5505
#     epoch 13/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.4171, train_r2=0.5829, test_loss=0.4197, test_r2=0.5693
#     epoch 14/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.4115, train_r2=0.5885, test_loss=0.4197, test_r2=0.5693
#     epoch 15/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.4064, train_r2=0.5936, test_loss=0.4124, test_r2=0.5767
#     epoch 16/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.3875, train_r2=0.6125, test_loss=0.3928, test_r2=0.5968
#     epoch 17/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.3826, train_r2=0.6174, test_loss=0.3959, test_r2=0.5937
#     epoch 18/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.3859, train_r2=0.6141, test_loss=0.4003, test_r2=0.5892
#     epoch 19/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.4201, train_r2=0.5799, test_loss=0.4367, test_r2=0.5517
#     epoch 20/20 | wp | lr=0.015, sigma=0.1 | train_loss=0.3726, train_r2=0.6274, test_loss=0.3853, test_r2=0.6045
#
# === Run 9/39 | wp | lr=0.015, sigma=0.12 | seed=0 ===
#     epoch  1/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.8623, train_r2=0.1377, test_loss=0.8477, test_r2=0.1299
#     epoch  2/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.8409, train_r2=0.1591, test_loss=0.8234, test_r2=0.1549
#     epoch  3/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.7505, train_r2=0.2495, test_loss=0.7384, test_r2=0.2421
#     epoch  4/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.6624, train_r2=0.3376, test_loss=0.6633, test_r2=0.3191
#     epoch  5/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.5664, train_r2=0.4336, test_loss=0.5673, test_r2=0.4177
#     epoch  6/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.5071, train_r2=0.4929, test_loss=0.5145, test_r2=0.4719
#     epoch  7/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.4932, train_r2=0.5068, test_loss=0.4989, test_r2=0.4879
#     epoch  8/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.4781, train_r2=0.5219, test_loss=0.4857, test_r2=0.5014
#     epoch  9/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.4766, train_r2=0.5234, test_loss=0.4848, test_r2=0.5024
#     epoch 10/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.4339, train_r2=0.5661, test_loss=0.4439, test_r2=0.5443
#     epoch 11/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.4064, train_r2=0.5936, test_loss=0.4185, test_r2=0.5704
#     epoch 12/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.4497, train_r2=0.5503, test_loss=0.4547, test_r2=0.5333
#     epoch 13/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.4167, train_r2=0.5833, test_loss=0.4204, test_r2=0.5685
#     epoch 14/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.4232, train_r2=0.5768, test_loss=0.4305, test_r2=0.5581
#     epoch 15/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.4038, train_r2=0.5962, test_loss=0.4113, test_r2=0.5778
#     epoch 16/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.4032, train_r2=0.5968, test_loss=0.4080, test_r2=0.5813
#     epoch 17/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.3873, train_r2=0.6127, test_loss=0.3983, test_r2=0.5912
#     epoch 18/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.3907, train_r2=0.6093, test_loss=0.4035, test_r2=0.5858
#     epoch 19/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.4002, train_r2=0.5998, test_loss=0.4132, test_r2=0.5759
#     epoch 20/20 | wp | lr=0.015, sigma=0.12 | train_loss=0.3868, train_r2=0.6132, test_loss=0.3974, test_r2=0.5922
#   method      lr  sigma  epochs_completed  final_train_loss  final_train_r2  \
# 0     wp  0.0150   0.10                20          0.372633        0.627367
# 1     wp  0.0150   0.08                20          0.384226        0.615774
# 2     wp  0.0125   0.08                20          0.381068        0.618932
# 3     wp  0.0150   0.12                20          0.386771        0.613229
# 4     wp  0.0125   0.10                20          0.385285        0.614715
#
#    final_test_loss  final_test_r2  best_test_loss  best_test_r2  diverged  \
# 0         0.385304       0.604527        0.385304      0.604527     False
# 1         0.395947       0.593602        0.391009      0.598670     False
# 2         0.396548       0.592985        0.395700      0.593856     False
# 3         0.397353       0.592160        0.397353      0.592160     False
# 4         0.398020       0.591474        0.398020      0.591474     False
#
#    duration_sec  seed
# 0      5.075930     0
# 1      4.914123     0
# 2      5.092716     0
# 3      4.870388     0
# 4      5.022575     0
#   method     lr  sigma  epochs_completed  final_train_loss  final_train_r2  \
# 0     wp  0.015    0.1                20          0.372633        0.627367
#
#    final_test_loss  final_test_r2  best_test_loss  best_test_r2  diverged  \
# 0         0.385304       0.604527        0.385304      0.604527     False
#
#    duration_sec  seed
# 0       5.07593     0

# %%
# Run a deeper comparison on the best config per method.
# You can increase FINAL_EPOCHS if the sweep already identified a promising region.

deep_results = run_best_config_comparison(
    best_df=best_configs_df,
    data=data,
    dimensions=DIMENSIONS,
    final_epochs=FINAL_EPOCHS,
    seed=0,
    device=device,
)

display(results_table(deep_results))
plot_training_histories(deep_results)
plot_layer_output_norm_histories(deep_results)
plot_prediction_diagnostics(deep_results, data, DIMENSIONS, device)
# Out:
# ### Final run | bp | lr=0.1
#     epoch  1/200 | bp | lr=0.1 | train_loss=0.9832, train_r2=0.0168, test_loss=0.9604, test_r2=0.0142
#     epoch  2/200 | bp | lr=0.1 | train_loss=0.9461, train_r2=0.0539, test_loss=0.9236, test_r2=0.0521
#     epoch  3/200 | bp | lr=0.1 | train_loss=0.8280, train_r2=0.1720, test_loss=0.8150, test_r2=0.1635
#     epoch  4/200 | bp | lr=0.1 | train_loss=0.5855, train_r2=0.4145, test_loss=0.5900, test_r2=0.3944
#     epoch  5/200 | bp | lr=0.1 | train_loss=0.4670, train_r2=0.5330, test_loss=0.4796, test_r2=0.5077
#     epoch  6/200 | bp | lr=0.1 | train_loss=0.4379, train_r2=0.5621, test_loss=0.4523, test_r2=0.5357
#     epoch  7/200 | bp | lr=0.1 | train_loss=0.4225, train_r2=0.5775, test_loss=0.4365, test_r2=0.5520
#     epoch  8/200 | bp | lr=0.1 | train_loss=0.4107, train_r2=0.5893, test_loss=0.4238, test_r2=0.5650
#     epoch  9/200 | bp | lr=0.1 | train_loss=0.4066, train_r2=0.5934, test_loss=0.4194, test_r2=0.5695
#     epoch 10/200 | bp | lr=0.1 | train_loss=0.3865, train_r2=0.6135, test_loss=0.3950, test_r2=0.5945
#     epoch 11/200 | bp | lr=0.1 | train_loss=0.3728, train_r2=0.6272, test_loss=0.3811, test_r2=0.6089
#     epoch 12/200 | bp | lr=0.1 | train_loss=0.3789, train_r2=0.6211, test_loss=0.3833, test_r2=0.6066
#     epoch 13/200 | bp | lr=0.1 | train_loss=0.3563, train_r2=0.6437, test_loss=0.3626, test_r2=0.6278
#     epoch 14/200 | bp | lr=0.1 | train_loss=0.3929, train_r2=0.6071, test_loss=0.3934, test_r2=0.5962
#     epoch 15/200 | bp | lr=0.1 | train_loss=0.3448, train_r2=0.6552, test_loss=0.3491, test_r2=0.6416
#     epoch 16/200 | bp | lr=0.1 | train_loss=0.3367, train_r2=0.6633, test_loss=0.3396, test_r2=0.6515
#     epoch 17/200 | bp | lr=0.1 | train_loss=0.3311, train_r2=0.6689, test_loss=0.3328, test_r2=0.6584
#     epoch 18/200 | bp | lr=0.1 | train_loss=0.3320, train_r2=0.6680, test_loss=0.3319, test_r2=0.6593
#     epoch 19/200 | bp | lr=0.1 | train_loss=0.3388, train_r2=0.6612, test_loss=0.3415, test_r2=0.6495
#     epoch 20/200 | bp | lr=0.1 | train_loss=0.3400, train_r2=0.6600, test_loss=0.3380, test_r2=0.6531
#     epoch 21/200 | bp | lr=0.1 | train_loss=0.3254, train_r2=0.6746, test_loss=0.3268, test_r2=0.6646
#     epoch 22/200 | bp | lr=0.1 | train_loss=0.3171, train_r2=0.6829, test_loss=0.3168, test_r2=0.6748
#     epoch 23/200 | bp | lr=0.1 | train_loss=0.3192, train_r2=0.6808, test_loss=0.3176, test_r2=0.6740
#     epoch 24/200 | bp | lr=0.1 | train_loss=0.3345, train_r2=0.6655, test_loss=0.3315, test_r2=0.6597
#     epoch 25/200 | bp | lr=0.1 | train_loss=0.3171, train_r2=0.6829, test_loss=0.3149, test_r2=0.6768
#     epoch 26/200 | bp | lr=0.1 | train_loss=0.3442, train_r2=0.6558, test_loss=0.3465, test_r2=0.6444
#     epoch 27/200 | bp | lr=0.1 | train_loss=0.3102, train_r2=0.6898, test_loss=0.3096, test_r2=0.6822
#     epoch 28/200 | bp | lr=0.1 | train_loss=0.3109, train_r2=0.6891, test_loss=0.3088, test_r2=0.6831
#     epoch 29/200 | bp | lr=0.1 | train_loss=0.3064, train_r2=0.6936, test_loss=0.3054, test_r2=0.6865
#     epoch 30/200 | bp | lr=0.1 | train_loss=0.3575, train_r2=0.6425, test_loss=0.3528, test_r2=0.6379
#     epoch 31/200 | bp | lr=0.1 | train_loss=0.3045, train_r2=0.6955, test_loss=0.3020, test_r2=0.6900
#     epoch 32/200 | bp | lr=0.1 | train_loss=0.3240, train_r2=0.6760, test_loss=0.3245, test_r2=0.6669
#     epoch 33/200 | bp | lr=0.1 | train_loss=0.3013, train_r2=0.6987, test_loss=0.2998, test_r2=0.6923
#     epoch 34/200 | bp | lr=0.1 | train_loss=0.3000, train_r2=0.7000, test_loss=0.2979, test_r2=0.6943
#     epoch 35/200 | bp | lr=0.1 | train_loss=0.2996, train_r2=0.7004, test_loss=0.2978, test_r2=0.6943
#     epoch 36/200 | bp | lr=0.1 | train_loss=0.3010, train_r2=0.6990, test_loss=0.2996, test_r2=0.6925
#     epoch 37/200 | bp | lr=0.1 | train_loss=0.3080, train_r2=0.6920, test_loss=0.3070, test_r2=0.6848
#     epoch 38/200 | bp | lr=0.1 | train_loss=0.3079, train_r2=0.6921, test_loss=0.3069, test_r2=0.6850
#     epoch 39/200 | bp | lr=0.1 | train_loss=0.2967, train_r2=0.7033, test_loss=0.2939, test_r2=0.6983
#     epoch 40/200 | bp | lr=0.1 | train_loss=0.3211, train_r2=0.6789, test_loss=0.3170, test_r2=0.6747
#     epoch 41/200 | bp | lr=0.1 | train_loss=0.3297, train_r2=0.6703, test_loss=0.3298, test_r2=0.6615
#     epoch 42/200 | bp | lr=0.1 | train_loss=0.2984, train_r2=0.7016, test_loss=0.2951, test_r2=0.6971
#     epoch 43/200 | bp | lr=0.1 | train_loss=0.2929, train_r2=0.7071, test_loss=0.2903, test_r2=0.7021
#     epoch 44/200 | bp | lr=0.1 | train_loss=0.3095, train_r2=0.6905, test_loss=0.3054, test_r2=0.6866
#     epoch 45/200 | bp | lr=0.1 | train_loss=0.3009, train_r2=0.6991, test_loss=0.2976, test_r2=0.6945
#     epoch 46/200 | bp | lr=0.1 | train_loss=0.2927, train_r2=0.7073, test_loss=0.2907, test_r2=0.7017
#     epoch 47/200 | bp | lr=0.1 | train_loss=0.2916, train_r2=0.7084, test_loss=0.2884, test_r2=0.7040
#     epoch 48/200 | bp | lr=0.1 | train_loss=0.2974, train_r2=0.7026, test_loss=0.2939, test_r2=0.6984
#     epoch 49/200 | bp | lr=0.1 | train_loss=0.3088, train_r2=0.6912, test_loss=0.3049, test_r2=0.6870
#     epoch 50/200 | bp | lr=0.1 | train_loss=0.2920, train_r2=0.7080, test_loss=0.2899, test_r2=0.7024
#     epoch 51/200 | bp | lr=0.1 | train_loss=0.2893, train_r2=0.7107, test_loss=0.2860, test_r2=0.7064
#     epoch 52/200 | bp | lr=0.1 | train_loss=0.2901, train_r2=0.7099, test_loss=0.2867, test_r2=0.7057
#     epoch 53/200 | bp | lr=0.1 | train_loss=0.2939, train_r2=0.7061, test_loss=0.2919, test_r2=0.7004
#     epoch 54/200 | bp | lr=0.1 | train_loss=0.2918, train_r2=0.7082, test_loss=0.2896, test_r2=0.7027
#     epoch 55/200 | bp | lr=0.1 | train_loss=0.2952, train_r2=0.7048, test_loss=0.2913, test_r2=0.7010
#     epoch 56/200 | bp | lr=0.1 | train_loss=0.2894, train_r2=0.7106, test_loss=0.2858, test_r2=0.7067
#     epoch 57/200 | bp | lr=0.1 | train_loss=0.2875, train_r2=0.7125, test_loss=0.2849, test_r2=0.7076
#     epoch 58/200 | bp | lr=0.1 | train_loss=0.2909, train_r2=0.7091, test_loss=0.2888, test_r2=0.7035
#     epoch 59/200 | bp | lr=0.1 | train_loss=0.2859, train_r2=0.7141, test_loss=0.2829, test_r2=0.7096
#     epoch 60/200 | bp | lr=0.1 | train_loss=0.2939, train_r2=0.7061, test_loss=0.2899, test_r2=0.7025
#     epoch 61/200 | bp | lr=0.1 | train_loss=0.2997, train_r2=0.7003, test_loss=0.2958, test_r2=0.6964
#     epoch 62/200 | bp | lr=0.1 | train_loss=0.2871, train_r2=0.7129, test_loss=0.2845, test_r2=0.7080
#     epoch 63/200 | bp | lr=0.1 | train_loss=0.3040, train_r2=0.6960, test_loss=0.2999, test_r2=0.6922
#     epoch 64/200 | bp | lr=0.1 | train_loss=0.2866, train_r2=0.7134, test_loss=0.2842, test_r2=0.7083
#     epoch 65/200 | bp | lr=0.1 | train_loss=0.2849, train_r2=0.7151, test_loss=0.2824, test_r2=0.7102
#     epoch 66/200 | bp | lr=0.1 | train_loss=0.2840, train_r2=0.7160, test_loss=0.2810, test_r2=0.7115
#     epoch 67/200 | bp | lr=0.1 | train_loss=0.2897, train_r2=0.7103, test_loss=0.2878, test_r2=0.7046
#     epoch 68/200 | bp | lr=0.1 | train_loss=0.3247, train_r2=0.6753, test_loss=0.3240, test_r2=0.6674
#     epoch 69/200 | bp | lr=0.1 | train_loss=0.3196, train_r2=0.6804, test_loss=0.3195, test_r2=0.6720
#     epoch 70/200 | bp | lr=0.1 | train_loss=0.3005, train_r2=0.6995, test_loss=0.2965, test_r2=0.6957
#     epoch 71/200 | bp | lr=0.1 | train_loss=0.3393, train_r2=0.6607, test_loss=0.3345, test_r2=0.6567
#     epoch 72/200 | bp | lr=0.1 | train_loss=0.2878, train_r2=0.7122, test_loss=0.2857, test_r2=0.7067
#     epoch 73/200 | bp | lr=0.1 | train_loss=0.2925, train_r2=0.7075, test_loss=0.2908, test_r2=0.7015
#     epoch 74/200 | bp | lr=0.1 | train_loss=0.3248, train_r2=0.6752, test_loss=0.3247, test_r2=0.6667
#     epoch 75/200 | bp | lr=0.1 | train_loss=0.2839, train_r2=0.7161, test_loss=0.2817, test_r2=0.7109
#     epoch 76/200 | bp | lr=0.1 | train_loss=0.2931, train_r2=0.7069, test_loss=0.2909, test_r2=0.7014
#     epoch 77/200 | bp | lr=0.1 | train_loss=0.2820, train_r2=0.7180, test_loss=0.2795, test_r2=0.7132
#     epoch 78/200 | bp | lr=0.1 | train_loss=0.2817, train_r2=0.7183, test_loss=0.2791, test_r2=0.7136
#     epoch 79/200 | bp | lr=0.1 | train_loss=0.2833, train_r2=0.7167, test_loss=0.2808, test_r2=0.7118
#     epoch 80/200 | bp | lr=0.1 | train_loss=0.2822, train_r2=0.7178, test_loss=0.2798, test_r2=0.7128
#     epoch 81/200 | bp | lr=0.1 | train_loss=0.2816, train_r2=0.7184, test_loss=0.2794, test_r2=0.7133
#     epoch 82/200 | bp | lr=0.1 | train_loss=0.2995, train_r2=0.7005, test_loss=0.2984, test_r2=0.6937
#     epoch 83/200 | bp | lr=0.1 | train_loss=0.3400, train_r2=0.6600, test_loss=0.3401, test_r2=0.6509
#     epoch 84/200 | bp | lr=0.1 | train_loss=0.2805, train_r2=0.7195, test_loss=0.2779, test_r2=0.7148
#     epoch 85/200 | bp | lr=0.1 | train_loss=0.2809, train_r2=0.7191, test_loss=0.2786, test_r2=0.7140
#     epoch 86/200 | bp | lr=0.1 | train_loss=0.2807, train_r2=0.7193, test_loss=0.2782, test_r2=0.7144
#     epoch 87/200 | bp | lr=0.1 | train_loss=0.2800, train_r2=0.7200, test_loss=0.2771, test_r2=0.7156
#     epoch 88/200 | bp | lr=0.1 | train_loss=0.2828, train_r2=0.7172, test_loss=0.2808, test_r2=0.7118
#     epoch 89/200 | bp | lr=0.1 | train_loss=0.2893, train_r2=0.7107, test_loss=0.2878, test_r2=0.7046
#     epoch 90/200 | bp | lr=0.1 | train_loss=0.2869, train_r2=0.7131, test_loss=0.2834, test_r2=0.7091
#     epoch 91/200 | bp | lr=0.1 | train_loss=0.2794, train_r2=0.7206, test_loss=0.2768, test_r2=0.7159
#     epoch 92/200 | bp | lr=0.1 | train_loss=0.2800, train_r2=0.7200, test_loss=0.2779, test_r2=0.7147
#     epoch 93/200 | bp | lr=0.1 | train_loss=0.2789, train_r2=0.7211, test_loss=0.2765, test_r2=0.7162
#     epoch 94/200 | bp | lr=0.1 | train_loss=0.2883, train_r2=0.7117, test_loss=0.2846, test_r2=0.7079
#     epoch 95/200 | bp | lr=0.1 | train_loss=0.2809, train_r2=0.7191, test_loss=0.2789, test_r2=0.7137
#     epoch 96/200 | bp | lr=0.1 | train_loss=0.2796, train_r2=0.7204, test_loss=0.2776, test_r2=0.7150
#     epoch 97/200 | bp | lr=0.1 | train_loss=0.2785, train_r2=0.7215, test_loss=0.2760, test_r2=0.7168
#     epoch 98/200 | bp | lr=0.1 | train_loss=0.2807, train_r2=0.7193, test_loss=0.2793, test_r2=0.7134
#     epoch 99/200 | bp | lr=0.1 | train_loss=0.2819, train_r2=0.7181, test_loss=0.2792, test_r2=0.7134
#     epoch 100/200 | bp | lr=0.1 | train_loss=0.2778, train_r2=0.7222, test_loss=0.2753, test_r2=0.7175
#     epoch 101/200 | bp | lr=0.1 | train_loss=0.3014, train_r2=0.6986, test_loss=0.3005, test_r2=0.6916
#     epoch 102/200 | bp | lr=0.1 | train_loss=0.2787, train_r2=0.7213, test_loss=0.2771, test_r2=0.7156
#     epoch 103/200 | bp | lr=0.1 | train_loss=0.2825, train_r2=0.7175, test_loss=0.2791, test_r2=0.7136
#     epoch 104/200 | bp | lr=0.1 | train_loss=0.2788, train_r2=0.7212, test_loss=0.2760, test_r2=0.7168
#     epoch 105/200 | bp | lr=0.1 | train_loss=0.2768, train_r2=0.7232, test_loss=0.2746, test_r2=0.7182
#     epoch 106/200 | bp | lr=0.1 | train_loss=0.2767, train_r2=0.7233, test_loss=0.2742, test_r2=0.7185
#     epoch 107/200 | bp | lr=0.1 | train_loss=0.2905, train_r2=0.7095, test_loss=0.2896, test_r2=0.7027
#     epoch 108/200 | bp | lr=0.1 | train_loss=0.2778, train_r2=0.7222, test_loss=0.2751, test_r2=0.7176
#     epoch 109/200 | bp | lr=0.1 | train_loss=0.2775, train_r2=0.7225, test_loss=0.2751, test_r2=0.7177
#     epoch 110/200 | bp | lr=0.1 | train_loss=0.2796, train_r2=0.7204, test_loss=0.2780, test_r2=0.7147
#     epoch 111/200 | bp | lr=0.1 | train_loss=0.2851, train_r2=0.7149, test_loss=0.2843, test_r2=0.7082
#     epoch 112/200 | bp | lr=0.1 | train_loss=0.2782, train_r2=0.7218, test_loss=0.2769, test_r2=0.7158
#     epoch 113/200 | bp | lr=0.1 | train_loss=0.2822, train_r2=0.7178, test_loss=0.2791, test_r2=0.7135
#     epoch 114/200 | bp | lr=0.1 | train_loss=0.2801, train_r2=0.7199, test_loss=0.2791, test_r2=0.7135
#     epoch 115/200 | bp | lr=0.1 | train_loss=0.3004, train_r2=0.6996, test_loss=0.2967, test_r2=0.6955
#     epoch 116/200 | bp | lr=0.1 | train_loss=0.2830, train_r2=0.7170, test_loss=0.2797, test_r2=0.7129
#     epoch 117/200 | bp | lr=0.1 | train_loss=0.2747, train_r2=0.7253, test_loss=0.2728, test_r2=0.7200
#     epoch 118/200 | bp | lr=0.1 | train_loss=0.3052, train_r2=0.6948, test_loss=0.3015, test_r2=0.6905
#     epoch 119/200 | bp | lr=0.1 | train_loss=0.2741, train_r2=0.7259, test_loss=0.2719, test_r2=0.7209
#     epoch 120/200 | bp | lr=0.1 | train_loss=0.2772, train_r2=0.7228, test_loss=0.2758, test_r2=0.7169
#     epoch 121/200 | bp | lr=0.1 | train_loss=0.2821, train_r2=0.7179, test_loss=0.2815, test_r2=0.7111
#     epoch 122/200 | bp | lr=0.1 | train_loss=0.2734, train_r2=0.7266, test_loss=0.2709, test_r2=0.7220
#     epoch 123/200 | bp | lr=0.1 | train_loss=0.2829, train_r2=0.7171, test_loss=0.2821, test_r2=0.7104
#     epoch 124/200 | bp | lr=0.1 | train_loss=0.2810, train_r2=0.7190, test_loss=0.2777, test_r2=0.7150
#     epoch 125/200 | bp | lr=0.1 | train_loss=0.2781, train_r2=0.7219, test_loss=0.2774, test_r2=0.7152
#     epoch 126/200 | bp | lr=0.1 | train_loss=0.3016, train_r2=0.6984, test_loss=0.2976, test_r2=0.6945
#     epoch 127/200 | bp | lr=0.1 | train_loss=0.2737, train_r2=0.7263, test_loss=0.2722, test_r2=0.7206
#     epoch 128/200 | bp | lr=0.1 | train_loss=0.2791, train_r2=0.7209, test_loss=0.2788, test_r2=0.7138
#     epoch 129/200 | bp | lr=0.1 | train_loss=0.2737, train_r2=0.7263, test_loss=0.2723, test_r2=0.7205
#     epoch 130/200 | bp | lr=0.1 | train_loss=0.2802, train_r2=0.7198, test_loss=0.2775, test_r2=0.7152
#     epoch 131/200 | bp | lr=0.1 | train_loss=0.2771, train_r2=0.7229, test_loss=0.2763, test_r2=0.7164
#     epoch 132/200 | bp | lr=0.1 | train_loss=0.2762, train_r2=0.7238, test_loss=0.2730, test_r2=0.7197
#     epoch 133/200 | bp | lr=0.1 | train_loss=0.2721, train_r2=0.7279, test_loss=0.2700, test_r2=0.7229
#     epoch 134/200 | bp | lr=0.1 | train_loss=0.2858, train_r2=0.7142, test_loss=0.2857, test_r2=0.7067
#     epoch 135/200 | bp | lr=0.1 | train_loss=0.2892, train_r2=0.7108, test_loss=0.2895, test_r2=0.7028
#     epoch 136/200 | bp | lr=0.1 | train_loss=0.2750, train_r2=0.7250, test_loss=0.2721, test_r2=0.7207
#     epoch 137/200 | bp | lr=0.1 | train_loss=0.2792, train_r2=0.7208, test_loss=0.2788, test_r2=0.7138
#     epoch 138/200 | bp | lr=0.1 | train_loss=0.2719, train_r2=0.7281, test_loss=0.2711, test_r2=0.7218
#     epoch 139/200 | bp | lr=0.1 | train_loss=0.2710, train_r2=0.7290, test_loss=0.2688, test_r2=0.7241
#     epoch 140/200 | bp | lr=0.1 | train_loss=0.2702, train_r2=0.7298, test_loss=0.2685, test_r2=0.7244
#     epoch 141/200 | bp | lr=0.1 | train_loss=0.2737, train_r2=0.7263, test_loss=0.2734, test_r2=0.7194
#     epoch 142/200 | bp | lr=0.1 | train_loss=0.2693, train_r2=0.7307, test_loss=0.2677, test_r2=0.7252
#     epoch 143/200 | bp | lr=0.1 | train_loss=0.2783, train_r2=0.7217, test_loss=0.2785, test_r2=0.7142
#     epoch 144/200 | bp | lr=0.1 | train_loss=0.2693, train_r2=0.7307, test_loss=0.2682, test_r2=0.7247
#     epoch 145/200 | bp | lr=0.1 | train_loss=0.2820, train_r2=0.7180, test_loss=0.2792, test_r2=0.7135
#     epoch 146/200 | bp | lr=0.1 | train_loss=0.2685, train_r2=0.7315, test_loss=0.2676, test_r2=0.7254
#     epoch 147/200 | bp | lr=0.1 | train_loss=0.2693, train_r2=0.7307, test_loss=0.2675, test_r2=0.7254
#     epoch 148/200 | bp | lr=0.1 | train_loss=0.2738, train_r2=0.7262, test_loss=0.2714, test_r2=0.7215
#     epoch 149/200 | bp | lr=0.1 | train_loss=0.2687, train_r2=0.7313, test_loss=0.2669, test_r2=0.7261
#     epoch 150/200 | bp | lr=0.1 | train_loss=0.2708, train_r2=0.7292, test_loss=0.2690, test_r2=0.7239
#     epoch 151/200 | bp | lr=0.1 | train_loss=0.2683, train_r2=0.7317, test_loss=0.2664, test_r2=0.7265
#     epoch 152/200 | bp | lr=0.1 | train_loss=0.2684, train_r2=0.7316, test_loss=0.2679, test_r2=0.7250
#     epoch 153/200 | bp | lr=0.1 | train_loss=0.2842, train_r2=0.7158, test_loss=0.2852, test_r2=0.7072
#     epoch 154/200 | bp | lr=0.1 | train_loss=0.2684, train_r2=0.7316, test_loss=0.2666, test_r2=0.7263
#     epoch 155/200 | bp | lr=0.1 | train_loss=0.2706, train_r2=0.7294, test_loss=0.2693, test_r2=0.7236
#     epoch 156/200 | bp | lr=0.1 | train_loss=0.2907, train_r2=0.7093, test_loss=0.2879, test_r2=0.7045
#     epoch 157/200 | bp | lr=0.1 | train_loss=0.2664, train_r2=0.7336, test_loss=0.2658, test_r2=0.7272
#     epoch 158/200 | bp | lr=0.1 | train_loss=0.2760, train_r2=0.7240, test_loss=0.2736, test_r2=0.7192
#     epoch 159/200 | bp | lr=0.1 | train_loss=0.2815, train_r2=0.7185, test_loss=0.2784, test_r2=0.7142
#     epoch 160/200 | bp | lr=0.1 | train_loss=0.2666, train_r2=0.7334, test_loss=0.2663, test_r2=0.7267
#     epoch 161/200 | bp | lr=0.1 | train_loss=0.2654, train_r2=0.7346, test_loss=0.2647, test_r2=0.7283
#     epoch 162/200 | bp | lr=0.1 | train_loss=0.2654, train_r2=0.7346, test_loss=0.2650, test_r2=0.7280
#     epoch 163/200 | bp | lr=0.1 | train_loss=0.2650, train_r2=0.7350, test_loss=0.2645, test_r2=0.7285
#     epoch 164/200 | bp | lr=0.1 | train_loss=0.2677, train_r2=0.7323, test_loss=0.2676, test_r2=0.7253
#     epoch 165/200 | bp | lr=0.1 | train_loss=0.2686, train_r2=0.7314, test_loss=0.2669, test_r2=0.7261
#     epoch 166/200 | bp | lr=0.1 | train_loss=0.2831, train_r2=0.7169, test_loss=0.2805, test_r2=0.7121
#     epoch 167/200 | bp | lr=0.1 | train_loss=0.2931, train_r2=0.7069, test_loss=0.2959, test_r2=0.6963
#     epoch 168/200 | bp | lr=0.1 | train_loss=0.2661, train_r2=0.7339, test_loss=0.2645, test_r2=0.7285
#     epoch 169/200 | bp | lr=0.1 | train_loss=0.2642, train_r2=0.7358, test_loss=0.2635, test_r2=0.7295
#     epoch 170/200 | bp | lr=0.1 | train_loss=0.3095, train_r2=0.6905, test_loss=0.3120, test_r2=0.6797
#     epoch 171/200 | bp | lr=0.1 | train_loss=0.2734, train_r2=0.7266, test_loss=0.2746, test_r2=0.7181
#     epoch 172/200 | bp | lr=0.1 | train_loss=0.2633, train_r2=0.7367, test_loss=0.2634, test_r2=0.7297
#     epoch 173/200 | bp | lr=0.1 | train_loss=0.2635, train_r2=0.7365, test_loss=0.2633, test_r2=0.7298
#     epoch 174/200 | bp | lr=0.1 | train_loss=0.2653, train_r2=0.7347, test_loss=0.2642, test_r2=0.7288
#     epoch 175/200 | bp | lr=0.1 | train_loss=0.2745, train_r2=0.7255, test_loss=0.2726, test_r2=0.7203
#     epoch 176/200 | bp | lr=0.1 | train_loss=0.2645, train_r2=0.7355, test_loss=0.2641, test_r2=0.7289
#     epoch 177/200 | bp | lr=0.1 | train_loss=0.2628, train_r2=0.7372, test_loss=0.2625, test_r2=0.7306
#     epoch 178/200 | bp | lr=0.1 | train_loss=0.2652, train_r2=0.7348, test_loss=0.2640, test_r2=0.7290
#     epoch 179/200 | bp | lr=0.1 | train_loss=0.2683, train_r2=0.7317, test_loss=0.2670, test_r2=0.7259
#     epoch 180/200 | bp | lr=0.1 | train_loss=0.2655, train_r2=0.7345, test_loss=0.2645, test_r2=0.7285
#     epoch 181/200 | bp | lr=0.1 | train_loss=0.2760, train_r2=0.7240, test_loss=0.2785, test_r2=0.7142
#     epoch 182/200 | bp | lr=0.1 | train_loss=0.2745, train_r2=0.7255, test_loss=0.2765, test_r2=0.7162
#     epoch 183/200 | bp | lr=0.1 | train_loss=0.2625, train_r2=0.7375, test_loss=0.2624, test_r2=0.7307
#     epoch 184/200 | bp | lr=0.1 | train_loss=0.2616, train_r2=0.7384, test_loss=0.2625, test_r2=0.7306
#     epoch 185/200 | bp | lr=0.1 | train_loss=0.2660, train_r2=0.7340, test_loss=0.2676, test_r2=0.7254
#     epoch 186/200 | bp | lr=0.1 | train_loss=0.2665, train_r2=0.7335, test_loss=0.2678, test_r2=0.7251
#     epoch 187/200 | bp | lr=0.1 | train_loss=0.2651, train_r2=0.7349, test_loss=0.2651, test_r2=0.7279
#     epoch 188/200 | bp | lr=0.1 | train_loss=0.2688, train_r2=0.7312, test_loss=0.2681, test_r2=0.7248
#     epoch 189/200 | bp | lr=0.1 | train_loss=0.2692, train_r2=0.7308, test_loss=0.2685, test_r2=0.7244
#     epoch 190/200 | bp | lr=0.1 | train_loss=0.2602, train_r2=0.7398, test_loss=0.2601, test_r2=0.7330
#     epoch 191/200 | bp | lr=0.1 | train_loss=0.2612, train_r2=0.7388, test_loss=0.2624, test_r2=0.7307
#     epoch 192/200 | bp | lr=0.1 | train_loss=0.2597, train_r2=0.7403, test_loss=0.2605, test_r2=0.7326
#     epoch 193/200 | bp | lr=0.1 | train_loss=0.2600, train_r2=0.7400, test_loss=0.2599, test_r2=0.7333
#     epoch 194/200 | bp | lr=0.1 | train_loss=0.2670, train_r2=0.7330, test_loss=0.2689, test_r2=0.7240
#     epoch 195/200 | bp | lr=0.1 | train_loss=0.2600, train_r2=0.7400, test_loss=0.2600, test_r2=0.7332
#     epoch 196/200 | bp | lr=0.1 | train_loss=0.2678, train_r2=0.7322, test_loss=0.2664, test_r2=0.7265
#     epoch 197/200 | bp | lr=0.1 | train_loss=0.2634, train_r2=0.7366, test_loss=0.2636, test_r2=0.7294
#     epoch 198/200 | bp | lr=0.1 | train_loss=0.2675, train_r2=0.7325, test_loss=0.2700, test_r2=0.7228
#     epoch 199/200 | bp | lr=0.1 | train_loss=0.2765, train_r2=0.7235, test_loss=0.2793, test_r2=0.7133
#     epoch 200/200 | bp | lr=0.1 | train_loss=0.2605, train_r2=0.7395, test_loss=0.2609, test_r2=0.7322
# ### Final run | np | lr=0.02, sigma=0.12
#     epoch  1/200 | np | lr=0.02, sigma=0.12 | train_loss=1.0345, train_r2=-0.0345, test_loss=1.0183, test_r2=-0.0452
#     epoch  2/200 | np | lr=0.02, sigma=0.12 | train_loss=0.9704, train_r2=0.0296, test_loss=0.9496, test_r2=0.0253
#     epoch  3/200 | np | lr=0.02, sigma=0.12 | train_loss=0.9453, train_r2=0.0547, test_loss=0.9225, test_r2=0.0532
#     epoch  4/200 | np | lr=0.02, sigma=0.12 | train_loss=0.9119, train_r2=0.0881, test_loss=0.8934, test_r2=0.0831
#     epoch  5/200 | np | lr=0.02, sigma=0.12 | train_loss=0.8739, train_r2=0.1261, test_loss=0.8558, test_r2=0.1216
#     epoch  6/200 | np | lr=0.02, sigma=0.12 | train_loss=0.8647, train_r2=0.1353, test_loss=0.8563, test_r2=0.1211
#     epoch  7/200 | np | lr=0.02, sigma=0.12 | train_loss=0.7491, train_r2=0.2509, test_loss=0.7396, test_r2=0.2409
#     epoch  8/200 | np | lr=0.02, sigma=0.12 | train_loss=0.6599, train_r2=0.3401, test_loss=0.6582, test_r2=0.3245
#     epoch  9/200 | np | lr=0.02, sigma=0.12 | train_loss=0.5946, train_r2=0.4054, test_loss=0.5985, test_r2=0.3857
#     epoch 10/200 | np | lr=0.02, sigma=0.12 | train_loss=0.5402, train_r2=0.4598, test_loss=0.5493, test_r2=0.4362
#     epoch 11/200 | np | lr=0.02, sigma=0.12 | train_loss=0.5247, train_r2=0.4753, test_loss=0.5347, test_r2=0.4512
#     epoch 12/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4847, train_r2=0.5153, test_loss=0.4996, test_r2=0.4873
#     epoch 13/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4761, train_r2=0.5239, test_loss=0.4927, test_r2=0.4943
#     epoch 14/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4596, train_r2=0.5404, test_loss=0.4783, test_r2=0.5091
#     epoch 15/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4534, train_r2=0.5466, test_loss=0.4711, test_r2=0.5165
#     epoch 16/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4509, train_r2=0.5491, test_loss=0.4678, test_r2=0.5199
#     epoch 17/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4475, train_r2=0.5525, test_loss=0.4677, test_r2=0.5200
#     epoch 18/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4482, train_r2=0.5518, test_loss=0.4639, test_r2=0.5239
#     epoch 19/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4356, train_r2=0.5644, test_loss=0.4535, test_r2=0.5345
#     epoch 20/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4420, train_r2=0.5580, test_loss=0.4597, test_r2=0.5282
#     epoch 21/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4776, train_r2=0.5224, test_loss=0.4915, test_r2=0.4955
#     epoch 22/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4342, train_r2=0.5658, test_loss=0.4523, test_r2=0.5358
#     epoch 23/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4331, train_r2=0.5669, test_loss=0.4492, test_r2=0.5389
#     epoch 24/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4297, train_r2=0.5703, test_loss=0.4464, test_r2=0.5418
#     epoch 25/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4324, train_r2=0.5676, test_loss=0.4483, test_r2=0.5398
#     epoch 26/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4295, train_r2=0.5705, test_loss=0.4477, test_r2=0.5404
#     epoch 27/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4235, train_r2=0.5765, test_loss=0.4405, test_r2=0.5478
#     epoch 28/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4589, train_r2=0.5411, test_loss=0.4719, test_r2=0.5156
#     epoch 29/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4252, train_r2=0.5748, test_loss=0.4409, test_r2=0.5474
#     epoch 30/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4438, train_r2=0.5562, test_loss=0.4573, test_r2=0.5307
#     epoch 31/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4263, train_r2=0.5737, test_loss=0.4397, test_r2=0.5487
#     epoch 32/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4226, train_r2=0.5774, test_loss=0.4367, test_r2=0.5518
#     epoch 33/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4207, train_r2=0.5793, test_loss=0.4367, test_r2=0.5517
#     epoch 34/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4137, train_r2=0.5863, test_loss=0.4281, test_r2=0.5606
#     epoch 35/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4232, train_r2=0.5768, test_loss=0.4362, test_r2=0.5523
#     epoch 36/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4110, train_r2=0.5890, test_loss=0.4240, test_r2=0.5648
#     epoch 37/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4229, train_r2=0.5771, test_loss=0.4336, test_r2=0.5549
#     epoch 38/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4160, train_r2=0.5840, test_loss=0.4259, test_r2=0.5629
#     epoch 39/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4271, train_r2=0.5729, test_loss=0.4363, test_r2=0.5521
#     epoch 40/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4136, train_r2=0.5864, test_loss=0.4249, test_r2=0.5639
#     epoch 41/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4039, train_r2=0.5961, test_loss=0.4175, test_r2=0.5715
#     epoch 42/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4039, train_r2=0.5961, test_loss=0.4155, test_r2=0.5736
#     epoch 43/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4011, train_r2=0.5989, test_loss=0.4128, test_r2=0.5763
#     epoch 44/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4182, train_r2=0.5818, test_loss=0.4277, test_r2=0.5610
#     epoch 45/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3995, train_r2=0.6005, test_loss=0.4104, test_r2=0.5788
#     epoch 46/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4124, train_r2=0.5876, test_loss=0.4221, test_r2=0.5668
#     epoch 47/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4013, train_r2=0.5987, test_loss=0.4125, test_r2=0.5766
#     epoch 48/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3981, train_r2=0.6019, test_loss=0.4104, test_r2=0.5787
#     epoch 49/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3986, train_r2=0.6014, test_loss=0.4116, test_r2=0.5775
#     epoch 50/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3958, train_r2=0.6042, test_loss=0.4077, test_r2=0.5815
#     epoch 51/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4031, train_r2=0.5969, test_loss=0.4132, test_r2=0.5758
#     epoch 52/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3973, train_r2=0.6027, test_loss=0.4078, test_r2=0.5814
#     epoch 53/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3904, train_r2=0.6096, test_loss=0.4035, test_r2=0.5858
#     epoch 54/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3919, train_r2=0.6081, test_loss=0.4033, test_r2=0.5860
#     epoch 55/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3981, train_r2=0.6019, test_loss=0.4083, test_r2=0.5809
#     epoch 56/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3919, train_r2=0.6081, test_loss=0.4027, test_r2=0.5867
#     epoch 57/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4015, train_r2=0.5985, test_loss=0.4121, test_r2=0.5771
#     epoch 58/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3943, train_r2=0.6057, test_loss=0.4067, test_r2=0.5826
#     epoch 59/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3908, train_r2=0.6092, test_loss=0.4030, test_r2=0.5863
#     epoch 60/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3861, train_r2=0.6139, test_loss=0.3996, test_r2=0.5898
#     epoch 61/200 | np | lr=0.02, sigma=0.12 | train_loss=0.4078, train_r2=0.5922, test_loss=0.4195, test_r2=0.5694
#     epoch 62/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3961, train_r2=0.6039, test_loss=0.4069, test_r2=0.5824
#     epoch 63/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3854, train_r2=0.6146, test_loss=0.3966, test_r2=0.5929
#     epoch 64/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3833, train_r2=0.6167, test_loss=0.3944, test_r2=0.5952
#     epoch 65/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3894, train_r2=0.6106, test_loss=0.3997, test_r2=0.5897
#     epoch 66/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3848, train_r2=0.6152, test_loss=0.3958, test_r2=0.5937
#     epoch 67/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3827, train_r2=0.6173, test_loss=0.3940, test_r2=0.5956
#     epoch 68/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3767, train_r2=0.6233, test_loss=0.3878, test_r2=0.6020
#     epoch 69/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3821, train_r2=0.6179, test_loss=0.3938, test_r2=0.5958
#     epoch 70/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3795, train_r2=0.6205, test_loss=0.3886, test_r2=0.6011
#     epoch 71/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3900, train_r2=0.6100, test_loss=0.3977, test_r2=0.5918
#     epoch 72/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3850, train_r2=0.6150, test_loss=0.3923, test_r2=0.5973
#     epoch 73/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3741, train_r2=0.6259, test_loss=0.3816, test_r2=0.6084
#     epoch 74/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3725, train_r2=0.6275, test_loss=0.3798, test_r2=0.6102
#     epoch 75/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3721, train_r2=0.6279, test_loss=0.3795, test_r2=0.6105
#     epoch 76/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3716, train_r2=0.6284, test_loss=0.3807, test_r2=0.6093
#     epoch 77/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3799, train_r2=0.6201, test_loss=0.3872, test_r2=0.6026
#     epoch 78/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3747, train_r2=0.6253, test_loss=0.3818, test_r2=0.6081
#     epoch 79/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3774, train_r2=0.6226, test_loss=0.3847, test_r2=0.6051
#     epoch 80/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3712, train_r2=0.6288, test_loss=0.3804, test_r2=0.6096
#     epoch 81/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3703, train_r2=0.6297, test_loss=0.3799, test_r2=0.6101
#     epoch 82/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3739, train_r2=0.6261, test_loss=0.3816, test_r2=0.6084
#     epoch 83/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3689, train_r2=0.6311, test_loss=0.3769, test_r2=0.6132
#     epoch 84/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3841, train_r2=0.6159, test_loss=0.3901, test_r2=0.5996
#     epoch 85/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3741, train_r2=0.6259, test_loss=0.3801, test_r2=0.6099
#     epoch 86/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3750, train_r2=0.6250, test_loss=0.3813, test_r2=0.6086
#     epoch 87/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3697, train_r2=0.6303, test_loss=0.3767, test_r2=0.6134
#     epoch 88/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3675, train_r2=0.6325, test_loss=0.3751, test_r2=0.6150
#     epoch 89/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3678, train_r2=0.6322, test_loss=0.3758, test_r2=0.6143
#     epoch 90/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3798, train_r2=0.6202, test_loss=0.3857, test_r2=0.6041
#     epoch 91/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3682, train_r2=0.6318, test_loss=0.3758, test_r2=0.6143
#     epoch 92/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3708, train_r2=0.6292, test_loss=0.3768, test_r2=0.6133
#     epoch 93/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3701, train_r2=0.6299, test_loss=0.3765, test_r2=0.6135
#     epoch 94/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3704, train_r2=0.6296, test_loss=0.3760, test_r2=0.6141
#     epoch 95/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3672, train_r2=0.6328, test_loss=0.3736, test_r2=0.6165
#     epoch 96/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3664, train_r2=0.6336, test_loss=0.3720, test_r2=0.6182
#     epoch 97/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3634, train_r2=0.6366, test_loss=0.3691, test_r2=0.6212
#     epoch 98/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3641, train_r2=0.6359, test_loss=0.3708, test_r2=0.6194
#     epoch 99/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3636, train_r2=0.6364, test_loss=0.3698, test_r2=0.6204
#     epoch 100/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3650, train_r2=0.6350, test_loss=0.3713, test_r2=0.6189
#     epoch 101/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3626, train_r2=0.6374, test_loss=0.3696, test_r2=0.6207
#     epoch 102/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3653, train_r2=0.6347, test_loss=0.3718, test_r2=0.6184
#     epoch 103/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3656, train_r2=0.6344, test_loss=0.3720, test_r2=0.6182
#     epoch 104/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3605, train_r2=0.6395, test_loss=0.3683, test_r2=0.6220
#     epoch 105/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3605, train_r2=0.6395, test_loss=0.3676, test_r2=0.6227
#     epoch 106/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3618, train_r2=0.6382, test_loss=0.3674, test_r2=0.6229
#     epoch 107/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3734, train_r2=0.6266, test_loss=0.3777, test_r2=0.6123
#     epoch 108/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3557, train_r2=0.6443, test_loss=0.3610, test_r2=0.6295
#     epoch 109/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3637, train_r2=0.6363, test_loss=0.3687, test_r2=0.6215
#     epoch 110/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3754, train_r2=0.6246, test_loss=0.3787, test_r2=0.6113
#     epoch 111/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3570, train_r2=0.6430, test_loss=0.3618, test_r2=0.6287
#     epoch 112/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3586, train_r2=0.6414, test_loss=0.3632, test_r2=0.6272
#     epoch 113/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3564, train_r2=0.6436, test_loss=0.3615, test_r2=0.6290
#     epoch 114/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3588, train_r2=0.6412, test_loss=0.3628, test_r2=0.6276
#     epoch 115/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3592, train_r2=0.6408, test_loss=0.3633, test_r2=0.6271
#     epoch 116/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3562, train_r2=0.6438, test_loss=0.3614, test_r2=0.6290
#     epoch 117/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3568, train_r2=0.6432, test_loss=0.3618, test_r2=0.6286
#     epoch 118/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3692, train_r2=0.6308, test_loss=0.3724, test_r2=0.6178
#     epoch 119/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3615, train_r2=0.6385, test_loss=0.3647, test_r2=0.6256
#     epoch 120/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3509, train_r2=0.6491, test_loss=0.3554, test_r2=0.6352
#     epoch 121/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3576, train_r2=0.6424, test_loss=0.3611, test_r2=0.6294
#     epoch 122/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3619, train_r2=0.6381, test_loss=0.3661, test_r2=0.6242
#     epoch 123/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3501, train_r2=0.6499, test_loss=0.3560, test_r2=0.6346
#     epoch 124/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3531, train_r2=0.6469, test_loss=0.3600, test_r2=0.6305
#     epoch 125/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3600, train_r2=0.6400, test_loss=0.3644, test_r2=0.6260
#     epoch 126/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3584, train_r2=0.6416, test_loss=0.3636, test_r2=0.6269
#     epoch 127/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3472, train_r2=0.6528, test_loss=0.3538, test_r2=0.6368
#     epoch 128/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3479, train_r2=0.6521, test_loss=0.3545, test_r2=0.6361
#     epoch 129/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3484, train_r2=0.6516, test_loss=0.3551, test_r2=0.6355
#     epoch 130/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3481, train_r2=0.6519, test_loss=0.3549, test_r2=0.6357
#     epoch 131/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3518, train_r2=0.6482, test_loss=0.3573, test_r2=0.6333
#     epoch 132/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3514, train_r2=0.6486, test_loss=0.3573, test_r2=0.6333
#     epoch 133/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3516, train_r2=0.6484, test_loss=0.3576, test_r2=0.6329
#     epoch 134/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3476, train_r2=0.6524, test_loss=0.3545, test_r2=0.6362
#     epoch 135/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3477, train_r2=0.6523, test_loss=0.3534, test_r2=0.6372
#     epoch 136/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3455, train_r2=0.6545, test_loss=0.3512, test_r2=0.6395
#     epoch 137/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3523, train_r2=0.6477, test_loss=0.3603, test_r2=0.6302
#     epoch 138/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3454, train_r2=0.6546, test_loss=0.3511, test_r2=0.6397
#     epoch 139/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3466, train_r2=0.6534, test_loss=0.3517, test_r2=0.6390
#     epoch 140/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3441, train_r2=0.6559, test_loss=0.3492, test_r2=0.6416
#     epoch 141/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3587, train_r2=0.6413, test_loss=0.3616, test_r2=0.6288
#     epoch 142/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3520, train_r2=0.6480, test_loss=0.3557, test_r2=0.6349
#     epoch 143/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3441, train_r2=0.6559, test_loss=0.3488, test_r2=0.6420
#     epoch 144/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3485, train_r2=0.6515, test_loss=0.3518, test_r2=0.6389
#     epoch 145/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3466, train_r2=0.6534, test_loss=0.3491, test_r2=0.6417
#     epoch 146/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3503, train_r2=0.6497, test_loss=0.3521, test_r2=0.6386
#     epoch 147/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3458, train_r2=0.6542, test_loss=0.3497, test_r2=0.6411
#     epoch 148/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3581, train_r2=0.6419, test_loss=0.3601, test_r2=0.6303
#     epoch 149/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3583, train_r2=0.6417, test_loss=0.3601, test_r2=0.6304
#     epoch 150/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3515, train_r2=0.6485, test_loss=0.3540, test_r2=0.6367
#     epoch 151/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3478, train_r2=0.6522, test_loss=0.3511, test_r2=0.6397
#     epoch 152/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3424, train_r2=0.6576, test_loss=0.3465, test_r2=0.6443
#     epoch 153/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3442, train_r2=0.6558, test_loss=0.3478, test_r2=0.6430
#     epoch 154/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3398, train_r2=0.6602, test_loss=0.3434, test_r2=0.6476
#     epoch 155/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3443, train_r2=0.6557, test_loss=0.3472, test_r2=0.6436
#     epoch 156/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3404, train_r2=0.6596, test_loss=0.3436, test_r2=0.6473
#     epoch 157/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3423, train_r2=0.6577, test_loss=0.3458, test_r2=0.6451
#     epoch 158/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3365, train_r2=0.6635, test_loss=0.3405, test_r2=0.6505
#     epoch 159/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3354, train_r2=0.6646, test_loss=0.3396, test_r2=0.6515
#     epoch 160/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3352, train_r2=0.6648, test_loss=0.3389, test_r2=0.6521
#     epoch 161/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3370, train_r2=0.6630, test_loss=0.3419, test_r2=0.6491
#     epoch 162/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3360, train_r2=0.6640, test_loss=0.3413, test_r2=0.6497
#     epoch 163/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3380, train_r2=0.6620, test_loss=0.3424, test_r2=0.6486
#     epoch 164/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3386, train_r2=0.6614, test_loss=0.3427, test_r2=0.6482
#     epoch 165/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3379, train_r2=0.6621, test_loss=0.3415, test_r2=0.6495
#     epoch 166/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3341, train_r2=0.6659, test_loss=0.3385, test_r2=0.6525
#     epoch 167/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3379, train_r2=0.6621, test_loss=0.3405, test_r2=0.6505
#     epoch 168/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3321, train_r2=0.6679, test_loss=0.3361, test_r2=0.6550
#     epoch 169/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3400, train_r2=0.6600, test_loss=0.3429, test_r2=0.6481
#     epoch 170/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3400, train_r2=0.6600, test_loss=0.3428, test_r2=0.6482
#     epoch 171/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3368, train_r2=0.6632, test_loss=0.3393, test_r2=0.6517
#     epoch 172/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3389, train_r2=0.6611, test_loss=0.3409, test_r2=0.6501
#     epoch 173/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3344, train_r2=0.6656, test_loss=0.3376, test_r2=0.6535
#     epoch 174/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3346, train_r2=0.6654, test_loss=0.3376, test_r2=0.6534
#     epoch 175/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3393, train_r2=0.6607, test_loss=0.3426, test_r2=0.6483
#     epoch 176/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3381, train_r2=0.6619, test_loss=0.3428, test_r2=0.6482
#     epoch 177/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3365, train_r2=0.6635, test_loss=0.3418, test_r2=0.6492
#     epoch 178/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3391, train_r2=0.6609, test_loss=0.3433, test_r2=0.6477
#     epoch 179/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3369, train_r2=0.6631, test_loss=0.3416, test_r2=0.6494
#     epoch 180/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3388, train_r2=0.6612, test_loss=0.3436, test_r2=0.6474
#     epoch 181/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3414, train_r2=0.6586, test_loss=0.3462, test_r2=0.6447
#     epoch 182/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3352, train_r2=0.6648, test_loss=0.3400, test_r2=0.6510
#     epoch 183/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3413, train_r2=0.6587, test_loss=0.3444, test_r2=0.6465
#     epoch 184/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3352, train_r2=0.6648, test_loss=0.3396, test_r2=0.6514
#     epoch 185/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3365, train_r2=0.6635, test_loss=0.3402, test_r2=0.6508
#     epoch 186/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3400, train_r2=0.6600, test_loss=0.3438, test_r2=0.6471
#     epoch 187/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3452, train_r2=0.6548, test_loss=0.3475, test_r2=0.6434
#     epoch 188/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3314, train_r2=0.6686, test_loss=0.3350, test_r2=0.6561
#     epoch 189/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3351, train_r2=0.6649, test_loss=0.3387, test_r2=0.6524
#     epoch 190/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3338, train_r2=0.6662, test_loss=0.3374, test_r2=0.6537
#     epoch 191/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3337, train_r2=0.6663, test_loss=0.3376, test_r2=0.6535
#     epoch 192/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3360, train_r2=0.6640, test_loss=0.3390, test_r2=0.6521
#     epoch 193/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3374, train_r2=0.6626, test_loss=0.3399, test_r2=0.6511
#     epoch 194/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3353, train_r2=0.6647, test_loss=0.3377, test_r2=0.6533
#     epoch 195/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3377, train_r2=0.6623, test_loss=0.3397, test_r2=0.6514
#     epoch 196/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3411, train_r2=0.6589, test_loss=0.3425, test_r2=0.6485
#     epoch 197/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3341, train_r2=0.6659, test_loss=0.3365, test_r2=0.6546
#     epoch 198/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3345, train_r2=0.6655, test_loss=0.3373, test_r2=0.6538
#     epoch 199/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3461, train_r2=0.6539, test_loss=0.3463, test_r2=0.6445
#     epoch 200/200 | np | lr=0.02, sigma=0.12 | train_loss=0.3401, train_r2=0.6599, test_loss=0.3428, test_r2=0.6481
# ### Final run | np_fan_in | lr=0.015, sigma=0.055
#     epoch  1/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=1.0152, train_r2=-0.0152, test_loss=0.9980, test_r2=-0.0244
#     epoch  2/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.9613, train_r2=0.0387, test_loss=0.9413, test_r2=0.0339
#     epoch  3/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.9258, train_r2=0.0742, test_loss=0.9048, test_r2=0.0713
#     epoch  4/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.8831, train_r2=0.1169, test_loss=0.8668, test_r2=0.1103
#     epoch  5/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.8370, train_r2=0.1630, test_loss=0.8224, test_r2=0.1559
#     epoch  6/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.8140, train_r2=0.1860, test_loss=0.8100, test_r2=0.1686
#     epoch  7/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.7025, train_r2=0.2975, test_loss=0.6988, test_r2=0.2828
#     epoch  8/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.6319, train_r2=0.3681, test_loss=0.6345, test_r2=0.3488
#     epoch  9/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.5858, train_r2=0.4142, test_loss=0.5948, test_r2=0.3895
#     epoch 10/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.5413, train_r2=0.4587, test_loss=0.5534, test_r2=0.4320
#     epoch 11/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.5369, train_r2=0.4631, test_loss=0.5490, test_r2=0.4365
#     epoch 12/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.5065, train_r2=0.4935, test_loss=0.5225, test_r2=0.4637
#     epoch 13/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4964, train_r2=0.5036, test_loss=0.5137, test_r2=0.4727
#     epoch 14/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4918, train_r2=0.5082, test_loss=0.5106, test_r2=0.4760
#     epoch 15/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4885, train_r2=0.5115, test_loss=0.5076, test_r2=0.4790
#     epoch 16/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4720, train_r2=0.5280, test_loss=0.4897, test_r2=0.4974
#     epoch 17/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4605, train_r2=0.5395, test_loss=0.4809, test_r2=0.5064
#     epoch 18/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4573, train_r2=0.5427, test_loss=0.4760, test_r2=0.5114
#     epoch 19/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4562, train_r2=0.5438, test_loss=0.4766, test_r2=0.5108
#     epoch 20/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4535, train_r2=0.5465, test_loss=0.4734, test_r2=0.5141
#     epoch 21/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.5017, train_r2=0.4983, test_loss=0.5149, test_r2=0.4715
#     epoch 22/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4556, train_r2=0.5444, test_loss=0.4734, test_r2=0.5141
#     epoch 23/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4472, train_r2=0.5528, test_loss=0.4673, test_r2=0.5203
#     epoch 24/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4449, train_r2=0.5551, test_loss=0.4655, test_r2=0.5222
#     epoch 25/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4443, train_r2=0.5557, test_loss=0.4635, test_r2=0.5243
#     epoch 26/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4473, train_r2=0.5527, test_loss=0.4675, test_r2=0.5202
#     epoch 27/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4416, train_r2=0.5584, test_loss=0.4587, test_r2=0.5292
#     epoch 28/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4625, train_r2=0.5375, test_loss=0.4773, test_r2=0.5101
#     epoch 29/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4380, train_r2=0.5620, test_loss=0.4559, test_r2=0.5320
#     epoch 30/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4567, train_r2=0.5433, test_loss=0.4697, test_r2=0.5179
#     epoch 31/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4293, train_r2=0.5707, test_loss=0.4436, test_r2=0.5447
#     epoch 32/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4395, train_r2=0.5605, test_loss=0.4551, test_r2=0.5329
#     epoch 33/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.4321, train_r2=0.5679, test_loss=0.4480, test_r2=0.5401
#     epoch 34/200 | np_fan_in | lr=0.015, sigma=0.055 | train_loss=0.5263, train_r2=0.4737, test_loss=0.5450, test_r2=0.4406
# ...
#     epoch 73/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3954, train_r2=0.6046, test_loss=0.3948, test_r2=0.5948
#     epoch 74/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3731, train_r2=0.6269, test_loss=0.3709, test_r2=0.6193
#     epoch 75/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3480, train_r2=0.6520, test_loss=0.3482, test_r2=0.6426
#     epoch 76/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3424, train_r2=0.6576, test_loss=0.3407, test_r2=0.6503
#     epoch 77/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3422, train_r2=0.6578, test_loss=0.3434, test_r2=0.6476
#     epoch 78/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3327, train_r2=0.6673, test_loss=0.3336, test_r2=0.6576
#     epoch 79/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3430, train_r2=0.6570, test_loss=0.3418, test_r2=0.6492
#     epoch 80/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3447, train_r2=0.6553, test_loss=0.3471, test_r2=0.6437
#     epoch 81/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3479, train_r2=0.6521, test_loss=0.3522, test_r2=0.6385
#     epoch 82/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3495, train_r2=0.6505, test_loss=0.3541, test_r2=0.6365
#     epoch 83/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3399, train_r2=0.6601, test_loss=0.3437, test_r2=0.6472
#     epoch 84/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3384, train_r2=0.6616, test_loss=0.3408, test_r2=0.6502
#     epoch 85/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3361, train_r2=0.6639, test_loss=0.3401, test_r2=0.6509
#     epoch 86/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3389, train_r2=0.6611, test_loss=0.3451, test_r2=0.6458
#     epoch 87/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3475, train_r2=0.6525, test_loss=0.3562, test_r2=0.6344
#     epoch 88/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3468, train_r2=0.6532, test_loss=0.3559, test_r2=0.6347
#     epoch 89/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3356, train_r2=0.6644, test_loss=0.3401, test_r2=0.6509
#     epoch 90/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3391, train_r2=0.6609, test_loss=0.3449, test_r2=0.6460
#     epoch 91/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3331, train_r2=0.6669, test_loss=0.3385, test_r2=0.6526
#     epoch 92/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3481, train_r2=0.6519, test_loss=0.3544, test_r2=0.6362
#     epoch 93/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3428, train_r2=0.6572, test_loss=0.3497, test_r2=0.6411
#     epoch 94/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3415, train_r2=0.6585, test_loss=0.3456, test_r2=0.6452
#     epoch 95/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3462, train_r2=0.6538, test_loss=0.3466, test_r2=0.6443
#     epoch 96/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3306, train_r2=0.6694, test_loss=0.3332, test_r2=0.6580
#     epoch 97/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3260, train_r2=0.6740, test_loss=0.3298, test_r2=0.6615
#     epoch 98/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3320, train_r2=0.6680, test_loss=0.3355, test_r2=0.6556
#     epoch 99/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3273, train_r2=0.6727, test_loss=0.3318, test_r2=0.6595
#     epoch 100/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3382, train_r2=0.6618, test_loss=0.3407, test_r2=0.6503
#     epoch 101/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3344, train_r2=0.6656, test_loss=0.3392, test_r2=0.6518
#     epoch 102/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3383, train_r2=0.6617, test_loss=0.3402, test_r2=0.6508
#     epoch 103/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3307, train_r2=0.6693, test_loss=0.3353, test_r2=0.6559
#     epoch 104/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3392, train_r2=0.6608, test_loss=0.3437, test_r2=0.6472
#     epoch 105/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3348, train_r2=0.6652, test_loss=0.3374, test_r2=0.6536
#     epoch 106/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3382, train_r2=0.6618, test_loss=0.3372, test_r2=0.6539
#     epoch 107/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3356, train_r2=0.6644, test_loss=0.3382, test_r2=0.6529
#     epoch 108/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3497, train_r2=0.6503, test_loss=0.3491, test_r2=0.6417
#     epoch 109/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3401, train_r2=0.6599, test_loss=0.3401, test_r2=0.6509
#     epoch 110/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3402, train_r2=0.6598, test_loss=0.3414, test_r2=0.6496
#     epoch 111/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3474, train_r2=0.6526, test_loss=0.3487, test_r2=0.6421
#     epoch 112/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3444, train_r2=0.6556, test_loss=0.3488, test_r2=0.6420
#     epoch 113/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3427, train_r2=0.6573, test_loss=0.3444, test_r2=0.6465
#     epoch 114/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3520, train_r2=0.6480, test_loss=0.3544, test_r2=0.6363
#     epoch 115/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3444, train_r2=0.6556, test_loss=0.3482, test_r2=0.6427
#     epoch 116/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3297, train_r2=0.6703, test_loss=0.3338, test_r2=0.6574
#     epoch 117/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3303, train_r2=0.6697, test_loss=0.3301, test_r2=0.6612
#     epoch 118/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3454, train_r2=0.6546, test_loss=0.3436, test_r2=0.6474
#     epoch 119/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3312, train_r2=0.6688, test_loss=0.3311, test_r2=0.6601
#     epoch 120/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3318, train_r2=0.6682, test_loss=0.3318, test_r2=0.6595
#     epoch 121/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3414, train_r2=0.6586, test_loss=0.3390, test_r2=0.6520
#     epoch 122/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3362, train_r2=0.6638, test_loss=0.3299, test_r2=0.6614
#     epoch 123/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3439, train_r2=0.6561, test_loss=0.3389, test_r2=0.6522
#     epoch 124/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3473, train_r2=0.6527, test_loss=0.3462, test_r2=0.6446
#     epoch 125/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3368, train_r2=0.6632, test_loss=0.3319, test_r2=0.6593
#     epoch 126/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3427, train_r2=0.6573, test_loss=0.3379, test_r2=0.6532
#     epoch 127/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3411, train_r2=0.6589, test_loss=0.3375, test_r2=0.6536
#     epoch 128/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3478, train_r2=0.6522, test_loss=0.3400, test_r2=0.6511
#     epoch 129/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3491, train_r2=0.6509, test_loss=0.3452, test_r2=0.6457
#     epoch 130/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3305, train_r2=0.6695, test_loss=0.3289, test_r2=0.6625
#     epoch 131/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3479, train_r2=0.6521, test_loss=0.3442, test_r2=0.6467
#     epoch 132/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3398, train_r2=0.6602, test_loss=0.3383, test_r2=0.6528
#     epoch 133/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3407, train_r2=0.6593, test_loss=0.3406, test_r2=0.6504
#     epoch 134/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3371, train_r2=0.6629, test_loss=0.3369, test_r2=0.6542
#     epoch 135/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3352, train_r2=0.6648, test_loss=0.3354, test_r2=0.6557
#     epoch 136/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3398, train_r2=0.6602, test_loss=0.3389, test_r2=0.6521
#     epoch 137/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3354, train_r2=0.6646, test_loss=0.3335, test_r2=0.6577
#     epoch 138/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3361, train_r2=0.6639, test_loss=0.3347, test_r2=0.6564
#     epoch 139/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3367, train_r2=0.6633, test_loss=0.3374, test_r2=0.6537
#     epoch 140/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3555, train_r2=0.6445, test_loss=0.3526, test_r2=0.6381
#     epoch 141/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3349, train_r2=0.6651, test_loss=0.3342, test_r2=0.6570
#     epoch 142/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3401, train_r2=0.6599, test_loss=0.3404, test_r2=0.6506
#     epoch 143/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3388, train_r2=0.6612, test_loss=0.3404, test_r2=0.6506
#     epoch 144/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3426, train_r2=0.6574, test_loss=0.3465, test_r2=0.6444
#     epoch 145/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3407, train_r2=0.6593, test_loss=0.3454, test_r2=0.6455
#     epoch 146/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3420, train_r2=0.6580, test_loss=0.3461, test_r2=0.6448
#     epoch 147/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3450, train_r2=0.6550, test_loss=0.3520, test_r2=0.6387
#     epoch 148/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3461, train_r2=0.6539, test_loss=0.3532, test_r2=0.6375
#     epoch 149/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3428, train_r2=0.6572, test_loss=0.3485, test_r2=0.6423
#     epoch 150/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3611, train_r2=0.6389, test_loss=0.3701, test_r2=0.6202
#     epoch 151/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3484, train_r2=0.6516, test_loss=0.3589, test_r2=0.6316
#     epoch 152/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3367, train_r2=0.6633, test_loss=0.3427, test_r2=0.6483
#     epoch 153/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3370, train_r2=0.6630, test_loss=0.3407, test_r2=0.6503
#     epoch 154/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3364, train_r2=0.6636, test_loss=0.3378, test_r2=0.6533
#     epoch 155/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3371, train_r2=0.6629, test_loss=0.3408, test_r2=0.6502
#     epoch 156/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3421, train_r2=0.6579, test_loss=0.3448, test_r2=0.6461
#     epoch 157/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3413, train_r2=0.6587, test_loss=0.3428, test_r2=0.6482
#     epoch 158/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3390, train_r2=0.6610, test_loss=0.3399, test_r2=0.6512
#     epoch 159/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3446, train_r2=0.6554, test_loss=0.3431, test_r2=0.6479
#     epoch 160/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3444, train_r2=0.6556, test_loss=0.3436, test_r2=0.6473
#     epoch 161/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3376, train_r2=0.6624, test_loss=0.3357, test_r2=0.6554
#     epoch 162/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3532, train_r2=0.6468, test_loss=0.3518, test_r2=0.6389
#     epoch 163/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3380, train_r2=0.6620, test_loss=0.3367, test_r2=0.6544
#     epoch 164/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3253, train_r2=0.6747, test_loss=0.3262, test_r2=0.6651
#     epoch 165/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3285, train_r2=0.6715, test_loss=0.3281, test_r2=0.6632
#     epoch 166/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3321, train_r2=0.6679, test_loss=0.3352, test_r2=0.6560
#     epoch 167/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3331, train_r2=0.6669, test_loss=0.3359, test_r2=0.6552
#     epoch 168/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3389, train_r2=0.6611, test_loss=0.3409, test_r2=0.6501
#     epoch 169/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3408, train_r2=0.6592, test_loss=0.3435, test_r2=0.6475
#     epoch 170/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3356, train_r2=0.6644, test_loss=0.3378, test_r2=0.6533
#     epoch 171/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3374, train_r2=0.6626, test_loss=0.3415, test_r2=0.6495
#     epoch 172/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3340, train_r2=0.6660, test_loss=0.3385, test_r2=0.6525
#     epoch 173/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3427, train_r2=0.6573, test_loss=0.3463, test_r2=0.6446
#     epoch 174/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3314, train_r2=0.6686, test_loss=0.3370, test_r2=0.6541
#     epoch 175/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3419, train_r2=0.6581, test_loss=0.3466, test_r2=0.6442
#     epoch 176/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3404, train_r2=0.6596, test_loss=0.3474, test_r2=0.6434
#     epoch 177/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3259, train_r2=0.6741, test_loss=0.3290, test_r2=0.6623
#     epoch 178/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3311, train_r2=0.6689, test_loss=0.3337, test_r2=0.6575
#     epoch 179/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3394, train_r2=0.6606, test_loss=0.3423, test_r2=0.6486
#     epoch 180/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3298, train_r2=0.6702, test_loss=0.3348, test_r2=0.6564
#     epoch 181/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3369, train_r2=0.6631, test_loss=0.3435, test_r2=0.6474
#     epoch 182/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3324, train_r2=0.6676, test_loss=0.3371, test_r2=0.6540
#     epoch 183/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3317, train_r2=0.6683, test_loss=0.3389, test_r2=0.6521
#     epoch 184/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3277, train_r2=0.6723, test_loss=0.3334, test_r2=0.6578
#     epoch 185/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3312, train_r2=0.6688, test_loss=0.3386, test_r2=0.6524
#     epoch 186/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3377, train_r2=0.6623, test_loss=0.3450, test_r2=0.6459
#     epoch 187/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3299, train_r2=0.6701, test_loss=0.3323, test_r2=0.6589
#     epoch 188/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3352, train_r2=0.6648, test_loss=0.3426, test_r2=0.6484
#     epoch 189/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3297, train_r2=0.6703, test_loss=0.3346, test_r2=0.6565
#     epoch 190/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3471, train_r2=0.6529, test_loss=0.3557, test_r2=0.6349
#     epoch 191/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3416, train_r2=0.6584, test_loss=0.3454, test_r2=0.6455
#     epoch 192/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3346, train_r2=0.6654, test_loss=0.3379, test_r2=0.6532
#     epoch 193/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3419, train_r2=0.6581, test_loss=0.3475, test_r2=0.6434
#     epoch 194/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3419, train_r2=0.6581, test_loss=0.3446, test_r2=0.6463
#     epoch 195/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3455, train_r2=0.6545, test_loss=0.3467, test_r2=0.6442
#     epoch 196/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3363, train_r2=0.6637, test_loss=0.3356, test_r2=0.6555
#     epoch 197/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3406, train_r2=0.6594, test_loss=0.3370, test_r2=0.6542
#     epoch 198/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3399, train_r2=0.6601, test_loss=0.3338, test_r2=0.6574
#     epoch 199/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3522, train_r2=0.6478, test_loss=0.3475, test_r2=0.6434
#     epoch 200/200 | wp | lr=0.0075, sigma=0.08 | train_loss=0.3545, train_r2=0.6455, test_loss=0.3523, test_r2=0.6384
#       method  final_train_loss  final_train_r2  final_test_loss  \
# 0         bp          0.260549        0.739451         0.260924
# 1         np          0.340074        0.659926         0.342812
# 2  np_fan_in          0.329791        0.670209         0.337885
# 3   np_fixed          0.382642        0.617358         0.394827
# 4         wp          0.354491        0.645509         0.352293
#
#    final_test_r2  best_test_loss  best_test_r2  diverged  duration_sec
# 0       0.732189        0.259873      0.733268     False     50.919485
# 1       0.648139        0.335015      0.656142     False     51.189654
# 2       0.653197        0.324556      0.666878     False     50.375308
# 3       0.594752        0.383735      0.606137     False     50.292064
# 4       0.638408        0.326242      0.665147     False     50.499020

# %%
# Optional single-config runner.
# Edit RUN_CONFIGS and rerun this cell if you want to test one chosen setup.

RUN_EPOCHS = FINAL_EPOCHS
RUN_SEED = 0
RUN_PRINT_EVERY_EPOCH = 1

METHODS = ["bp", "np", "np_fan_in", "np_fixed", "wp"]


RUN_CONFIGS = {
    "bp": {"lr": 0.1},
    "np": {"lr": 0.03*0.9, "sigma": 0.1},
    "np_fan_in": {"lr": 0.025*0.7, "sigma": 0.0525},
    "np_fixed": {"lr": 0.025*0.7, "sigma": 0.45},
    "wp": {"lr": 0.015*0.9, "sigma": 0.1},
}

single_results = {}

print(
    f"Running {len(RUN_CONFIGS)} config(s) | "
    f"epochs={RUN_EPOCHS}, seed={RUN_SEED}, dims={DIMENSIONS}, device={device}"
)

for method in METHODS:
    if method not in RUN_CONFIGS:
        continue
    config = RUN_CONFIGS[method]
    sigma_str = f", sigma={config['sigma']:.4g}" if "sigma" in config else ""
    print()
    print(f"### Final run | {method} | lr={config['lr']:.4g}{sigma_str}")
    single_results[method] = train_one_run(
        method=method,
        run_config=config,
        data=data,
        dimensions=DIMENSIONS,
        epochs=RUN_EPOCHS,
        seed=RUN_SEED,
        device=device,
        print_every_epoch=RUN_PRINT_EVERY_EPOCH,
    )

display(results_table(single_results))
plot_training_histories(single_results)
plot_layer_output_norm_histories(single_results)
plot_prediction_diagnostics(single_results, data, DIMENSIONS, device)
# Out:
# Running 5 config(s) | epochs=200, seed=0, dims=(8, 128, 64, 1), device=cuda
#
# ### Final run | bp | lr=0.1
#     epoch  1/200 | bp | lr=0.1 | train_loss=0.9832, train_r2=0.0168, test_loss=0.9604, test_r2=0.0142
#     epoch  2/200 | bp | lr=0.1 | train_loss=0.9461, train_r2=0.0539, test_loss=0.9236, test_r2=0.0521
#     epoch  3/200 | bp | lr=0.1 | train_loss=0.8280, train_r2=0.1720, test_loss=0.8150, test_r2=0.1635
#     epoch  4/200 | bp | lr=0.1 | train_loss=0.5855, train_r2=0.4145, test_loss=0.5900, test_r2=0.3944
#     epoch  5/200 | bp | lr=0.1 | train_loss=0.4670, train_r2=0.5330, test_loss=0.4796, test_r2=0.5077
#     epoch  6/200 | bp | lr=0.1 | train_loss=0.4379, train_r2=0.5621, test_loss=0.4523, test_r2=0.5357
#     epoch  7/200 | bp | lr=0.1 | train_loss=0.4225, train_r2=0.5775, test_loss=0.4365, test_r2=0.5520
#     epoch  8/200 | bp | lr=0.1 | train_loss=0.4107, train_r2=0.5893, test_loss=0.4238, test_r2=0.5650
#     epoch  9/200 | bp | lr=0.1 | train_loss=0.4066, train_r2=0.5934, test_loss=0.4194, test_r2=0.5695
#     epoch 10/200 | bp | lr=0.1 | train_loss=0.3865, train_r2=0.6135, test_loss=0.3950, test_r2=0.5945
#     epoch 11/200 | bp | lr=0.1 | train_loss=0.3728, train_r2=0.6272, test_loss=0.3811, test_r2=0.6089
#     epoch 12/200 | bp | lr=0.1 | train_loss=0.3789, train_r2=0.6211, test_loss=0.3833, test_r2=0.6066
#     epoch 13/200 | bp | lr=0.1 | train_loss=0.3563, train_r2=0.6437, test_loss=0.3626, test_r2=0.6278
#     epoch 14/200 | bp | lr=0.1 | train_loss=0.3929, train_r2=0.6071, test_loss=0.3934, test_r2=0.5962
#     epoch 15/200 | bp | lr=0.1 | train_loss=0.3448, train_r2=0.6552, test_loss=0.3491, test_r2=0.6416
#     epoch 16/200 | bp | lr=0.1 | train_loss=0.3367, train_r2=0.6633, test_loss=0.3396, test_r2=0.6515
#     epoch 17/200 | bp | lr=0.1 | train_loss=0.3311, train_r2=0.6689, test_loss=0.3328, test_r2=0.6584
#     epoch 18/200 | bp | lr=0.1 | train_loss=0.3320, train_r2=0.6680, test_loss=0.3319, test_r2=0.6593
#     epoch 19/200 | bp | lr=0.1 | train_loss=0.3388, train_r2=0.6612, test_loss=0.3415, test_r2=0.6495
#     epoch 20/200 | bp | lr=0.1 | train_loss=0.3400, train_r2=0.6600, test_loss=0.3380, test_r2=0.6531
#     epoch 21/200 | bp | lr=0.1 | train_loss=0.3254, train_r2=0.6746, test_loss=0.3268, test_r2=0.6646
#     epoch 22/200 | bp | lr=0.1 | train_loss=0.3171, train_r2=0.6829, test_loss=0.3168, test_r2=0.6748
#     epoch 23/200 | bp | lr=0.1 | train_loss=0.3192, train_r2=0.6808, test_loss=0.3176, test_r2=0.6740
#     epoch 24/200 | bp | lr=0.1 | train_loss=0.3345, train_r2=0.6655, test_loss=0.3315, test_r2=0.6597
#     epoch 25/200 | bp | lr=0.1 | train_loss=0.3171, train_r2=0.6829, test_loss=0.3149, test_r2=0.6768
#     epoch 26/200 | bp | lr=0.1 | train_loss=0.3442, train_r2=0.6558, test_loss=0.3465, test_r2=0.6444
#     epoch 27/200 | bp | lr=0.1 | train_loss=0.3102, train_r2=0.6898, test_loss=0.3096, test_r2=0.6822
#     epoch 28/200 | bp | lr=0.1 | train_loss=0.3109, train_r2=0.6891, test_loss=0.3088, test_r2=0.6831
#     epoch 29/200 | bp | lr=0.1 | train_loss=0.3064, train_r2=0.6936, test_loss=0.3054, test_r2=0.6865
#     epoch 30/200 | bp | lr=0.1 | train_loss=0.3575, train_r2=0.6425, test_loss=0.3528, test_r2=0.6379
#     epoch 31/200 | bp | lr=0.1 | train_loss=0.3045, train_r2=0.6955, test_loss=0.3020, test_r2=0.6900
#     epoch 32/200 | bp | lr=0.1 | train_loss=0.3240, train_r2=0.6760, test_loss=0.3245, test_r2=0.6669
#     epoch 33/200 | bp | lr=0.1 | train_loss=0.3013, train_r2=0.6987, test_loss=0.2998, test_r2=0.6923
#     epoch 34/200 | bp | lr=0.1 | train_loss=0.3000, train_r2=0.7000, test_loss=0.2979, test_r2=0.6943
#     epoch 35/200 | bp | lr=0.1 | train_loss=0.2996, train_r2=0.7004, test_loss=0.2978, test_r2=0.6943
#     epoch 36/200 | bp | lr=0.1 | train_loss=0.3010, train_r2=0.6990, test_loss=0.2996, test_r2=0.6925
#     epoch 37/200 | bp | lr=0.1 | train_loss=0.3080, train_r2=0.6920, test_loss=0.3070, test_r2=0.6848
#     epoch 38/200 | bp | lr=0.1 | train_loss=0.3079, train_r2=0.6921, test_loss=0.3069, test_r2=0.6850
#     epoch 39/200 | bp | lr=0.1 | train_loss=0.2967, train_r2=0.7033, test_loss=0.2939, test_r2=0.6983
#     epoch 40/200 | bp | lr=0.1 | train_loss=0.3211, train_r2=0.6789, test_loss=0.3170, test_r2=0.6747
#     epoch 41/200 | bp | lr=0.1 | train_loss=0.3297, train_r2=0.6703, test_loss=0.3298, test_r2=0.6615
#     epoch 42/200 | bp | lr=0.1 | train_loss=0.2984, train_r2=0.7016, test_loss=0.2951, test_r2=0.6971
#     epoch 43/200 | bp | lr=0.1 | train_loss=0.2929, train_r2=0.7071, test_loss=0.2903, test_r2=0.7021
#     epoch 44/200 | bp | lr=0.1 | train_loss=0.3095, train_r2=0.6905, test_loss=0.3054, test_r2=0.6866
#     epoch 45/200 | bp | lr=0.1 | train_loss=0.3009, train_r2=0.6991, test_loss=0.2976, test_r2=0.6945
#     epoch 46/200 | bp | lr=0.1 | train_loss=0.2927, train_r2=0.7073, test_loss=0.2907, test_r2=0.7017
#     epoch 47/200 | bp | lr=0.1 | train_loss=0.2916, train_r2=0.7084, test_loss=0.2884, test_r2=0.7040
#     epoch 48/200 | bp | lr=0.1 | train_loss=0.2974, train_r2=0.7026, test_loss=0.2939, test_r2=0.6984
#     epoch 49/200 | bp | lr=0.1 | train_loss=0.3088, train_r2=0.6912, test_loss=0.3049, test_r2=0.6870
#     epoch 50/200 | bp | lr=0.1 | train_loss=0.2920, train_r2=0.7080, test_loss=0.2899, test_r2=0.7024
#     epoch 51/200 | bp | lr=0.1 | train_loss=0.2893, train_r2=0.7107, test_loss=0.2860, test_r2=0.7064
#     epoch 52/200 | bp | lr=0.1 | train_loss=0.2901, train_r2=0.7099, test_loss=0.2867, test_r2=0.7057
#     epoch 53/200 | bp | lr=0.1 | train_loss=0.2939, train_r2=0.7061, test_loss=0.2919, test_r2=0.7004
#     epoch 54/200 | bp | lr=0.1 | train_loss=0.2918, train_r2=0.7082, test_loss=0.2896, test_r2=0.7027
#     epoch 55/200 | bp | lr=0.1 | train_loss=0.2952, train_r2=0.7048, test_loss=0.2913, test_r2=0.7010
#     epoch 56/200 | bp | lr=0.1 | train_loss=0.2894, train_r2=0.7106, test_loss=0.2858, test_r2=0.7067
#     epoch 57/200 | bp | lr=0.1 | train_loss=0.2875, train_r2=0.7125, test_loss=0.2849, test_r2=0.7076
#     epoch 58/200 | bp | lr=0.1 | train_loss=0.2909, train_r2=0.7091, test_loss=0.2888, test_r2=0.7035
#     epoch 59/200 | bp | lr=0.1 | train_loss=0.2859, train_r2=0.7141, test_loss=0.2829, test_r2=0.7096
#     epoch 60/200 | bp | lr=0.1 | train_loss=0.2939, train_r2=0.7061, test_loss=0.2899, test_r2=0.7025
#     epoch 61/200 | bp | lr=0.1 | train_loss=0.2997, train_r2=0.7003, test_loss=0.2958, test_r2=0.6964
#     epoch 62/200 | bp | lr=0.1 | train_loss=0.2871, train_r2=0.7129, test_loss=0.2845, test_r2=0.7080
#     epoch 63/200 | bp | lr=0.1 | train_loss=0.3040, train_r2=0.6960, test_loss=0.2999, test_r2=0.6922
#     epoch 64/200 | bp | lr=0.1 | train_loss=0.2866, train_r2=0.7134, test_loss=0.2842, test_r2=0.7083
#     epoch 65/200 | bp | lr=0.1 | train_loss=0.2849, train_r2=0.7151, test_loss=0.2824, test_r2=0.7102
#     epoch 66/200 | bp | lr=0.1 | train_loss=0.2840, train_r2=0.7160, test_loss=0.2810, test_r2=0.7115
#     epoch 67/200 | bp | lr=0.1 | train_loss=0.2897, train_r2=0.7103, test_loss=0.2878, test_r2=0.7046
#     epoch 68/200 | bp | lr=0.1 | train_loss=0.3247, train_r2=0.6753, test_loss=0.3240, test_r2=0.6674
#     epoch 69/200 | bp | lr=0.1 | train_loss=0.3196, train_r2=0.6804, test_loss=0.3195, test_r2=0.6720
#     epoch 70/200 | bp | lr=0.1 | train_loss=0.3005, train_r2=0.6995, test_loss=0.2965, test_r2=0.6957
#     epoch 71/200 | bp | lr=0.1 | train_loss=0.3393, train_r2=0.6607, test_loss=0.3345, test_r2=0.6567
#     epoch 72/200 | bp | lr=0.1 | train_loss=0.2878, train_r2=0.7122, test_loss=0.2857, test_r2=0.7067
#     epoch 73/200 | bp | lr=0.1 | train_loss=0.2925, train_r2=0.7075, test_loss=0.2908, test_r2=0.7015
#     epoch 74/200 | bp | lr=0.1 | train_loss=0.3248, train_r2=0.6752, test_loss=0.3247, test_r2=0.6667
#     epoch 75/200 | bp | lr=0.1 | train_loss=0.2839, train_r2=0.7161, test_loss=0.2817, test_r2=0.7109
#     epoch 76/200 | bp | lr=0.1 | train_loss=0.2931, train_r2=0.7069, test_loss=0.2909, test_r2=0.7014
#     epoch 77/200 | bp | lr=0.1 | train_loss=0.2820, train_r2=0.7180, test_loss=0.2795, test_r2=0.7132
#     epoch 78/200 | bp | lr=0.1 | train_loss=0.2817, train_r2=0.7183, test_loss=0.2791, test_r2=0.7136
#     epoch 79/200 | bp | lr=0.1 | train_loss=0.2833, train_r2=0.7167, test_loss=0.2808, test_r2=0.7118
#     epoch 80/200 | bp | lr=0.1 | train_loss=0.2822, train_r2=0.7178, test_loss=0.2798, test_r2=0.7128
#     epoch 81/200 | bp | lr=0.1 | train_loss=0.2816, train_r2=0.7184, test_loss=0.2794, test_r2=0.7133
#     epoch 82/200 | bp | lr=0.1 | train_loss=0.2995, train_r2=0.7005, test_loss=0.2984, test_r2=0.6937
#     epoch 83/200 | bp | lr=0.1 | train_loss=0.3400, train_r2=0.6600, test_loss=0.3401, test_r2=0.6509
#     epoch 84/200 | bp | lr=0.1 | train_loss=0.2805, train_r2=0.7195, test_loss=0.2779, test_r2=0.7148
#     epoch 85/200 | bp | lr=0.1 | train_loss=0.2809, train_r2=0.7191, test_loss=0.2786, test_r2=0.7140
#     epoch 86/200 | bp | lr=0.1 | train_loss=0.2807, train_r2=0.7193, test_loss=0.2782, test_r2=0.7144
#     epoch 87/200 | bp | lr=0.1 | train_loss=0.2800, train_r2=0.7200, test_loss=0.2771, test_r2=0.7156
#     epoch 88/200 | bp | lr=0.1 | train_loss=0.2828, train_r2=0.7172, test_loss=0.2808, test_r2=0.7118
#     epoch 89/200 | bp | lr=0.1 | train_loss=0.2893, train_r2=0.7107, test_loss=0.2878, test_r2=0.7046
#     epoch 90/200 | bp | lr=0.1 | train_loss=0.2869, train_r2=0.7131, test_loss=0.2834, test_r2=0.7091
#     epoch 91/200 | bp | lr=0.1 | train_loss=0.2794, train_r2=0.7206, test_loss=0.2768, test_r2=0.7159
#     epoch 92/200 | bp | lr=0.1 | train_loss=0.2800, train_r2=0.7200, test_loss=0.2779, test_r2=0.7147
#     epoch 93/200 | bp | lr=0.1 | train_loss=0.2789, train_r2=0.7211, test_loss=0.2765, test_r2=0.7162
#     epoch 94/200 | bp | lr=0.1 | train_loss=0.2883, train_r2=0.7117, test_loss=0.2846, test_r2=0.7079
#     epoch 95/200 | bp | lr=0.1 | train_loss=0.2809, train_r2=0.7191, test_loss=0.2789, test_r2=0.7137
#     epoch 96/200 | bp | lr=0.1 | train_loss=0.2796, train_r2=0.7204, test_loss=0.2776, test_r2=0.7150
#     epoch 97/200 | bp | lr=0.1 | train_loss=0.2785, train_r2=0.7215, test_loss=0.2760, test_r2=0.7168
#     epoch 98/200 | bp | lr=0.1 | train_loss=0.2807, train_r2=0.7193, test_loss=0.2793, test_r2=0.7134
#     epoch 99/200 | bp | lr=0.1 | train_loss=0.2819, train_r2=0.7181, test_loss=0.2792, test_r2=0.7134
#     epoch 100/200 | bp | lr=0.1 | train_loss=0.2778, train_r2=0.7222, test_loss=0.2753, test_r2=0.7175
#     epoch 101/200 | bp | lr=0.1 | train_loss=0.3014, train_r2=0.6986, test_loss=0.3005, test_r2=0.6916
#     epoch 102/200 | bp | lr=0.1 | train_loss=0.2787, train_r2=0.7213, test_loss=0.2771, test_r2=0.7156
#     epoch 103/200 | bp | lr=0.1 | train_loss=0.2825, train_r2=0.7175, test_loss=0.2791, test_r2=0.7136
#     epoch 104/200 | bp | lr=0.1 | train_loss=0.2788, train_r2=0.7212, test_loss=0.2760, test_r2=0.7168
#     epoch 105/200 | bp | lr=0.1 | train_loss=0.2768, train_r2=0.7232, test_loss=0.2746, test_r2=0.7182
#     epoch 106/200 | bp | lr=0.1 | train_loss=0.2767, train_r2=0.7233, test_loss=0.2742, test_r2=0.7185
#     epoch 107/200 | bp | lr=0.1 | train_loss=0.2905, train_r2=0.7095, test_loss=0.2896, test_r2=0.7027
#     epoch 108/200 | bp | lr=0.1 | train_loss=0.2778, train_r2=0.7222, test_loss=0.2751, test_r2=0.7176
#     epoch 109/200 | bp | lr=0.1 | train_loss=0.2775, train_r2=0.7225, test_loss=0.2751, test_r2=0.7177
#     epoch 110/200 | bp | lr=0.1 | train_loss=0.2796, train_r2=0.7204, test_loss=0.2780, test_r2=0.7147
#     epoch 111/200 | bp | lr=0.1 | train_loss=0.2851, train_r2=0.7149, test_loss=0.2843, test_r2=0.7082
#     epoch 112/200 | bp | lr=0.1 | train_loss=0.2782, train_r2=0.7218, test_loss=0.2769, test_r2=0.7158
#     epoch 113/200 | bp | lr=0.1 | train_loss=0.2822, train_r2=0.7178, test_loss=0.2791, test_r2=0.7135
#     epoch 114/200 | bp | lr=0.1 | train_loss=0.2801, train_r2=0.7199, test_loss=0.2791, test_r2=0.7135
#     epoch 115/200 | bp | lr=0.1 | train_loss=0.3004, train_r2=0.6996, test_loss=0.2967, test_r2=0.6955
#     epoch 116/200 | bp | lr=0.1 | train_loss=0.2830, train_r2=0.7170, test_loss=0.2797, test_r2=0.7129
#     epoch 117/200 | bp | lr=0.1 | train_loss=0.2747, train_r2=0.7253, test_loss=0.2728, test_r2=0.7200
#     epoch 118/200 | bp | lr=0.1 | train_loss=0.3052, train_r2=0.6948, test_loss=0.3015, test_r2=0.6905
#     epoch 119/200 | bp | lr=0.1 | train_loss=0.2741, train_r2=0.7259, test_loss=0.2719, test_r2=0.7209
#     epoch 120/200 | bp | lr=0.1 | train_loss=0.2772, train_r2=0.7228, test_loss=0.2758, test_r2=0.7169
#     epoch 121/200 | bp | lr=0.1 | train_loss=0.2821, train_r2=0.7179, test_loss=0.2815, test_r2=0.7111
#     epoch 122/200 | bp | lr=0.1 | train_loss=0.2734, train_r2=0.7266, test_loss=0.2709, test_r2=0.7220
#     epoch 123/200 | bp | lr=0.1 | train_loss=0.2829, train_r2=0.7171, test_loss=0.2821, test_r2=0.7104
#     epoch 124/200 | bp | lr=0.1 | train_loss=0.2810, train_r2=0.7190, test_loss=0.2777, test_r2=0.7150
#     epoch 125/200 | bp | lr=0.1 | train_loss=0.2781, train_r2=0.7219, test_loss=0.2774, test_r2=0.7152
#     epoch 126/200 | bp | lr=0.1 | train_loss=0.3016, train_r2=0.6984, test_loss=0.2976, test_r2=0.6945
#     epoch 127/200 | bp | lr=0.1 | train_loss=0.2737, train_r2=0.7263, test_loss=0.2722, test_r2=0.7206
#     epoch 128/200 | bp | lr=0.1 | train_loss=0.2791, train_r2=0.7209, test_loss=0.2788, test_r2=0.7138
#     epoch 129/200 | bp | lr=0.1 | train_loss=0.2737, train_r2=0.7263, test_loss=0.2723, test_r2=0.7205
#     epoch 130/200 | bp | lr=0.1 | train_loss=0.2802, train_r2=0.7198, test_loss=0.2775, test_r2=0.7152
#     epoch 131/200 | bp | lr=0.1 | train_loss=0.2771, train_r2=0.7229, test_loss=0.2763, test_r2=0.7164
#     epoch 132/200 | bp | lr=0.1 | train_loss=0.2762, train_r2=0.7238, test_loss=0.2730, test_r2=0.7197
#     epoch 133/200 | bp | lr=0.1 | train_loss=0.2721, train_r2=0.7279, test_loss=0.2700, test_r2=0.7229
#     epoch 134/200 | bp | lr=0.1 | train_loss=0.2858, train_r2=0.7142, test_loss=0.2857, test_r2=0.7067
#     epoch 135/200 | bp | lr=0.1 | train_loss=0.2892, train_r2=0.7108, test_loss=0.2895, test_r2=0.7028
#     epoch 136/200 | bp | lr=0.1 | train_loss=0.2750, train_r2=0.7250, test_loss=0.2721, test_r2=0.7207
#     epoch 137/200 | bp | lr=0.1 | train_loss=0.2792, train_r2=0.7208, test_loss=0.2788, test_r2=0.7138
#     epoch 138/200 | bp | lr=0.1 | train_loss=0.2719, train_r2=0.7281, test_loss=0.2711, test_r2=0.7218
#     epoch 139/200 | bp | lr=0.1 | train_loss=0.2710, train_r2=0.7290, test_loss=0.2688, test_r2=0.7241
#     epoch 140/200 | bp | lr=0.1 | train_loss=0.2702, train_r2=0.7298, test_loss=0.2685, test_r2=0.7244
#     epoch 141/200 | bp | lr=0.1 | train_loss=0.2737, train_r2=0.7263, test_loss=0.2734, test_r2=0.7194
#     epoch 142/200 | bp | lr=0.1 | train_loss=0.2693, train_r2=0.7307, test_loss=0.2677, test_r2=0.7252
#     epoch 143/200 | bp | lr=0.1 | train_loss=0.2783, train_r2=0.7217, test_loss=0.2785, test_r2=0.7142
#     epoch 144/200 | bp | lr=0.1 | train_loss=0.2693, train_r2=0.7307, test_loss=0.2682, test_r2=0.7247
#     epoch 145/200 | bp | lr=0.1 | train_loss=0.2820, train_r2=0.7180, test_loss=0.2792, test_r2=0.7135
#     epoch 146/200 | bp | lr=0.1 | train_loss=0.2685, train_r2=0.7315, test_loss=0.2676, test_r2=0.7254
#     epoch 147/200 | bp | lr=0.1 | train_loss=0.2693, train_r2=0.7307, test_loss=0.2675, test_r2=0.7254
#     epoch 148/200 | bp | lr=0.1 | train_loss=0.2738, train_r2=0.7262, test_loss=0.2714, test_r2=0.7215
#     epoch 149/200 | bp | lr=0.1 | train_loss=0.2687, train_r2=0.7313, test_loss=0.2669, test_r2=0.7261
#     epoch 150/200 | bp | lr=0.1 | train_loss=0.2708, train_r2=0.7292, test_loss=0.2690, test_r2=0.7239
#     epoch 151/200 | bp | lr=0.1 | train_loss=0.2683, train_r2=0.7317, test_loss=0.2664, test_r2=0.7265
#     epoch 152/200 | bp | lr=0.1 | train_loss=0.2684, train_r2=0.7316, test_loss=0.2679, test_r2=0.7250
#     epoch 153/200 | bp | lr=0.1 | train_loss=0.2842, train_r2=0.7158, test_loss=0.2852, test_r2=0.7072
#     epoch 154/200 | bp | lr=0.1 | train_loss=0.2684, train_r2=0.7316, test_loss=0.2666, test_r2=0.7263
#     epoch 155/200 | bp | lr=0.1 | train_loss=0.2706, train_r2=0.7294, test_loss=0.2693, test_r2=0.7236
#     epoch 156/200 | bp | lr=0.1 | train_loss=0.2907, train_r2=0.7093, test_loss=0.2879, test_r2=0.7045
#     epoch 157/200 | bp | lr=0.1 | train_loss=0.2664, train_r2=0.7336, test_loss=0.2658, test_r2=0.7272
#     epoch 158/200 | bp | lr=0.1 | train_loss=0.2760, train_r2=0.7240, test_loss=0.2736, test_r2=0.7192
#     epoch 159/200 | bp | lr=0.1 | train_loss=0.2815, train_r2=0.7185, test_loss=0.2784, test_r2=0.7142
#     epoch 160/200 | bp | lr=0.1 | train_loss=0.2666, train_r2=0.7334, test_loss=0.2663, test_r2=0.7267
#     epoch 161/200 | bp | lr=0.1 | train_loss=0.2654, train_r2=0.7346, test_loss=0.2647, test_r2=0.7283
#     epoch 162/200 | bp | lr=0.1 | train_loss=0.2654, train_r2=0.7346, test_loss=0.2650, test_r2=0.7280
#     epoch 163/200 | bp | lr=0.1 | train_loss=0.2650, train_r2=0.7350, test_loss=0.2645, test_r2=0.7285
#     epoch 164/200 | bp | lr=0.1 | train_loss=0.2677, train_r2=0.7323, test_loss=0.2676, test_r2=0.7253
#     epoch 165/200 | bp | lr=0.1 | train_loss=0.2686, train_r2=0.7314, test_loss=0.2669, test_r2=0.7261
#     epoch 166/200 | bp | lr=0.1 | train_loss=0.2831, train_r2=0.7169, test_loss=0.2805, test_r2=0.7121
#     epoch 167/200 | bp | lr=0.1 | train_loss=0.2931, train_r2=0.7069, test_loss=0.2959, test_r2=0.6963
#     epoch 168/200 | bp | lr=0.1 | train_loss=0.2661, train_r2=0.7339, test_loss=0.2645, test_r2=0.7285
#     epoch 169/200 | bp | lr=0.1 | train_loss=0.2642, train_r2=0.7358, test_loss=0.2635, test_r2=0.7295
#     epoch 170/200 | bp | lr=0.1 | train_loss=0.3095, train_r2=0.6905, test_loss=0.3120, test_r2=0.6797
#     epoch 171/200 | bp | lr=0.1 | train_loss=0.2734, train_r2=0.7266, test_loss=0.2746, test_r2=0.7181
#     epoch 172/200 | bp | lr=0.1 | train_loss=0.2633, train_r2=0.7367, test_loss=0.2634, test_r2=0.7297
#     epoch 173/200 | bp | lr=0.1 | train_loss=0.2635, train_r2=0.7365, test_loss=0.2633, test_r2=0.7298
#     epoch 174/200 | bp | lr=0.1 | train_loss=0.2653, train_r2=0.7347, test_loss=0.2642, test_r2=0.7288
#     epoch 175/200 | bp | lr=0.1 | train_loss=0.2745, train_r2=0.7255, test_loss=0.2726, test_r2=0.7203
#     epoch 176/200 | bp | lr=0.1 | train_loss=0.2645, train_r2=0.7355, test_loss=0.2641, test_r2=0.7289
#     epoch 177/200 | bp | lr=0.1 | train_loss=0.2628, train_r2=0.7372, test_loss=0.2625, test_r2=0.7306
#     epoch 178/200 | bp | lr=0.1 | train_loss=0.2652, train_r2=0.7348, test_loss=0.2640, test_r2=0.7290
#     epoch 179/200 | bp | lr=0.1 | train_loss=0.2683, train_r2=0.7317, test_loss=0.2670, test_r2=0.7259
#     epoch 180/200 | bp | lr=0.1 | train_loss=0.2655, train_r2=0.7345, test_loss=0.2645, test_r2=0.7285
#     epoch 181/200 | bp | lr=0.1 | train_loss=0.2760, train_r2=0.7240, test_loss=0.2785, test_r2=0.7142
#     epoch 182/200 | bp | lr=0.1 | train_loss=0.2745, train_r2=0.7255, test_loss=0.2765, test_r2=0.7162
#     epoch 183/200 | bp | lr=0.1 | train_loss=0.2625, train_r2=0.7375, test_loss=0.2624, test_r2=0.7307
#     epoch 184/200 | bp | lr=0.1 | train_loss=0.2616, train_r2=0.7384, test_loss=0.2625, test_r2=0.7306
#     epoch 185/200 | bp | lr=0.1 | train_loss=0.2660, train_r2=0.7340, test_loss=0.2676, test_r2=0.7254
#     epoch 186/200 | bp | lr=0.1 | train_loss=0.2665, train_r2=0.7335, test_loss=0.2678, test_r2=0.7251
#     epoch 187/200 | bp | lr=0.1 | train_loss=0.2651, train_r2=0.7349, test_loss=0.2651, test_r2=0.7279
#     epoch 188/200 | bp | lr=0.1 | train_loss=0.2688, train_r2=0.7312, test_loss=0.2681, test_r2=0.7248
#     epoch 189/200 | bp | lr=0.1 | train_loss=0.2692, train_r2=0.7308, test_loss=0.2685, test_r2=0.7244
#     epoch 190/200 | bp | lr=0.1 | train_loss=0.2602, train_r2=0.7398, test_loss=0.2601, test_r2=0.7330
#     epoch 191/200 | bp | lr=0.1 | train_loss=0.2612, train_r2=0.7388, test_loss=0.2624, test_r2=0.7307
#     epoch 192/200 | bp | lr=0.1 | train_loss=0.2597, train_r2=0.7403, test_loss=0.2605, test_r2=0.7326
#     epoch 193/200 | bp | lr=0.1 | train_loss=0.2600, train_r2=0.7400, test_loss=0.2599, test_r2=0.7333
#     epoch 194/200 | bp | lr=0.1 | train_loss=0.2670, train_r2=0.7330, test_loss=0.2689, test_r2=0.7240
#     epoch 195/200 | bp | lr=0.1 | train_loss=0.2600, train_r2=0.7400, test_loss=0.2600, test_r2=0.7332
#     epoch 196/200 | bp | lr=0.1 | train_loss=0.2678, train_r2=0.7322, test_loss=0.2664, test_r2=0.7265
#     epoch 197/200 | bp | lr=0.1 | train_loss=0.2634, train_r2=0.7366, test_loss=0.2636, test_r2=0.7294
#     epoch 198/200 | bp | lr=0.1 | train_loss=0.2675, train_r2=0.7325, test_loss=0.2700, test_r2=0.7228
#     epoch 199/200 | bp | lr=0.1 | train_loss=0.2765, train_r2=0.7235, test_loss=0.2793, test_r2=0.7133
#     epoch 200/200 | bp | lr=0.1 | train_loss=0.2605, train_r2=0.7395, test_loss=0.2609, test_r2=0.7322
#
# ### Final run | np | lr=0.027, sigma=0.1
#     epoch  1/200 | np | lr=0.027, sigma=0.1 | train_loss=1.0553, train_r2=-0.0553, test_loss=1.0415, test_r2=-0.0690
#     epoch  2/200 | np | lr=0.027, sigma=0.1 | train_loss=0.9476, train_r2=0.0524, test_loss=0.9266, test_r2=0.0490
#     epoch  3/200 | np | lr=0.027, sigma=0.1 | train_loss=0.9177, train_r2=0.0823, test_loss=0.8947, test_r2=0.0817
#     epoch  4/200 | np | lr=0.027, sigma=0.1 | train_loss=0.8211, train_r2=0.1789, test_loss=0.8091, test_r2=0.1696
#     epoch  5/200 | np | lr=0.027, sigma=0.1 | train_loss=0.7244, train_r2=0.2756, test_loss=0.7177, test_r2=0.2633
#     epoch  6/200 | np | lr=0.027, sigma=0.1 | train_loss=0.6798, train_r2=0.3202, test_loss=0.6853, test_r2=0.2966
#     epoch  7/200 | np | lr=0.027, sigma=0.1 | train_loss=0.5357, train_r2=0.4643, test_loss=0.5458, test_r2=0.4398
#     epoch  8/200 | np | lr=0.027, sigma=0.1 | train_loss=0.5054, train_r2=0.4946, test_loss=0.5198, test_r2=0.4665
#     epoch  9/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4894, train_r2=0.5106, test_loss=0.5088, test_r2=0.4777
#     epoch 10/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4895, train_r2=0.5105, test_loss=0.5060, test_r2=0.4807
#     epoch 11/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4800, train_r2=0.5200, test_loss=0.4971, test_r2=0.4897
#     epoch 12/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4617, train_r2=0.5383, test_loss=0.4800, test_r2=0.5073
#     epoch 13/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4527, train_r2=0.5473, test_loss=0.4729, test_r2=0.5146
#     epoch 14/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4534, train_r2=0.5466, test_loss=0.4731, test_r2=0.5144
#     epoch 15/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4799, train_r2=0.5201, test_loss=0.4995, test_r2=0.4873
#     epoch 16/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4397, train_r2=0.5603, test_loss=0.4573, test_r2=0.5307
#     epoch 17/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4352, train_r2=0.5648, test_loss=0.4547, test_r2=0.5333
#     epoch 18/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4384, train_r2=0.5616, test_loss=0.4537, test_r2=0.5344
#     epoch 19/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4293, train_r2=0.5707, test_loss=0.4457, test_r2=0.5426
#     epoch 20/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4272, train_r2=0.5728, test_loss=0.4441, test_r2=0.5442
#     epoch 21/200 | np | lr=0.027, sigma=0.1 | train_loss=0.5239, train_r2=0.4761, test_loss=0.5330, test_r2=0.4529
#     epoch 22/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4495, train_r2=0.5505, test_loss=0.4649, test_r2=0.5228
#     epoch 23/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4279, train_r2=0.5721, test_loss=0.4446, test_r2=0.5437
#     epoch 24/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4243, train_r2=0.5757, test_loss=0.4391, test_r2=0.5493
#     epoch 25/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4303, train_r2=0.5697, test_loss=0.4479, test_r2=0.5403
#     epoch 26/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4260, train_r2=0.5740, test_loss=0.4435, test_r2=0.5448
#     epoch 27/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4197, train_r2=0.5803, test_loss=0.4360, test_r2=0.5525
#     epoch 28/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4643, train_r2=0.5357, test_loss=0.4751, test_r2=0.5124
#     epoch 29/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4239, train_r2=0.5761, test_loss=0.4383, test_r2=0.5502
#     epoch 30/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4727, train_r2=0.5273, test_loss=0.4817, test_r2=0.5055
#     epoch 31/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4204, train_r2=0.5796, test_loss=0.4307, test_r2=0.5580
#     epoch 32/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4135, train_r2=0.5865, test_loss=0.4267, test_r2=0.5620
#     epoch 33/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4174, train_r2=0.5826, test_loss=0.4318, test_r2=0.5568
#     epoch 34/200 | np | lr=0.027, sigma=0.1 | train_loss=0.5451, train_r2=0.4549, test_loss=0.5634, test_r2=0.4218
#     epoch 35/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4373, train_r2=0.5627, test_loss=0.4466, test_r2=0.5416
#     epoch 36/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4016, train_r2=0.5984, test_loss=0.4123, test_r2=0.5768
#     epoch 37/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3997, train_r2=0.6003, test_loss=0.4099, test_r2=0.5793
#     epoch 38/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3972, train_r2=0.6028, test_loss=0.4063, test_r2=0.5830
#     epoch 39/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4212, train_r2=0.5788, test_loss=0.4281, test_r2=0.5606
#     epoch 40/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4062, train_r2=0.5938, test_loss=0.4151, test_r2=0.5740
#     epoch 41/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3895, train_r2=0.6105, test_loss=0.4004, test_r2=0.5890
#     epoch 42/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3910, train_r2=0.6090, test_loss=0.3993, test_r2=0.5901
#     epoch 43/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3893, train_r2=0.6107, test_loss=0.3984, test_r2=0.5911
#     epoch 44/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4255, train_r2=0.5745, test_loss=0.4294, test_r2=0.5593
#     epoch 45/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3960, train_r2=0.6040, test_loss=0.4065, test_r2=0.5827
#     epoch 46/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3932, train_r2=0.6068, test_loss=0.4012, test_r2=0.5882
#     epoch 47/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4012, train_r2=0.5988, test_loss=0.4091, test_r2=0.5801
#     epoch 48/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3911, train_r2=0.6089, test_loss=0.4023, test_r2=0.5871
#     epoch 49/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3975, train_r2=0.6025, test_loss=0.4107, test_r2=0.5785
#     epoch 50/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3862, train_r2=0.6138, test_loss=0.3943, test_r2=0.5953
#     epoch 51/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3977, train_r2=0.6023, test_loss=0.4053, test_r2=0.5840
#     epoch 52/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4484, train_r2=0.5516, test_loss=0.4534, test_r2=0.5346
#     epoch 53/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3980, train_r2=0.6020, test_loss=0.4110, test_r2=0.5781
#     epoch 54/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3818, train_r2=0.6182, test_loss=0.3921, test_r2=0.5975
#     epoch 55/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3849, train_r2=0.6151, test_loss=0.3935, test_r2=0.5961
#     epoch 56/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3854, train_r2=0.6146, test_loss=0.3937, test_r2=0.5959
#     epoch 57/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3824, train_r2=0.6176, test_loss=0.3914, test_r2=0.5982
#     epoch 58/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3858, train_r2=0.6142, test_loss=0.3960, test_r2=0.5936
#     epoch 59/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3788, train_r2=0.6212, test_loss=0.3878, test_r2=0.6019
#     epoch 60/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3751, train_r2=0.6249, test_loss=0.3866, test_r2=0.6032
#     epoch 61/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4375, train_r2=0.5625, test_loss=0.4433, test_r2=0.5450
#     epoch 62/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3920, train_r2=0.6080, test_loss=0.3978, test_r2=0.5917
#     epoch 63/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3728, train_r2=0.6272, test_loss=0.3796, test_r2=0.6103
#     epoch 64/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3725, train_r2=0.6275, test_loss=0.3824, test_r2=0.6075
#     epoch 65/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3754, train_r2=0.6246, test_loss=0.3824, test_r2=0.6075
#     epoch 66/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3676, train_r2=0.6324, test_loss=0.3746, test_r2=0.6155
#     epoch 67/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3806, train_r2=0.6194, test_loss=0.3857, test_r2=0.6042
#     epoch 68/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3957, train_r2=0.6043, test_loss=0.4035, test_r2=0.5858
#     epoch 69/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4948, train_r2=0.5052, test_loss=0.5054, test_r2=0.4813
#     epoch 70/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3637, train_r2=0.6363, test_loss=0.3695, test_r2=0.6207
#     epoch 71/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3991, train_r2=0.6009, test_loss=0.4008, test_r2=0.5886
#     epoch 72/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3758, train_r2=0.6242, test_loss=0.3786, test_r2=0.6114
#     epoch 73/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3692, train_r2=0.6308, test_loss=0.3739, test_r2=0.6163
#     epoch 74/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3709, train_r2=0.6291, test_loss=0.3751, test_r2=0.6150
#     epoch 75/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3691, train_r2=0.6309, test_loss=0.3735, test_r2=0.6166
#     epoch 76/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3646, train_r2=0.6354, test_loss=0.3694, test_r2=0.6209
#     epoch 77/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3718, train_r2=0.6282, test_loss=0.3751, test_r2=0.6150
#     epoch 78/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3656, train_r2=0.6344, test_loss=0.3689, test_r2=0.6213
#     epoch 79/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3714, train_r2=0.6286, test_loss=0.3738, test_r2=0.6163
#     epoch 80/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3692, train_r2=0.6308, test_loss=0.3754, test_r2=0.6147
#     epoch 81/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3732, train_r2=0.6268, test_loss=0.3819, test_r2=0.6080
#     epoch 82/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3825, train_r2=0.6175, test_loss=0.3845, test_r2=0.6054
#     epoch 83/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3657, train_r2=0.6343, test_loss=0.3690, test_r2=0.6212
#     epoch 84/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3602, train_r2=0.6398, test_loss=0.3647, test_r2=0.6257
#     epoch 85/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3682, train_r2=0.6318, test_loss=0.3694, test_r2=0.6208
#     epoch 86/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3583, train_r2=0.6417, test_loss=0.3623, test_r2=0.6282
#     epoch 87/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3613, train_r2=0.6387, test_loss=0.3635, test_r2=0.6269
#     epoch 88/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3610, train_r2=0.6390, test_loss=0.3637, test_r2=0.6267
#     epoch 89/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3627, train_r2=0.6373, test_loss=0.3663, test_r2=0.6240
#     epoch 90/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4005, train_r2=0.5995, test_loss=0.4010, test_r2=0.5885
#     epoch 91/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3758, train_r2=0.6242, test_loss=0.3806, test_r2=0.6094
#     epoch 92/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3657, train_r2=0.6343, test_loss=0.3680, test_r2=0.6223
#     epoch 93/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3770, train_r2=0.6230, test_loss=0.3806, test_r2=0.6093
#     epoch 94/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3729, train_r2=0.6271, test_loss=0.3745, test_r2=0.6157
#     epoch 95/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3607, train_r2=0.6393, test_loss=0.3643, test_r2=0.6261
#     epoch 96/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3674, train_r2=0.6326, test_loss=0.3731, test_r2=0.6171
#     epoch 97/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3579, train_r2=0.6421, test_loss=0.3592, test_r2=0.6313
#     epoch 98/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3662, train_r2=0.6338, test_loss=0.3699, test_r2=0.6203
#     epoch 99/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3594, train_r2=0.6406, test_loss=0.3615, test_r2=0.6290
#     epoch 100/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3673, train_r2=0.6327, test_loss=0.3675, test_r2=0.6228
#     epoch 101/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3623, train_r2=0.6377, test_loss=0.3629, test_r2=0.6275
#     epoch 102/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3601, train_r2=0.6399, test_loss=0.3604, test_r2=0.6301
#     epoch 103/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3776, train_r2=0.6224, test_loss=0.3774, test_r2=0.6126
#     epoch 104/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3557, train_r2=0.6443, test_loss=0.3606, test_r2=0.6299
#     epoch 105/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3631, train_r2=0.6369, test_loss=0.3701, test_r2=0.6202
#     epoch 106/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3519, train_r2=0.6481, test_loss=0.3582, test_r2=0.6323
#     epoch 107/200 | np | lr=0.027, sigma=0.1 | train_loss=0.4037, train_r2=0.5963, test_loss=0.4045, test_r2=0.5848
#     epoch 108/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3449, train_r2=0.6551, test_loss=0.3481, test_r2=0.6427
#     epoch 109/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3651, train_r2=0.6349, test_loss=0.3650, test_r2=0.6254
#     epoch 110/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3775, train_r2=0.6225, test_loss=0.3767, test_r2=0.6133
#     epoch 111/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3533, train_r2=0.6467, test_loss=0.3554, test_r2=0.6353
#     epoch 112/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3653, train_r2=0.6347, test_loss=0.3669, test_r2=0.6235
#     epoch 113/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3471, train_r2=0.6529, test_loss=0.3514, test_r2=0.6394
#     epoch 114/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3695, train_r2=0.6305, test_loss=0.3719, test_r2=0.6183
#     epoch 115/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3496, train_r2=0.6504, test_loss=0.3541, test_r2=0.6366
#     epoch 116/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3441, train_r2=0.6559, test_loss=0.3485, test_r2=0.6423
#     epoch 117/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3483, train_r2=0.6517, test_loss=0.3504, test_r2=0.6404
#     epoch 118/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3815, train_r2=0.6185, test_loss=0.3778, test_r2=0.6123
#     epoch 119/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3550, train_r2=0.6450, test_loss=0.3536, test_r2=0.6370
#     epoch 120/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3409, train_r2=0.6591, test_loss=0.3423, test_r2=0.6487
#     epoch 121/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3370, train_r2=0.6630, test_loss=0.3366, test_r2=0.6545
#     epoch 122/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3437, train_r2=0.6563, test_loss=0.3439, test_r2=0.6471
#     epoch 123/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3404, train_r2=0.6596, test_loss=0.3439, test_r2=0.6471
#     epoch 124/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3438, train_r2=0.6562, test_loss=0.3480, test_r2=0.6428
#     epoch 125/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3481, train_r2=0.6519, test_loss=0.3488, test_r2=0.6420
#     epoch 126/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3538, train_r2=0.6462, test_loss=0.3538, test_r2=0.6369
#     epoch 127/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3391, train_r2=0.6609, test_loss=0.3449, test_r2=0.6460
#     epoch 128/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3372, train_r2=0.6628, test_loss=0.3422, test_r2=0.6488
#     epoch 129/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3426, train_r2=0.6574, test_loss=0.3503, test_r2=0.6405
#     epoch 130/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3432, train_r2=0.6568, test_loss=0.3524, test_r2=0.6383
#     epoch 131/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3377, train_r2=0.6623, test_loss=0.3454, test_r2=0.6455
#     epoch 132/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3436, train_r2=0.6564, test_loss=0.3518, test_r2=0.6389
#     epoch 133/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3468, train_r2=0.6532, test_loss=0.3554, test_r2=0.6352
#     epoch 134/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3588, train_r2=0.6412, test_loss=0.3687, test_r2=0.6216
#     epoch 135/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3478, train_r2=0.6522, test_loss=0.3509, test_r2=0.6398
#     epoch 136/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3404, train_r2=0.6596, test_loss=0.3447, test_r2=0.6462
#     epoch 137/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3415, train_r2=0.6585, test_loss=0.3495, test_r2=0.6413
#     epoch 138/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3517, train_r2=0.6483, test_loss=0.3623, test_r2=0.6282
#     epoch 139/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3423, train_r2=0.6577, test_loss=0.3511, test_r2=0.6396
#     epoch 140/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3411, train_r2=0.6589, test_loss=0.3473, test_r2=0.6435
#     epoch 141/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3577, train_r2=0.6423, test_loss=0.3626, test_r2=0.6278
#     epoch 142/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3471, train_r2=0.6529, test_loss=0.3536, test_r2=0.6371
#     epoch 143/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3457, train_r2=0.6543, test_loss=0.3551, test_r2=0.6356
#     epoch 144/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3408, train_r2=0.6592, test_loss=0.3489, test_r2=0.6419
#     epoch 145/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3351, train_r2=0.6649, test_loss=0.3434, test_r2=0.6475
#     epoch 146/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3493, train_r2=0.6507, test_loss=0.3552, test_r2=0.6354
#     epoch 147/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3449, train_r2=0.6551, test_loss=0.3552, test_r2=0.6354
#     epoch 148/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3487, train_r2=0.6513, test_loss=0.3568, test_r2=0.6338
#     epoch 149/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3424, train_r2=0.6576, test_loss=0.3477, test_r2=0.6431
#     epoch 150/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3430, train_r2=0.6570, test_loss=0.3491, test_r2=0.6417
#     epoch 151/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3408, train_r2=0.6592, test_loss=0.3470, test_r2=0.6438
#     epoch 152/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3386, train_r2=0.6614, test_loss=0.3452, test_r2=0.6457
#     epoch 153/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3461, train_r2=0.6539, test_loss=0.3501, test_r2=0.6406
#     epoch 154/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3390, train_r2=0.6610, test_loss=0.3419, test_r2=0.6491
#     epoch 155/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3403, train_r2=0.6597, test_loss=0.3443, test_r2=0.6466
#     epoch 156/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3486, train_r2=0.6514, test_loss=0.3517, test_r2=0.6390
#     epoch 157/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3478, train_r2=0.6522, test_loss=0.3496, test_r2=0.6411
#     epoch 158/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3366, train_r2=0.6634, test_loss=0.3386, test_r2=0.6525
#     epoch 159/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3345, train_r2=0.6655, test_loss=0.3373, test_r2=0.6538
#     epoch 160/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3427, train_r2=0.6573, test_loss=0.3449, test_r2=0.6460
#     epoch 161/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3518, train_r2=0.6482, test_loss=0.3570, test_r2=0.6336
#     epoch 162/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3437, train_r2=0.6563, test_loss=0.3463, test_r2=0.6446
#     epoch 163/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3472, train_r2=0.6528, test_loss=0.3482, test_r2=0.6426
#     epoch 164/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3468, train_r2=0.6532, test_loss=0.3499, test_r2=0.6409
#     epoch 165/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3367, train_r2=0.6633, test_loss=0.3372, test_r2=0.6539
#     epoch 166/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3329, train_r2=0.6671, test_loss=0.3319, test_r2=0.6594
#     epoch 167/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3318, train_r2=0.6682, test_loss=0.3309, test_r2=0.6603
#     epoch 168/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3304, train_r2=0.6696, test_loss=0.3312, test_r2=0.6601
#     epoch 169/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3349, train_r2=0.6651, test_loss=0.3343, test_r2=0.6569
#     epoch 170/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3543, train_r2=0.6457, test_loss=0.3527, test_r2=0.6380
#     epoch 171/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3431, train_r2=0.6569, test_loss=0.3414, test_r2=0.6496
#     epoch 172/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3480, train_r2=0.6520, test_loss=0.3481, test_r2=0.6427
#     epoch 173/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3371, train_r2=0.6629, test_loss=0.3379, test_r2=0.6532
#     epoch 174/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3391, train_r2=0.6609, test_loss=0.3404, test_r2=0.6506
#     epoch 175/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3503, train_r2=0.6497, test_loss=0.3507, test_r2=0.6400
#     epoch 176/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3395, train_r2=0.6605, test_loss=0.3395, test_r2=0.6515
#     epoch 177/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3354, train_r2=0.6646, test_loss=0.3350, test_r2=0.6561
#     epoch 178/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3487, train_r2=0.6513, test_loss=0.3478, test_r2=0.6430
#     epoch 179/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3427, train_r2=0.6573, test_loss=0.3425, test_r2=0.6484
#     epoch 180/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3375, train_r2=0.6625, test_loss=0.3419, test_r2=0.6491
#     epoch 181/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3350, train_r2=0.6650, test_loss=0.3377, test_r2=0.6534
#     epoch 182/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3361, train_r2=0.6639, test_loss=0.3389, test_r2=0.6522
#     epoch 183/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3606, train_r2=0.6394, test_loss=0.3582, test_r2=0.6324
#     epoch 184/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3327, train_r2=0.6673, test_loss=0.3326, test_r2=0.6586
#     epoch 185/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3285, train_r2=0.6715, test_loss=0.3304, test_r2=0.6609
#     epoch 186/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3297, train_r2=0.6703, test_loss=0.3298, test_r2=0.6615
#     epoch 187/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3624, train_r2=0.6376, test_loss=0.3586, test_r2=0.6319
#     epoch 188/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3330, train_r2=0.6670, test_loss=0.3316, test_r2=0.6596
#     epoch 189/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3328, train_r2=0.6672, test_loss=0.3345, test_r2=0.6566
#     epoch 190/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3343, train_r2=0.6657, test_loss=0.3363, test_r2=0.6549
#     epoch 191/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3439, train_r2=0.6561, test_loss=0.3453, test_r2=0.6456
#     epoch 192/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3373, train_r2=0.6627, test_loss=0.3407, test_r2=0.6503
#     epoch 193/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3370, train_r2=0.6630, test_loss=0.3389, test_r2=0.6521
#     epoch 194/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3384, train_r2=0.6616, test_loss=0.3366, test_r2=0.6545
#     epoch 195/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3414, train_r2=0.6586, test_loss=0.3385, test_r2=0.6525
#     epoch 196/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3402, train_r2=0.6598, test_loss=0.3381, test_r2=0.6529
#     epoch 197/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3364, train_r2=0.6636, test_loss=0.3333, test_r2=0.6579
#     epoch 198/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3292, train_r2=0.6708, test_loss=0.3265, test_r2=0.6649
#     epoch 199/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3321, train_r2=0.6679, test_loss=0.3271, test_r2=0.6642
#     epoch 200/200 | np | lr=0.027, sigma=0.1 | train_loss=0.3377, train_r2=0.6623, test_loss=0.3360, test_r2=0.6552
#
# ### Final run | np_fan_in | lr=0.0175, sigma=0.0525
#     epoch  1/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=1.0197, train_r2=-0.0197, test_loss=1.0036, test_r2=-0.0301
#     epoch  2/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.9474, train_r2=0.0526, test_loss=0.9277, test_r2=0.0478
#     epoch  3/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.9034, train_r2=0.0966, test_loss=0.8833, test_r2=0.0933
#     epoch  4/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.8349, train_r2=0.1651, test_loss=0.8222, test_r2=0.1561
#     epoch  5/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.7681, train_r2=0.2319, test_loss=0.7594, test_r2=0.2205
#     epoch  6/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.7297, train_r2=0.2703, test_loss=0.7334, test_r2=0.2472
#     epoch  7/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.6096, train_r2=0.3904, test_loss=0.6151, test_r2=0.3686
#     epoch  8/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.5641, train_r2=0.4359, test_loss=0.5747, test_r2=0.4101
#     epoch  9/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.5394, train_r2=0.4606, test_loss=0.5556, test_r2=0.4297
#     epoch 10/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.5062, train_r2=0.4938, test_loss=0.5227, test_r2=0.4635
#     epoch 11/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.5092, train_r2=0.4908, test_loss=0.5252, test_r2=0.4609
#     epoch 12/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4855, train_r2=0.5145, test_loss=0.5038, test_r2=0.4829
#     epoch 13/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4793, train_r2=0.5207, test_loss=0.4989, test_r2=0.4879
#     epoch 14/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4786, train_r2=0.5214, test_loss=0.4983, test_r2=0.4885
#     epoch 15/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4916, train_r2=0.5084, test_loss=0.5123, test_r2=0.4742
#     epoch 16/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4649, train_r2=0.5351, test_loss=0.4821, test_r2=0.5051
#     epoch 17/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4502, train_r2=0.5498, test_loss=0.4693, test_r2=0.5183
#     epoch 18/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4556, train_r2=0.5444, test_loss=0.4735, test_r2=0.5141
#     epoch 19/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4483, train_r2=0.5517, test_loss=0.4678, test_r2=0.5198
#     epoch 20/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4467, train_r2=0.5533, test_loss=0.4664, test_r2=0.5213
#     epoch 21/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.5217, train_r2=0.4783, test_loss=0.5337, test_r2=0.4522
#     epoch 22/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4582, train_r2=0.5418, test_loss=0.4753, test_r2=0.5121
#     epoch 23/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4410, train_r2=0.5590, test_loss=0.4618, test_r2=0.5260
#     epoch 24/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4356, train_r2=0.5644, test_loss=0.4554, test_r2=0.5325
#     epoch 25/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4419, train_r2=0.5581, test_loss=0.4599, test_r2=0.5280
#     epoch 26/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4375, train_r2=0.5625, test_loss=0.4567, test_r2=0.5312
#     epoch 27/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4345, train_r2=0.5655, test_loss=0.4504, test_r2=0.5377
#     epoch 28/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4680, train_r2=0.5320, test_loss=0.4813, test_r2=0.5060
#     epoch 29/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4311, train_r2=0.5689, test_loss=0.4485, test_r2=0.5397
#     epoch 30/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4619, train_r2=0.5381, test_loss=0.4732, test_r2=0.5143
#     epoch 31/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4228, train_r2=0.5772, test_loss=0.4357, test_r2=0.5528
#     epoch 32/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4359, train_r2=0.5641, test_loss=0.4508, test_r2=0.5373
#     epoch 33/200 | np_fan_in | lr=0.0175, sigma=0.0525 | train_loss=0.4212, train_r2=0.5788, test_loss=0.4361, test_r2=0.5524
# ...
#     epoch 72/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3733, train_r2=0.6267, test_loss=0.3782, test_r2=0.6118
#     epoch 73/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3890, train_r2=0.6110, test_loss=0.3855, test_r2=0.6043
#     epoch 74/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3657, train_r2=0.6343, test_loss=0.3655, test_r2=0.6249
#     epoch 75/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3619, train_r2=0.6381, test_loss=0.3602, test_r2=0.6303
#     epoch 76/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3554, train_r2=0.6446, test_loss=0.3519, test_r2=0.6388
#     epoch 77/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3512, train_r2=0.6488, test_loss=0.3528, test_r2=0.6379
#     epoch 78/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3541, train_r2=0.6459, test_loss=0.3524, test_r2=0.6383
#     epoch 79/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3516, train_r2=0.6484, test_loss=0.3550, test_r2=0.6356
#     epoch 80/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3553, train_r2=0.6447, test_loss=0.3607, test_r2=0.6298
#     epoch 81/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3648, train_r2=0.6352, test_loss=0.3721, test_r2=0.6181
#     epoch 82/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3607, train_r2=0.6393, test_loss=0.3633, test_r2=0.6272
#     epoch 83/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3443, train_r2=0.6557, test_loss=0.3445, test_r2=0.6464
#     epoch 84/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3498, train_r2=0.6502, test_loss=0.3463, test_r2=0.6445
#     epoch 85/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3506, train_r2=0.6494, test_loss=0.3469, test_r2=0.6439
#     epoch 86/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3539, train_r2=0.6461, test_loss=0.3525, test_r2=0.6382
#     epoch 87/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3703, train_r2=0.6297, test_loss=0.3731, test_r2=0.6171
#     epoch 88/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3573, train_r2=0.6427, test_loss=0.3607, test_r2=0.6298
#     epoch 89/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3505, train_r2=0.6495, test_loss=0.3531, test_r2=0.6375
#     epoch 90/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3492, train_r2=0.6508, test_loss=0.3550, test_r2=0.6357
#     epoch 91/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3423, train_r2=0.6577, test_loss=0.3480, test_r2=0.6428
#     epoch 92/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3543, train_r2=0.6457, test_loss=0.3584, test_r2=0.6321
#     epoch 93/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3372, train_r2=0.6628, test_loss=0.3400, test_r2=0.6511
#     epoch 94/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3470, train_r2=0.6530, test_loss=0.3483, test_r2=0.6425
#     epoch 95/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3422, train_r2=0.6578, test_loss=0.3392, test_r2=0.6519
#     epoch 96/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3423, train_r2=0.6577, test_loss=0.3394, test_r2=0.6516
#     epoch 97/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3400, train_r2=0.6600, test_loss=0.3414, test_r2=0.6496
#     epoch 98/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3437, train_r2=0.6563, test_loss=0.3450, test_r2=0.6459
#     epoch 99/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3463, train_r2=0.6537, test_loss=0.3540, test_r2=0.6366
#     epoch 100/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3502, train_r2=0.6498, test_loss=0.3524, test_r2=0.6383
#     epoch 101/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3459, train_r2=0.6541, test_loss=0.3497, test_r2=0.6411
#     epoch 102/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3471, train_r2=0.6529, test_loss=0.3429, test_r2=0.6480
#     epoch 103/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3268, train_r2=0.6732, test_loss=0.3276, test_r2=0.6637
#     epoch 104/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3309, train_r2=0.6691, test_loss=0.3296, test_r2=0.6617
#     epoch 105/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3320, train_r2=0.6680, test_loss=0.3294, test_r2=0.6619
#     epoch 106/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3282, train_r2=0.6718, test_loss=0.3258, test_r2=0.6656
#     epoch 107/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3331, train_r2=0.6669, test_loss=0.3401, test_r2=0.6509
#     epoch 108/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3449, train_r2=0.6551, test_loss=0.3411, test_r2=0.6499
#     epoch 109/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3346, train_r2=0.6654, test_loss=0.3325, test_r2=0.6587
#     epoch 110/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3323, train_r2=0.6677, test_loss=0.3303, test_r2=0.6610
#     epoch 111/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3478, train_r2=0.6522, test_loss=0.3457, test_r2=0.6452
#     epoch 112/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3381, train_r2=0.6619, test_loss=0.3307, test_r2=0.6606
#     epoch 113/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3395, train_r2=0.6605, test_loss=0.3389, test_r2=0.6522
#     epoch 114/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3729, train_r2=0.6271, test_loss=0.3744, test_r2=0.6157
#     epoch 115/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3638, train_r2=0.6362, test_loss=0.3620, test_r2=0.6285
#     epoch 116/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3308, train_r2=0.6692, test_loss=0.3280, test_r2=0.6634
#     epoch 117/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3354, train_r2=0.6646, test_loss=0.3301, test_r2=0.6612
#     epoch 118/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3466, train_r2=0.6534, test_loss=0.3404, test_r2=0.6506
#     epoch 119/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3367, train_r2=0.6633, test_loss=0.3286, test_r2=0.6627
#     epoch 120/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3407, train_r2=0.6593, test_loss=0.3371, test_r2=0.6540
#     epoch 121/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3320, train_r2=0.6680, test_loss=0.3236, test_r2=0.6678
#     epoch 122/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3312, train_r2=0.6688, test_loss=0.3253, test_r2=0.6661
#     epoch 123/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3441, train_r2=0.6559, test_loss=0.3430, test_r2=0.6480
#     epoch 124/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3369, train_r2=0.6631, test_loss=0.3361, test_r2=0.6550
#     epoch 125/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3636, train_r2=0.6364, test_loss=0.3619, test_r2=0.6286
#     epoch 126/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3550, train_r2=0.6450, test_loss=0.3564, test_r2=0.6342
#     epoch 127/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3514, train_r2=0.6486, test_loss=0.3480, test_r2=0.6429
#     epoch 128/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3467, train_r2=0.6533, test_loss=0.3405, test_r2=0.6505
#     epoch 129/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3397, train_r2=0.6603, test_loss=0.3404, test_r2=0.6506
#     epoch 130/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3214, train_r2=0.6786, test_loss=0.3217, test_r2=0.6699
#     epoch 131/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3532, train_r2=0.6468, test_loss=0.3537, test_r2=0.6370
#     epoch 132/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3540, train_r2=0.6460, test_loss=0.3572, test_r2=0.6333
#     epoch 133/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3590, train_r2=0.6410, test_loss=0.3624, test_r2=0.6281
#     epoch 134/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3444, train_r2=0.6556, test_loss=0.3492, test_r2=0.6416
#     epoch 135/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3532, train_r2=0.6468, test_loss=0.3504, test_r2=0.6404
#     epoch 136/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3409, train_r2=0.6591, test_loss=0.3401, test_r2=0.6510
#     epoch 137/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3295, train_r2=0.6705, test_loss=0.3337, test_r2=0.6575
#     epoch 138/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3322, train_r2=0.6678, test_loss=0.3295, test_r2=0.6618
#     epoch 139/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3395, train_r2=0.6605, test_loss=0.3391, test_r2=0.6519
#     epoch 140/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3448, train_r2=0.6552, test_loss=0.3433, test_r2=0.6477
#     epoch 141/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3229, train_r2=0.6771, test_loss=0.3242, test_r2=0.6672
#     epoch 142/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3307, train_r2=0.6693, test_loss=0.3305, test_r2=0.6608
#     epoch 143/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3280, train_r2=0.6720, test_loss=0.3260, test_r2=0.6654
#     epoch 144/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3344, train_r2=0.6656, test_loss=0.3411, test_r2=0.6499
#     epoch 145/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3274, train_r2=0.6726, test_loss=0.3342, test_r2=0.6570
#     epoch 146/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3358, train_r2=0.6642, test_loss=0.3431, test_r2=0.6478
#     epoch 147/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3463, train_r2=0.6537, test_loss=0.3507, test_r2=0.6401
#     epoch 148/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3443, train_r2=0.6557, test_loss=0.3540, test_r2=0.6367
#     epoch 149/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3432, train_r2=0.6568, test_loss=0.3494, test_r2=0.6414
#     epoch 150/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3680, train_r2=0.6320, test_loss=0.3736, test_r2=0.6165
#     epoch 151/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3667, train_r2=0.6333, test_loss=0.3692, test_r2=0.6211
#     epoch 152/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3565, train_r2=0.6435, test_loss=0.3590, test_r2=0.6316
#     epoch 153/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3520, train_r2=0.6480, test_loss=0.3509, test_r2=0.6399
#     epoch 154/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3711, train_r2=0.6289, test_loss=0.3608, test_r2=0.6297
#     epoch 155/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3525, train_r2=0.6475, test_loss=0.3492, test_r2=0.6416
#     epoch 156/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3471, train_r2=0.6529, test_loss=0.3421, test_r2=0.6489
#     epoch 157/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3512, train_r2=0.6488, test_loss=0.3462, test_r2=0.6447
#     epoch 158/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3549, train_r2=0.6451, test_loss=0.3493, test_r2=0.6415
#     epoch 159/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3553, train_r2=0.6447, test_loss=0.3531, test_r2=0.6375
#     epoch 160/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3465, train_r2=0.6535, test_loss=0.3451, test_r2=0.6457
#     epoch 161/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3551, train_r2=0.6449, test_loss=0.3507, test_r2=0.6401
#     epoch 162/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3671, train_r2=0.6329, test_loss=0.3675, test_r2=0.6228
#     epoch 163/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3505, train_r2=0.6495, test_loss=0.3510, test_r2=0.6398
#     epoch 164/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3435, train_r2=0.6565, test_loss=0.3458, test_r2=0.6451
#     epoch 165/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3474, train_r2=0.6526, test_loss=0.3506, test_r2=0.6401
#     epoch 166/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3497, train_r2=0.6503, test_loss=0.3508, test_r2=0.6400
#     epoch 167/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3479, train_r2=0.6521, test_loss=0.3475, test_r2=0.6433
#     epoch 168/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3595, train_r2=0.6405, test_loss=0.3590, test_r2=0.6315
#     epoch 169/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3508, train_r2=0.6492, test_loss=0.3524, test_r2=0.6383
#     epoch 170/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3597, train_r2=0.6403, test_loss=0.3662, test_r2=0.6241
#     epoch 171/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3600, train_r2=0.6400, test_loss=0.3715, test_r2=0.6187
#     epoch 172/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3536, train_r2=0.6464, test_loss=0.3625, test_r2=0.6279
#     epoch 173/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3511, train_r2=0.6489, test_loss=0.3589, test_r2=0.6316
#     epoch 174/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3504, train_r2=0.6496, test_loss=0.3624, test_r2=0.6280
#     epoch 175/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3471, train_r2=0.6529, test_loss=0.3525, test_r2=0.6382
#     epoch 176/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3559, train_r2=0.6441, test_loss=0.3577, test_r2=0.6329
#     epoch 177/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3485, train_r2=0.6515, test_loss=0.3508, test_r2=0.6399
#     epoch 178/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3517, train_r2=0.6483, test_loss=0.3541, test_r2=0.6366
#     epoch 179/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3580, train_r2=0.6420, test_loss=0.3605, test_r2=0.6300
#     epoch 180/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3601, train_r2=0.6399, test_loss=0.3617, test_r2=0.6288
#     epoch 181/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3671, train_r2=0.6329, test_loss=0.3683, test_r2=0.6220
#     epoch 182/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3600, train_r2=0.6400, test_loss=0.3623, test_r2=0.6281
#     epoch 183/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3648, train_r2=0.6352, test_loss=0.3747, test_r2=0.6154
#     epoch 184/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3731, train_r2=0.6269, test_loss=0.3751, test_r2=0.6150
#     epoch 185/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3771, train_r2=0.6229, test_loss=0.3895, test_r2=0.6002
#     epoch 186/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3682, train_r2=0.6318, test_loss=0.3736, test_r2=0.6166
#     epoch 187/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3611, train_r2=0.6389, test_loss=0.3579, test_r2=0.6326
#     epoch 188/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3625, train_r2=0.6375, test_loss=0.3608, test_r2=0.6297
#     epoch 189/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3550, train_r2=0.6450, test_loss=0.3515, test_r2=0.6392
#     epoch 190/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3670, train_r2=0.6330, test_loss=0.3664, test_r2=0.6239
#     epoch 191/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3669, train_r2=0.6331, test_loss=0.3628, test_r2=0.6276
#     epoch 192/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3565, train_r2=0.6435, test_loss=0.3533, test_r2=0.6374
#     epoch 193/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3661, train_r2=0.6339, test_loss=0.3619, test_r2=0.6285
#     epoch 194/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3545, train_r2=0.6455, test_loss=0.3562, test_r2=0.6344
#     epoch 195/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3708, train_r2=0.6292, test_loss=0.3692, test_r2=0.6211
#     epoch 196/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3581, train_r2=0.6419, test_loss=0.3582, test_r2=0.6323
#     epoch 197/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3547, train_r2=0.6453, test_loss=0.3522, test_r2=0.6385
#     epoch 198/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3621, train_r2=0.6379, test_loss=0.3568, test_r2=0.6338
#     epoch 199/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3661, train_r2=0.6339, test_loss=0.3675, test_r2=0.6228
#     epoch 200/200 | wp | lr=0.0135, sigma=0.1 | train_loss=0.3618, train_r2=0.6382, test_loss=0.3633, test_r2=0.6271
#       method  final_train_loss  final_train_r2  final_test_loss  \
# 0         bp          0.260549        0.739451         0.260924
# 1         np          0.337691        0.662309         0.335956
# 2  np_fan_in          0.330074        0.669926         0.337289
# 3   np_fixed          0.344832        0.655168         0.348102
# 4         wp          0.361822        0.638178         0.363323
#
#    final_test_r2  best_test_loss  best_test_r2  diverged  duration_sec
# 0       0.732189        0.259873      0.733268     False     50.858857
# 1       0.655177        0.326509      0.664873     False     50.469848
# 2       0.653809        0.322908      0.668569     False     49.697999
# 3       0.642710        0.316814      0.674824     False     49.957955
# 4       0.627087        0.321657      0.669853     False     50.028522

# %% [markdown]
# # Frozen-Backprop Estimator Analysis
#
# Train only backprop, freeze the weights after 1/3, 2/3, and 3/3 of training, then evaluate perturbation estimators on a full epoch of batches.
# For each batch and method, sample 50 perturbations, compute the average sample cosine to the true gradient, the cosine of the mean estimator, and the sample variance around the mean estimator.

# %%
# Frozen-backprop estimator analysis.
# Uses the same sigma values as the current hand-picked final run, but no learning rate.

ANALYSIS_EPOCHS = 50
ANALYSIS_SEED = 0
ANALYSIS_BP_LR = 0.01
ANALYSIS_NUM_PERTURBATIONS = 50
ANALYSIS_BATCH_SIZE = BATCH_SIZE
ANALYSIS_CHECKPOINT_EPOCHS = sorted({max(1, 1), max(1, (ANALYSIS_EPOCHS) // 2), ANALYSIS_EPOCHS})
ANALYSIS_METHOD_SIGMAS = {
    "np": 0.1,
    "np_fan_in": 0.0525,
    "np_fixed": 0.45,
    "wp": 0.1,
}

print(
    f"Running frozen estimator analysis | epochs={ANALYSIS_EPOCHS}, seed={ANALYSIS_SEED}, "
    f"bp_lr={ANALYSIS_BP_LR}, checkpoints={ANALYSIS_CHECKPOINT_EPOCHS}, "
    f"num_perturbations={ANALYSIS_NUM_PERTURBATIONS}, batch_size={ANALYSIS_BATCH_SIZE}"
)
print(ANALYSIS_METHOD_SIGMAS)

checkpoint_states = train_backprop_checkpoint_states(
    data=data,
    dimensions=DIMENSIONS,
    epochs=ANALYSIS_EPOCHS,
    seed=ANALYSIS_SEED,
    device=device,
    lr=ANALYSIS_BP_LR,
    checkpoint_epochs=ANALYSIS_CHECKPOINT_EPOCHS,
    print_every_epoch=max(1, ANALYSIS_EPOCHS // 10),
)

frozen_stats_df = analyze_frozen_backprop_estimators(
    checkpoint_states=checkpoint_states,
    data=data,
    dimensions=DIMENSIONS,
    device=device,
    method_sigmas=ANALYSIS_METHOD_SIGMAS,
    num_perturbations=ANALYSIS_NUM_PERTURBATIONS,
    batch_size=ANALYSIS_BATCH_SIZE,
)

display(frozen_stats_df.sort_values(["layer_index", "checkpoint_epoch", "method"]).reset_index(drop=True))
plot_frozen_estimator_statistics(frozen_stats_df)
# Out:
# Running frozen estimator analysis | epochs=50, seed=0, bp_lr=0.01, checkpoints=[1, 25, 50], num_perturbations=50, batch_size=256
# {'np': 0.1, 'np_fan_in': 0.0525, 'np_fixed': 0.45, 'wp': 0.1}
#     bp checkpoint training epoch    1/50 | train_loss=0.9867, train_r2=0.0133, test_loss=0.9613, test_r2=0.0133
#     bp checkpoint training epoch    5/50 | train_loss=0.9224, train_r2=0.0776, test_loss=0.9006, test_r2=0.0756
#     bp checkpoint training epoch   10/50 | train_loss=0.7477, train_r2=0.2523, test_loss=0.7384, test_r2=0.2421
#     bp checkpoint training epoch   15/50 | train_loss=0.5255, train_r2=0.4745, test_loss=0.5350, test_r2=0.4509
#     bp checkpoint training epoch   20/50 | train_loss=0.4503, train_r2=0.5497, test_loss=0.4670, test_r2=0.5206
#     bp checkpoint training epoch   25/50 | train_loss=0.4311, train_r2=0.5689, test_loss=0.4474, test_r2=0.5408
#     bp checkpoint training epoch   30/50 | train_loss=0.4184, train_r2=0.5816, test_loss=0.4333, test_r2=0.5553
#     bp checkpoint training epoch   35/50 | train_loss=0.4078, train_r2=0.5922, test_loss=0.4214, test_r2=0.5674
#     bp checkpoint training epoch   40/50 | train_loss=0.3990, train_r2=0.6010, test_loss=0.4108, test_r2=0.5783
#     bp checkpoint training epoch   45/50 | train_loss=0.3900, train_r2=0.6100, test_loss=0.4013, test_r2=0.5881
#     bp checkpoint training epoch   50/50 | train_loss=0.3836, train_r2=0.6164, test_loss=0.3942, test_r2=0.5954
#     checkpoint_epoch  checkpoint_fraction     method   sigma component  \
# 0                  1                 0.02         np  0.1000       all
# 1                  1                 0.02  np_fan_in  0.0525       all
# 2                  1                 0.02   np_fixed  0.4500       all
# 3                  1                 0.02         wp  0.1000       all
# 4                 25                 0.50         np  0.1000       all
# 5                 25                 0.50  np_fan_in  0.0525       all
# 6                 25                 0.50   np_fixed  0.4500       all
# 7                 25                 0.50         wp  0.1000       all
# 8                 50                 1.00         np  0.1000       all
# 9                 50                 1.00  np_fan_in  0.0525       all
# 10                50                 1.00   np_fixed  0.4500       all
# 11                50                 1.00         wp  0.1000       all
# 12                 1                 0.02         np  0.1000   layer_1
# 13                 1                 0.02  np_fan_in  0.0525   layer_1
# 14                 1                 0.02   np_fixed  0.4500   layer_1
# 15                 1                 0.02         wp  0.1000   layer_1
# 16                25                 0.50         np  0.1000   layer_1
# 17                25                 0.50  np_fan_in  0.0525   layer_1
# 18                25                 0.50   np_fixed  0.4500   layer_1
# 19                25                 0.50         wp  0.1000   layer_1
# 20                50                 1.00         np  0.1000   layer_1
# 21                50                 1.00  np_fan_in  0.0525   layer_1
# 22                50                 1.00   np_fixed  0.4500   layer_1
# 23                50                 1.00         wp  0.1000   layer_1
# 24                 1                 0.02         np  0.1000   layer_2
# 25                 1                 0.02  np_fan_in  0.0525   layer_2
# 26                 1                 0.02   np_fixed  0.4500   layer_2
# 27                 1                 0.02         wp  0.1000   layer_2
# 28                25                 0.50         np  0.1000   layer_2
# 29                25                 0.50  np_fan_in  0.0525   layer_2
# 30                25                 0.50   np_fixed  0.4500   layer_2
# 31                25                 0.50         wp  0.1000   layer_2
# 32                50                 1.00         np  0.1000   layer_2
# 33                50                 1.00  np_fan_in  0.0525   layer_2
# 34                50                 1.00   np_fixed  0.4500   layer_2
# 35                50                 1.00         wp  0.1000   layer_2
# 36                 1                 0.02         np  0.1000   layer_3
# 37                 1                 0.02  np_fan_in  0.0525   layer_3
# 38                 1                 0.02   np_fixed  0.4500   layer_3
# 39                 1                 0.02         wp  0.1000   layer_3
# 40                25                 0.50         np  0.1000   layer_3
# 41                25                 0.50  np_fan_in  0.0525   layer_3
# 42                25                 0.50   np_fixed  0.4500   layer_3
# 43                25                 0.50         wp  0.1000   layer_3
# 44                50                 1.00         np  0.1000   layer_3
# 45                50                 1.00  np_fan_in  0.0525   layer_3
# 46                50                 1.00   np_fixed  0.4500   layer_3
# 47                50                 1.00         wp  0.1000   layer_3
#
#    component_label  layer_index  avg_sample_cosine  mean_estimate_cosine  \
# 0       All layers           -1           0.032383              0.226024
# 1       All layers           -1           0.016235              0.116235
# 2       All layers           -1           0.031182              0.218277
# 3       All layers           -1           0.004185              0.030950
# 4       All layers           -1           0.033620              0.209378
# 5       All layers           -1           0.020499              0.134791
# 6       All layers           -1           0.034741              0.215628
# 7       All layers           -1           0.005103              0.036274
# 8       All layers           -1           0.070219              0.378606
# 9       All layers           -1           0.046867              0.273331
# 10      All layers           -1           0.070235              0.366796
# 11      All layers           -1           0.009983              0.066321
# 12         Layer 1            0          -0.000399             -0.003216
# 13         Layer 1            0           0.000890              0.004912
# 14         Layer 1            0           0.002781              0.021359
# 15         Layer 1            0           0.000561              0.004192
# 16         Layer 1            0           0.007200              0.051144
# 17         Layer 1            0           0.004623              0.031475
# 18         Layer 1            0           0.010806              0.076801
# 19         Layer 1            0           0.002842              0.021231
# 20         Layer 1            0           0.008491              0.059771
# 21         Layer 1            0           0.004915              0.035343
# 22         Layer 1            0           0.012524              0.087726
# 23         Layer 1            0           0.002418              0.016405
# 24         Layer 2            1           0.015269              0.108348
# 25         Layer 2            1           0.017041              0.123157
# 26         Layer 2            1           0.013595              0.098195
# 27         Layer 2            1           0.001366              0.009978
# 28         Layer 2            1           0.032363              0.204847
# 29         Layer 2            1           0.032577              0.204631
# 30         Layer 2            1           0.024821              0.161839
# 31         Layer 2            1           0.003144              0.022389
# 32         Layer 2            1           0.067392              0.370759
# 33         Layer 2            1           0.075928              0.405034
# 34         Layer 2            1           0.051772              0.296841
# 35         Layer 2            1           0.006228              0.041547
# 36         Layer 3            2           0.306281              0.940523
# 37         Layer 3            2           0.263713              0.883498
# 38         Layer 3            2           0.297330              0.898375
# 39         Layer 3            2           0.046849              0.308780
# 40         Layer 3            2           0.198674              0.486387
# 41         Layer 3            2           0.182128              0.324467
# 42         Layer 3            2           0.203538              0.491729
# 43         Layer 3            2           0.045466              0.257307
# 44         Layer 3            2           0.432090              0.707224
# 45         Layer 3            2           0.410810              0.708006
# 46         Layer 3            2           0.426116              0.752033
# 47         Layer 3            2           0.096287              0.458984
#
#     sample_variance  batch_variance
# 0          0.025856        0.000521
# 1          0.106312        0.002128
# 2          0.027671        0.000548
# 3          1.266041        0.025280
# 4          0.011482        0.000241
# 5          0.108604        0.002190
# 6          0.018830        0.000378
# 7          0.564638        0.011309
# 8          0.010307        0.000221
# 9          0.136300        0.002600
# 10         0.022829        0.000438
# 11         0.506035        0.010135
# 12         0.140821        0.002842
# 13         0.805560        0.016135
# 14         0.102317        0.002074
# 15         1.264858        0.025187
# 16         0.062385        0.001263
# 17         0.862167        0.017287
# 18         0.099537        0.001982
# 19         0.565460        0.011396
# 20         0.055925        0.001132
# 21         1.092953        0.020718
# 22         0.137765        0.002536
# 23         0.506367        0.010139
# 24         0.009812        0.000197
# 25         0.009376        0.000185
# 26         0.017286        0.000335
# 27         1.266116        0.025289
# 28         0.004359        0.000091
# 29         0.004201        0.000091
# 30         0.007620        0.000152
# 31         0.564505        0.011291
# 32         0.003914        0.000082
# 33         0.003778        0.000080
# 34         0.006878        0.000141
# 35         0.505947        0.010121
# 36         0.026190        0.000616
# 37         0.025762        0.000550
# 38         0.023734        0.000524
# 39         1.277473        0.025868
# 40         0.014036        0.001212
# 41         0.013947        0.001291
# 42         0.012212        0.000707
# 43         0.566972        0.011997
# 44         0.013828        0.001722
# 45         0.013715        0.001632
# 46         0.011815        0.001083
# 47         0.511392        0.011745

# %% [markdown]
# # Frozen-Backprop Sigma Search
#
# Run the same frozen-backprop repeated-perturbation analysis as above, but sweep only over `sigma` for each perturbation method.
# The plots are grouped per method, with one row per checkpoint epoch and separate bar panels for average sample cosine, cosine of the mean estimator, and sample variance.

# %%
# Frozen-backprop sigma search.
# Reuses the repeated-perturbation estimator procedure, but sweeps only over sigma.

SIGMA_SEARCH_EPOCHS = 50
SIGMA_SEARCH_SEED = 0
SIGMA_SEARCH_BP_LR = 0.01
SIGMA_SEARCH_NUM_PERTURBATIONS = 50
SIGMA_SEARCH_BATCH_SIZE = BATCH_SIZE
SIGMA_SEARCH_CHECKPOINT_EPOCHS = sorted({max(1, SIGMA_SEARCH_EPOCHS // 3), max(1, (2 * SIGMA_SEARCH_EPOCHS) // 3), SIGMA_SEARCH_EPOCHS})
SIGMA_SEARCH_METHOD_SIGMA_GRID = {
    "np": [
        0.08,
        0.1,
        0.12
    ],
    "np_fan_in": [
        0.045,
        0.055,
        0.06
    ],
    "np_fixed": [
        0.4,
        0.45,
        0.5
    ],
    "wp": [
        0.08,
        0.1,
        0.12
    ]
}

print(
    f"Running frozen sigma search | epochs={SIGMA_SEARCH_EPOCHS}, seed={SIGMA_SEARCH_SEED}, "
    f"bp_lr={SIGMA_SEARCH_BP_LR}, checkpoints={SIGMA_SEARCH_CHECKPOINT_EPOCHS}, "
    f"num_perturbations={SIGMA_SEARCH_NUM_PERTURBATIONS}, batch_size={SIGMA_SEARCH_BATCH_SIZE}"
)
print(SIGMA_SEARCH_METHOD_SIGMA_GRID)

if "checkpoint_states" in globals() and sorted(checkpoint_states.keys()) == SIGMA_SEARCH_CHECKPOINT_EPOCHS:
    sigma_search_checkpoint_states = checkpoint_states
else:
    sigma_search_checkpoint_states = train_backprop_checkpoint_states(
        data=data,
        dimensions=DIMENSIONS,
        epochs=SIGMA_SEARCH_EPOCHS,
        seed=SIGMA_SEARCH_SEED,
        device=device,
        lr=SIGMA_SEARCH_BP_LR,
        checkpoint_epochs=SIGMA_SEARCH_CHECKPOINT_EPOCHS,
        print_every_epoch=max(1, SIGMA_SEARCH_EPOCHS // 10),
    )

sigma_search_df = analyze_frozen_backprop_sigma_grid(
    checkpoint_states=sigma_search_checkpoint_states,
    data=data,
    dimensions=DIMENSIONS,
    device=device,
    method_sigma_grid=SIGMA_SEARCH_METHOD_SIGMA_GRID,
    num_perturbations=SIGMA_SEARCH_NUM_PERTURBATIONS,
    batch_size=SIGMA_SEARCH_BATCH_SIZE,
)

display(sigma_search_df.sort_values(["method", "checkpoint_epoch", "sigma"]).reset_index(drop=True))
plot_frozen_sigma_search_results(sigma_search_df)
# Out:
# Running frozen sigma search | epochs=50, seed=0, bp_lr=0.01, checkpoints=[16, 33, 50], num_perturbations=50, batch_size=256
# {'np': [0.08, 0.1, 0.12], 'np_fan_in': [0.035, 0.045, 0.055], 'np_fixed': [0.35, 0.4, 0.45], 'wp': [0.08, 0.1, 0.12]}
#     bp checkpoint training epoch    1/50 | train_loss=0.9867, train_r2=0.0133, test_loss=0.9613, test_r2=0.0133
#     bp checkpoint training epoch    5/50 | train_loss=0.9224, train_r2=0.0776, test_loss=0.9006, test_r2=0.0756
#     bp checkpoint training epoch   10/50 | train_loss=0.7477, train_r2=0.2523, test_loss=0.7384, test_r2=0.2421
#     bp checkpoint training epoch   15/50 | train_loss=0.5255, train_r2=0.4745, test_loss=0.5350, test_r2=0.4509
#     bp checkpoint training epoch   16/50 | train_loss=0.4991, train_r2=0.5009, test_loss=0.5106, test_r2=0.4759
#     bp checkpoint training epoch   20/50 | train_loss=0.4501, train_r2=0.5499, test_loss=0.4668, test_r2=0.5209
#     bp checkpoint training epoch   25/50 | train_loss=0.4311, train_r2=0.5689, test_loss=0.4474, test_r2=0.5408
#     bp checkpoint training epoch   30/50 | train_loss=0.4184, train_r2=0.5816, test_loss=0.4334, test_r2=0.5552
#     bp checkpoint training epoch   33/50 | train_loss=0.4130, train_r2=0.5870, test_loss=0.4265, test_r2=0.5622
#     bp checkpoint training epoch   35/50 | train_loss=0.4077, train_r2=0.5923, test_loss=0.4213, test_r2=0.5676
#     bp checkpoint training epoch   40/50 | train_loss=0.3999, train_r2=0.6001, test_loss=0.4114, test_r2=0.5777
#     bp checkpoint training epoch   45/50 | train_loss=0.3904, train_r2=0.6096, test_loss=0.4019, test_r2=0.5875
#     bp checkpoint training epoch   50/50 | train_loss=0.3826, train_r2=0.6174, test_loss=0.3924, test_r2=0.5972
#     checkpoint_epoch  checkpoint_fraction     method  sigma  \
# 0                 16                 0.32         np  0.080
# 1                 16                 0.32         np  0.100
# 2                 16                 0.32         np  0.120
# 3                 33                 0.66         np  0.080
# 4                 33                 0.66         np  0.100
# 5                 33                 0.66         np  0.120
# 6                 50                 1.00         np  0.080
# 7                 50                 1.00         np  0.100
# 8                 50                 1.00         np  0.120
# 9                 16                 0.32  np_fan_in  0.035
# 10                16                 0.32  np_fan_in  0.045
# 11                16                 0.32  np_fan_in  0.055
# 12                33                 0.66  np_fan_in  0.035
# 13                33                 0.66  np_fan_in  0.045
# 14                33                 0.66  np_fan_in  0.055
# 15                50                 1.00  np_fan_in  0.035
# 16                50                 1.00  np_fan_in  0.045
# 17                50                 1.00  np_fan_in  0.055
# 18                16                 0.32   np_fixed  0.350
# 19                16                 0.32   np_fixed  0.400
# 20                16                 0.32   np_fixed  0.450
# 21                33                 0.66   np_fixed  0.350
# 22                33                 0.66   np_fixed  0.400
# 23                33                 0.66   np_fixed  0.450
# 24                50                 1.00   np_fixed  0.350
# 25                50                 1.00   np_fixed  0.400
# 26                50                 1.00   np_fixed  0.450
# 27                16                 0.32         wp  0.080
# 28                16                 0.32         wp  0.100
# 29                16                 0.32         wp  0.120
# 30                33                 0.66         wp  0.080
# 31                33                 0.66         wp  0.100
# 32                33                 0.66         wp  0.120
# 33                50                 1.00         wp  0.080
# 34                50                 1.00         wp  0.100
# 35                50                 1.00         wp  0.120
#
#     avg_sample_cosine  mean_estimate_cosine  sample_variance  batch_variance
# 0            0.027825              0.194359         0.016221        0.000328
# 1            0.032571              0.218912         0.012518        0.000259
# 2            0.033558              0.222978         0.010804        0.000224
# 3            0.023439              0.178705         0.015016        0.000306
# 4            0.018171              0.140206         0.011430        0.000246
# 5            0.012835              0.098865         0.009942        0.000223
# 6            0.025877              0.177396         0.013655        0.000279
# 7            0.026447              0.173723         0.010621        0.000231
# 8            0.020831              0.122036         0.009524        0.000224
# 9            0.019175              0.137127         0.132061        0.002730
# 10           0.021510              0.152627         0.093484        0.001816
# 11           0.022281              0.154914         0.065042        0.001335
# 12           0.014798              0.117087         0.257019        0.005912
# 13           0.014389              0.114457         0.167883        0.003197
# 14           0.011465              0.093094         0.122711        0.002457
# 15           0.014734              0.108422         0.299093        0.006114
# 16           0.015073              0.107675         0.227726        0.004760
# 17           0.017391              0.118229         0.132581        0.002663
# 18           0.034545              0.243814         0.021831        0.000424
# 19           0.035768              0.245281         0.019267        0.000368
# 20           0.038835              0.260933         0.015272        0.000304
# 21           0.028704              0.217188         0.035607        0.000707
# 22           0.025912              0.194367         0.029614        0.000579
# 23           0.028398              0.212936         0.023219        0.000462
# 24           0.027889              0.191126         0.037032        0.000736
# 25           0.029971              0.201843         0.030377        0.000651
# 26           0.029684              0.196040         0.024977        0.000510
# 27           0.004528              0.033003         0.800917        0.016006
# 28           0.004365              0.032332         0.614899        0.012310
# 29           0.004524              0.033461         0.527229        0.010562
# 30           0.003904              0.031081         0.740221        0.014793
# 31           0.003080              0.025517         0.567380        0.011411
# 32           0.001791              0.016413         0.487986        0.009808
# 33           0.003565              0.026984         0.660907        0.013202
# 34           0.003478              0.026544         0.523365        0.010510
# 35           0.003334              0.025182         0.462779        0.009274
