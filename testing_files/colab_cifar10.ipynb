# %% [markdown]
# # CIFAR-10 Hyperparameter Search in Colab
#
# This notebook is self-contained and includes:
# - CIFAR-10 loading and preprocessing
# - a modest hyperparameter sweep for `bp`, `np`, `np_fan_in`, `np_fixed`, and `wp`
# - a deeper rerun using the best config per method
# - an optional single-config runner
# - frozen-backprop repeated-perturbation analysis
# - frozen-backprop sigma search
#
# Architecture used here:
# - input `3072`
# - linear `3072 -> 512`
# - `ReLU`
# - linear `512 -> 256`
# - `ReLU`
# - linear `256 -> 10`

# %%
import itertools
import math
import random
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from IPython.display import display
from torch.utils.data import DataLoader, TensorDataset, Subset
from torchvision.datasets import CIFAR10

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if hasattr(torch, "set_float32_matmul_precision"):
    torch.set_float32_matmul_precision("high")

def set_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(0)
print(f"device={device}")
if device.type == "cuda":
    print(torch.cuda.get_device_name(0))
# Out:
# device=cuda
# NVIDIA RTX PRO 6000 Blackwell Server Edition

# %%
METHODS = ["bp", "np", "np_fan_in", "np_fixed", "wp"]
METHOD_LABELS = {
    "bp": "Backprop",
    "np": "Node Perturbation",
    "np_fan_in": "Node Perturbation Fan-In",
    "np_fixed": "Node Perturbation Fixed Sigma",
    "wp": "Weight Perturbation",
}
METHOD_COLORS = {
    "bp": "C0",
    "np": "C1",
    "np_fan_in": "C4",
    "np_fixed": "C3",
    "wp": "C2",
}


class MLP(nn.Module):
    def __init__(self, dimensions, activation=torch.relu, output_activation=None, require_grad=False):
        super().__init__()
        self.layers = nn.ModuleList(
            [nn.Linear(dimensions[i], dimensions[i + 1], bias=True) for i in range(len(dimensions) - 1)]
        )
        self.activation = activation
        self.output_activation = output_activation
        if not require_grad:
            for p in self.parameters():
                p.requires_grad_(False)

    def forward(self, x):
        final_layer = len(self.layers) - 1
        h = x
        for i, layer in enumerate(self.layers):
            u = layer(h)
            if i == final_layer:
                h = self.output_activation(u) if self.output_activation else u
            else:
                h = self.activation(u)
        return h

    def forward_weight_perturb(self, x, sigma):
        batch_size = x.shape[0]
        xs = [x]
        ys = []
        noises = []
        h = x
        for i, layer in enumerate(self.layers):
            w = layer.weight
            b = layer.bias
            eps_w = torch.randn(batch_size, *w.shape, device=w.device, dtype=w.dtype) * sigma
            eps_b = torch.randn(batch_size, *b.shape, device=b.device, dtype=b.dtype) * sigma
            w_used = w.unsqueeze(0) + eps_w
            b_used = b.unsqueeze(0) + eps_b
            u = torch.bmm(h.unsqueeze(1), w_used.transpose(1, 2)).squeeze(1) + b_used
            final_layer = len(self.layers) - 1
            if i == final_layer:
                h = self.output_activation(u) if self.output_activation else u
                ys.append(h)
            else:
                h = self.activation(u)
                ys.append(h)
                xs.append(h)
            noises.append((eps_w, eps_b))
        return ys, xs, noises

    def forward_node_perturb(self, x, sigma):
        acts = [x]
        noises = []
        noise_scales = []
        last = len(self.layers) - 1
        a_noisy = x
        for i, layer in enumerate(self.layers):
            x_in = a_noisy
            z_noisy = layer(a_noisy)
            eps = torch.randn_like(z_noisy)
            noise_scale = sigma * torch.sqrt(1.0 + x_in.pow(2).sum(dim=1, keepdim=True))
            noises.append(eps)
            noise_scales.append(noise_scale)
            z_noisy = z_noisy + noise_scale * eps
            if i == last:
                a_noisy = self.output_activation(z_noisy) if self.output_activation else z_noisy
            else:
                a_noisy = self.activation(z_noisy)
            acts.append(a_noisy)
        return acts, noises, noise_scales, a_noisy

    def forward_node_perturb_fixed_sigma(self, x, sigma):
        acts = [x]
        noises = []
        noise_scales = []
        last = len(self.layers) - 1
        a_noisy = x
        for i, layer in enumerate(self.layers):
            z_noisy = layer(a_noisy)
            eps = torch.randn_like(z_noisy)
            noise_scale = torch.full_like(z_noisy, sigma)
            noises.append(eps)
            noise_scales.append(noise_scale)
            z_noisy = z_noisy + noise_scale * eps
            if i == last:
                a_noisy = self.output_activation(z_noisy) if self.output_activation else z_noisy
            else:
                a_noisy = self.activation(z_noisy)
            acts.append(a_noisy)
        return acts, noises, noise_scales, a_noisy

    def forward_node_perturb_fan_in_scaled(self, x, sigma):
        acts = [x]
        noises = []
        noise_scales = []
        last = len(self.layers) - 1
        a_noisy = x
        for i, layer in enumerate(self.layers):
            z_noisy = layer(a_noisy)
            eps = torch.randn_like(z_noisy)
            fan_in_with_bias = layer.in_features + 1
            noise_scale_value = sigma * math.sqrt(fan_in_with_bias)
            noise_scale = torch.full_like(z_noisy, noise_scale_value)
            noises.append(eps)
            noise_scales.append(noise_scale)
            z_noisy = z_noisy + noise_scale * eps
            if i == last:
                a_noisy = self.output_activation(z_noisy) if self.output_activation else z_noisy
            else:
                a_noisy = self.activation(z_noisy)
            acts.append(a_noisy)
        return acts, noises, noise_scales, a_noisy


def _mean_loss_per_sample(prediction, target):
    loss = F.mse_loss(prediction, target, reduction="none")
    if loss.dim() > 1:
        loss = loss.mean(dim=1)
    return loss.view(-1)


def _centered_reward_signal(loss_per_sample):
    reward = -loss_per_sample
    return reward - reward.mean()


def _flatten_parameter_tensors(weight_tensors, bias_tensors):
    pieces = []
    for weight_tensor, bias_tensor in zip(weight_tensors, bias_tensors):
        pieces.append(weight_tensor.reshape(-1))
        pieces.append(bias_tensor.reshape(-1))
    return torch.cat(pieces)


def node_perturbation_step(model, X, target, eta=0.5, sigma=0.1, return_unscaled_parameter_update_vector=False):
    model.train()
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb(X, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, target)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    with torch.no_grad():
        for layer, x_in, noise, noise_scale in zip(model.layers, activations, noises, noise_scales):
            scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
            raw_weight_update = torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0)
            raw_bias_update = scaled_noise.mean(dim=0)
            raw_weight_updates.append(raw_weight_update)
            raw_bias_updates.append(raw_bias_update)
            layer.weight += eta * raw_weight_update
            layer.bias += eta * raw_bias_update
    mean_loss = loss_per_sample.mean().item()
    if return_unscaled_parameter_update_vector:
        return mean_loss, _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)
    return mean_loss


def node_perturbation_step_fixed_sigma(model, X, target, eta=0.5, sigma=0.1, return_unscaled_parameter_update_vector=False):
    model.train()
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb_fixed_sigma(X, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, target)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    with torch.no_grad():
        for layer, x_in, noise, noise_scale in zip(model.layers, activations, noises, noise_scales):
            scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
            raw_weight_update = torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0)
            raw_bias_update = scaled_noise.mean(dim=0)
            raw_weight_updates.append(raw_weight_update)
            raw_bias_updates.append(raw_bias_update)
            layer.weight += eta * raw_weight_update
            layer.bias += eta * raw_bias_update
    mean_loss = loss_per_sample.mean().item()
    if return_unscaled_parameter_update_vector:
        return mean_loss, _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)
    return mean_loss


def node_perturbation_step_fan_in_scaled(model, X, target, eta=0.5, sigma=0.1, return_unscaled_parameter_update_vector=False):
    model.train()
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb_fan_in_scaled(X, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, target)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    with torch.no_grad():
        for layer, x_in, noise, noise_scale in zip(model.layers, activations, noises, noise_scales):
            scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
            raw_weight_update = torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0)
            raw_bias_update = scaled_noise.mean(dim=0)
            raw_weight_updates.append(raw_weight_update)
            raw_bias_updates.append(raw_bias_update)
            layer.weight += eta * raw_weight_update
            layer.bias += eta * raw_bias_update
    mean_loss = loss_per_sample.mean().item()
    if return_unscaled_parameter_update_vector:
        return mean_loss, _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)
    return mean_loss


def weight_perturb_step(model, X, target, eta=0.5, sigma=0.1, return_unscaled_parameter_update_vector=False):
    model.train()
    layer_outputs, _, noises = model.forward_weight_perturb(X, sigma)
    prediction_noisy = layer_outputs[-1]
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, target)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    noise_scale = sigma ** 2 + 1e-12
    raw_weight_updates = []
    raw_bias_updates = []
    with torch.no_grad():
        for layer, (weight_noise, bias_noise) in zip(model.layers, noises):
            scaled_weight_noise = scalar_signal.view(-1, 1, 1) * weight_noise / noise_scale
            scaled_bias_noise = scalar_signal.view(-1, 1) * bias_noise / noise_scale
            raw_weight_update = scaled_weight_noise.mean(dim=0)
            raw_bias_update = scaled_bias_noise.mean(dim=0)
            raw_weight_updates.append(raw_weight_update)
            raw_bias_updates.append(raw_bias_update)
            layer.weight += eta * raw_weight_update
            layer.bias += eta * raw_bias_update
    mean_loss = loss_per_sample.mean().item()
    if return_unscaled_parameter_update_vector:
        return mean_loss, _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)
    return mean_loss


def backprop_step(model, X, target, optimizer, loss_fn=F.mse_loss, return_unscaled_parameter_update_vector=False):
    model.train()
    for p in model.parameters():
        p.requires_grad_(True)
    optimizer.zero_grad()
    y_pred = model(X)
    loss = loss_fn(y_pred, target, reduction="mean")
    loss.backward()
    weight_grads = [layer.weight.grad.detach().clone() for layer in model.layers]
    bias_grads = [layer.bias.grad.detach().clone() for layer in model.layers]
    optimizer.step()
    if return_unscaled_parameter_update_vector:
        return loss.item(), -_flatten_parameter_tensors(weight_grads, bias_grads)
    return loss.item()


def cosine_similarity_safe(a, b, eps=1e-12):
    a_norm = torch.norm(a)
    b_norm = torch.norm(b)
    if a_norm.item() < eps or b_norm.item() < eps:
        return 0.0
    return float(torch.dot(a, b) / (a_norm * b_norm + eps))


def true_gradient_vector(model, xb, yb):
    requires_grad_state = [parameter.requires_grad for parameter in model.parameters()]
    for parameter in model.parameters():
        parameter.requires_grad_(True)
    model.zero_grad(set_to_none=True)
    prediction = model(xb)
    loss = F.mse_loss(prediction, yb, reduction="mean")
    loss.backward()
    weight_grads = [layer.weight.grad.detach().clone() for layer in model.layers]
    bias_grads = [layer.bias.grad.detach().clone() for layer in model.layers]
    flat_grad = _flatten_parameter_tensors(weight_grads, bias_grads)
    model.zero_grad(set_to_none=True)
    for parameter, old_value in zip(model.parameters(), requires_grad_state):
        parameter.requires_grad_(old_value)
    return -flat_grad


def gradient_metrics(unscaled_parameter_update_vector, true_update):
    diff = unscaled_parameter_update_vector - true_update
    cosine = cosine_similarity_safe(unscaled_parameter_update_vector, true_update)
    squared_error = float(diff.pow(2).mean())
    true_update_norm = float(torch.norm(true_update))
    projection = float(torch.dot(unscaled_parameter_update_vector, true_update) / (true_update_norm + 1e-12))
    return cosine, squared_error, projection


def node_perturbation_gradient_estimate_vector(model, xb, yb, sigma):
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb(xb, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, yb)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    for x_in, noise, noise_scale in zip(activations, noises, noise_scales):
        scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
        raw_weight_updates.append(torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0))
        raw_bias_updates.append(scaled_noise.mean(dim=0))
    return _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)


def node_perturbation_fixed_sigma_gradient_estimate_vector(model, xb, yb, sigma):
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb_fixed_sigma(xb, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, yb)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    for x_in, noise, noise_scale in zip(activations, noises, noise_scales):
        scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
        raw_weight_updates.append(torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0))
        raw_bias_updates.append(scaled_noise.mean(dim=0))
    return _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)


def node_perturbation_fan_in_gradient_estimate_vector(model, xb, yb, sigma):
    activations, noises, noise_scales, prediction_noisy = model.forward_node_perturb_fan_in_scaled(xb, sigma)
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, yb)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    raw_weight_updates = []
    raw_bias_updates = []
    for x_in, noise, noise_scale in zip(activations, noises, noise_scales):
        scaled_noise = scalar_signal.view(-1, 1) * noise / (noise_scale + 1e-12)
        raw_weight_updates.append(torch.bmm(scaled_noise.unsqueeze(2), x_in.unsqueeze(1)).mean(dim=0))
        raw_bias_updates.append(scaled_noise.mean(dim=0))
    return _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)


def weight_perturbation_gradient_estimate_vector(model, xb, yb, sigma):
    layer_outputs, _, noises = model.forward_weight_perturb(xb, sigma)
    prediction_noisy = layer_outputs[-1]
    loss_per_sample = _mean_loss_per_sample(prediction_noisy, yb)
    scalar_signal = _centered_reward_signal(loss_per_sample)
    noise_scale = sigma ** 2 + 1e-12
    raw_weight_updates = []
    raw_bias_updates = []
    for weight_noise, bias_noise in noises:
        scaled_weight_noise = scalar_signal.view(-1, 1, 1) * weight_noise / noise_scale
        scaled_bias_noise = scalar_signal.view(-1, 1) * bias_noise / noise_scale
        raw_weight_updates.append(scaled_weight_noise.mean(dim=0))
        raw_bias_updates.append(scaled_bias_noise.mean(dim=0))
    return _flatten_parameter_tensors(raw_weight_updates, raw_bias_updates)


def perturbation_gradient_estimate_vector(method, model, xb, yb, sigma):
    if method == "np":
        return node_perturbation_gradient_estimate_vector(model, xb, yb, sigma)
    if method == "np_fan_in":
        return node_perturbation_fan_in_gradient_estimate_vector(model, xb, yb, sigma)
    if method == "np_fixed":
        return node_perturbation_fixed_sigma_gradient_estimate_vector(model, xb, yb, sigma)
    if method == "wp":
        return weight_perturbation_gradient_estimate_vector(model, xb, yb, sigma)
    raise ValueError(f"Unknown perturbation method: {method}")


def variance_against_true_gradient(estimate_matrix, true_update):
    num_samples = estimate_matrix.shape[0]
    if num_samples == 0:
        return 0.0, 0.0

    squared_errors = (estimate_matrix - true_update.unsqueeze(0)).pow(2)
    per_sample_variance = float(squared_errors.mean(dim=1).mean())
    mean_estimate = estimate_matrix.mean(dim=0)
    batch_variance = float((mean_estimate - true_update).pow(2).mean())
    return per_sample_variance, batch_variance


def model_weight_norm(model):
    total = torch.tensor(0.0, device=next(model.parameters()).device)
    for layer in model.layers:
        total = total + layer.weight.detach().pow(2).sum()
    return float(torch.sqrt(total))


def mean_normalized_layer_output_norms(model, loader, device):
    model.eval()
    summed_norms = [0.0 for _ in model.layers]
    total_examples = 0

    with torch.no_grad():
        for batch in loader:
            if len(batch) == 3:
                xb, _, _ = batch
            else:
                xb, _ = batch
            xb = xb.to(device, non_blocking=True)
            h = xb
            batch_size = xb.size(0)

            for layer_idx, layer in enumerate(model.layers):
                h_for_norm = h if h.dim() > 1 else h.unsqueeze(1)
                normalized_norm = torch.norm(h_for_norm, dim=1) / math.sqrt(h_for_norm.shape[1] + 1)
                summed_norms[layer_idx] += normalized_norm.sum().item()
                u = layer(h)
                if layer_idx == len(model.layers) - 1:
                    h = model.output_activation(u) if model.output_activation else u
                else:
                    h = model.activation(u)

            total_examples += batch_size

    return [value / max(total_examples, 1) for value in summed_norms]


def _random_subset_indices(n, limit, seed):
    if limit is None or limit >= n:
        return torch.arange(n)
    g = torch.Generator().manual_seed(seed)
    return torch.randperm(n, generator=g)[:limit]


def load_cifar10(
    train_limit=20000,
    test_limit=5000,
    train_eval_limit=4000,
    batch_size=128,
    eval_batch_size=1024,
    data_dir="./data",
    seed=0,
    mean_center_only=True,
    num_workers=0,
):
    train_dataset = CIFAR10(root=data_dir, train=True, download=True)
    test_dataset = CIFAR10(root=data_dir, train=False, download=True)

    x_train = torch.from_numpy(train_dataset.data).float() / 255.0
    x_test = torch.from_numpy(test_dataset.data).float() / 255.0
    train_labels = torch.tensor(train_dataset.targets, dtype=torch.long)
    test_labels = torch.tensor(test_dataset.targets, dtype=torch.long)

    train_idx = _random_subset_indices(len(x_train), train_limit, seed)
    test_idx = _random_subset_indices(len(x_test), test_limit, seed + 1)

    x_train = x_train[train_idx]
    train_labels = train_labels[train_idx]
    x_test = x_test[test_idx]
    test_labels = test_labels[test_idx]

    mean = x_train.mean()
    if mean_center_only:
        x_train = x_train - mean
        x_test = x_test - mean
    else:
        std = x_train.std().clamp_min(1e-6)
        x_train = (x_train - mean) / std
        x_test = (x_test - mean) / std

    x_train = x_train.permute(0, 3, 1, 2).contiguous().view(x_train.size(0), -1)
    x_test = x_test.permute(0, 3, 1, 2).contiguous().view(x_test.size(0), -1)

    y_train = F.one_hot(train_labels, num_classes=10).float()
    y_test = F.one_hot(test_labels, num_classes=10).float()

    train_tensor_dataset = TensorDataset(x_train, y_train, train_labels)
    test_tensor_dataset = TensorDataset(x_test, y_test, test_labels)

    if train_eval_limit is None or train_eval_limit >= len(train_tensor_dataset):
        train_eval_dataset = train_tensor_dataset
    else:
        eval_idx = _random_subset_indices(len(train_tensor_dataset), train_eval_limit, seed + 2)
        train_eval_dataset = Subset(train_tensor_dataset, eval_idx.tolist())

    pin_memory = device.type == "cuda"
    train_loader = DataLoader(train_tensor_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
    train_eval_loader = DataLoader(train_eval_dataset, batch_size=eval_batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
    test_loader = DataLoader(test_tensor_dataset, batch_size=eval_batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)

    return {
        "train_loader": train_loader,
        "train_eval_loader": train_eval_loader,
        "test_loader": test_loader,
        "train_size": len(train_tensor_dataset),
        "train_eval_size": len(train_eval_dataset),
        "test_size": len(test_tensor_dataset),
        "x_train": x_train,
        "y_train": y_train,
        "train_labels": train_labels,
        "x_test": x_test,
        "y_test": y_test,
        "test_labels": test_labels,
    }


def evaluate_model(model, loader, device):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_examples = 0
    with torch.no_grad():
        for xb, yb, labels in loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)
            logits = model(xb)
            loss = F.mse_loss(logits, yb, reduction="mean")
            total_loss += loss.item() * xb.size(0)
            total_correct += (logits.argmax(dim=1) == labels).sum().item()
            total_examples += xb.size(0)
    mean_loss = total_loss / max(total_examples, 1)
    accuracy = total_correct / max(total_examples, 1)
    return mean_loss, accuracy


def make_model(dimensions, require_grad, device):
    return MLP(dimensions, activation=torch.relu, output_activation=None, require_grad=require_grad).to(device)


def train_one_run(
    method,
    run_config,
    data,
    dimensions,
    epochs,
    seed,
    device,
    print_every_epoch=1,
    divergence_loss_threshold=5.0,
):
    set_seed(seed)

    base_model = make_model(dimensions, require_grad=True, device=device)
    base_state = {name: tensor.detach().clone() for name, tensor in base_model.state_dict().items()}

    require_grad = method == "bp"
    model = make_model(dimensions, require_grad=require_grad, device=device)
    model.load_state_dict(base_state)

    optimizer = None
    if method == "bp":
        optimizer = torch.optim.SGD(model.parameters(), lr=run_config["lr"])

    history = {
        "epoch": [],
        "train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": [],
        "weight_norm": [],
        "layer_output_norms": [],
    }

    diverged = False
    best_test_acc = -float("inf")
    best_test_loss = float("inf")
    start_time = time.time()

    train_loader = data["train_loader"]
    train_eval_loader = data["train_eval_loader"]
    test_loader = data["test_loader"]

    for epoch in range(1, epochs + 1):
        model.train()
        for xb, yb, _ in train_loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)

            if method == "bp":
                backprop_step(model, xb, yb, optimizer=optimizer)
            elif method == "np":
                node_perturbation_step(model, xb, yb, eta=run_config["lr"], sigma=run_config["sigma"])
            elif method == "np_fan_in":
                node_perturbation_step_fan_in_scaled(model, xb, yb, eta=run_config["lr"], sigma=run_config["sigma"])
            elif method == "np_fixed":
                node_perturbation_step_fixed_sigma(model, xb, yb, eta=run_config["lr"], sigma=run_config["sigma"])
            elif method == "wp":
                weight_perturb_step(model, xb, yb, eta=run_config["lr"], sigma=run_config["sigma"])
            else:
                raise ValueError(f"Unknown method: {method}")

        train_loss, train_acc = evaluate_model(model, train_eval_loader, device)
        test_loss, test_acc = evaluate_model(model, test_loader, device)

        history["epoch"].append(epoch)
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["test_loss"].append(test_loss)
        history["test_acc"].append(test_acc)
        history["weight_norm"].append(model_weight_norm(model))
        history["layer_output_norms"].append(mean_normalized_layer_output_norms(model, train_eval_loader, device))

        best_test_acc = max(best_test_acc, test_acc)
        best_test_loss = min(best_test_loss, test_loss)

        if (not math.isfinite(train_loss)) or (not math.isfinite(test_loss)) or test_loss > divergence_loss_threshold:
            diverged = True
            print(
                f"    diverged at epoch {epoch}/{epochs} | "
                f"train_loss={train_loss:.4f}, test_loss={test_loss:.4f}, test_acc={test_acc:.4f}"
            )
            break

        if epoch % print_every_epoch == 0 or epoch == 1 or epoch == epochs:
            sigma_str = f", sigma={run_config['sigma']:.4g}" if "sigma" in run_config else ""
            print(
                f"    epoch {epoch:2d}/{epochs} | {method} | lr={run_config['lr']:.4g}{sigma_str} | "
                f"train_loss={train_loss:.4f}, train_acc={train_acc:.4f}, "
                f"test_loss={test_loss:.4f}, test_acc={test_acc:.4f}"
            )

    duration_sec = time.time() - start_time
    state_dict_cpu = {name: tensor.detach().cpu().clone() for name, tensor in model.state_dict().items()}
    result = {
        "method": method,
        "lr": float(run_config["lr"]),
        "sigma": float(run_config["sigma"]) if "sigma" in run_config else np.nan,
        "epochs_completed": len(history["epoch"]),
        "final_train_loss": history["train_loss"][-1] if history["train_loss"] else np.nan,
        "final_train_acc": history["train_acc"][-1] if history["train_acc"] else np.nan,
        "final_test_loss": history["test_loss"][-1] if history["test_loss"] else np.nan,
        "final_test_acc": history["test_acc"][-1] if history["test_acc"] else np.nan,
        "best_test_loss": best_test_loss,
        "best_test_acc": best_test_acc,
        "diverged": diverged,
        "duration_sec": duration_sec,
        "history": history,
        "state_dict": state_dict_cpu,
    }
    del model
    if device.type == "cuda":
        torch.cuda.empty_cache()
    return result


def train_backprop_checkpoint_states(data, dimensions, epochs, seed, device, lr, checkpoint_epochs, print_every_epoch=100):
    checkpoint_epochs = sorted(set(int(epoch) for epoch in checkpoint_epochs))
    set_seed(seed)
    model = make_model(dimensions, require_grad=True, device=device)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)
    checkpoint_states = {}

    for epoch in range(1, epochs + 1):
        model.train()
        for xb, yb, _ in data["train_loader"]:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)
            backprop_step(model, xb, yb, optimizer=optimizer)

        if epoch in checkpoint_epochs:
            checkpoint_states[epoch] = {name: tensor.detach().cpu().clone() for name, tensor in model.state_dict().items()}

        if epoch % print_every_epoch == 0 or epoch == 1 or epoch == epochs or epoch in checkpoint_epochs:
            train_loss, train_acc = evaluate_model(model, data["train_eval_loader"], device)
            test_loss, test_acc = evaluate_model(model, data["test_loader"], device)
            print(
                f"    bp checkpoint training epoch {epoch:4d}/{epochs} | "
                f"train_loss={train_loss:.4f}, train_acc={train_acc:.4f}, "
                f"test_loss={test_loss:.4f}, test_acc={test_acc:.4f}"
            )

    return checkpoint_states


def plot_layer_output_norm_histories(results_by_method):
    first_result = next((results_by_method[method] for method in METHODS if method in results_by_method), None)
    if first_result is None:
        return

    layer_output_history = first_result["history"].get("layer_output_norms", [])
    if len(layer_output_history) == 0:
        return

    num_layers = len(layer_output_history[0])
    fig, axes = plt.subplots(num_layers, 1, figsize=(10, 3.4 * num_layers), sharex=True, squeeze=False)
    axes = axes.flatten()

    for layer_idx in range(num_layers):
        fan_in = int(first_result["state_dict"][f"layers.{layer_idx}.weight"].shape[1])
        layer_label = "Input layer" if layer_idx == 0 else f"Hidden layer {layer_idx} output"
        axis = axes[layer_idx]
        for method in METHODS:
            if method not in results_by_method:
                continue
            history = results_by_method[method]["history"]
            values = [epoch_values[layer_idx] for epoch_values in history.get("layer_output_norms", [])]
            if len(values) == 0:
                continue
            axis.plot(history["epoch"], values, label=METHOD_LABELS[method], color=METHOD_COLORS[method])
        axis.set_title(f"{layer_label} norm / sqrt({fan_in} + 1)")
        axis.set_ylabel("Average norm")
        axis.legend(ncol=2)

    axes[-1].set_xlabel("Epoch")
    fig.tight_layout()
    plt.show()


def layer_parameter_slices(model):
    layer_slices = []
    start = 0
    for layer_idx, layer in enumerate(model.layers):
        layer_parameter_count = layer.weight.numel() + layer.bias.numel()
        layer_slices.append((layer_idx, slice(start, start + layer_parameter_count), f"Layer {layer_idx + 1}"))
        start += layer_parameter_count
    return layer_slices


def analyze_frozen_backprop_estimators(
    checkpoint_states,
    data,
    dimensions,
    device,
    method_sigmas,
    num_perturbations=50,
    batch_size=128,
):
    analysis_dataset = TensorDataset(data["x_train"], data["y_train"])
    analysis_loader = DataLoader(
        analysis_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=0,
        pin_memory=(device.type == "cuda"),
    )

    rows = []
    perturbation_methods = list(method_sigmas.keys())

    for checkpoint_epoch, state_dict in checkpoint_states.items():
        model = make_model(dimensions, require_grad=True, device=device)
        model.load_state_dict(state_dict)
        component_specs = [(-1, slice(None), "All layers")] + layer_parameter_slices(model)

        batch_metrics = {
            method: {
                layer_index: {
                    "component": "all" if layer_index == -1 else f"layer_{layer_index + 1}",
                    "component_label": component_label,
                    "avg_sample_cosine": [],
                    "mean_estimate_cosine": [],
                    "sample_variance": [],
                    "batch_variance": [],
                }
                for layer_index, _, component_label in component_specs
            }
            for method in perturbation_methods
        }

        for xb, yb in analysis_loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)
            true_update = true_gradient_vector(model, xb, yb)

            for method in perturbation_methods:
                sigma = method_sigmas[method]
                estimates = [
                    perturbation_gradient_estimate_vector(method, model, xb, yb, sigma)
                    for _ in range(num_perturbations)
                ]
                estimate_matrix = torch.stack(estimates, dim=0)
                mean_estimate = estimate_matrix.mean(dim=0)

                for layer_index, component_slice, _ in component_specs:
                    component_true_update = true_update[component_slice]
                    component_estimate_matrix = estimate_matrix[:, component_slice]
                    component_mean_estimate = mean_estimate[component_slice]

                    avg_sample_cosine = float(
                        np.mean(
                            [
                                cosine_similarity_safe(component_estimate, component_true_update)
                                for component_estimate in component_estimate_matrix
                            ]
                        )
                    )
                    mean_estimate_cosine = cosine_similarity_safe(component_mean_estimate, component_true_update)
                    sample_variance, batch_variance = variance_against_true_gradient(
                        component_estimate_matrix,
                        component_true_update,
                    )

                    metrics = batch_metrics[method][layer_index]
                    metrics["avg_sample_cosine"].append(avg_sample_cosine)
                    metrics["mean_estimate_cosine"].append(mean_estimate_cosine)
                    metrics["sample_variance"].append(sample_variance)
                    metrics["batch_variance"].append(batch_variance)

        checkpoint_fraction = checkpoint_epoch / max(checkpoint_states.keys())
        for method in perturbation_methods:
            for layer_index, _, component_label in component_specs:
                metrics = batch_metrics[method][layer_index]
                rows.append({
                    "checkpoint_epoch": checkpoint_epoch,
                    "checkpoint_fraction": checkpoint_fraction,
                    "method": method,
                    "sigma": method_sigmas[method],
                    "component": metrics["component"],
                    "component_label": component_label,
                    "layer_index": layer_index,
                    "avg_sample_cosine": float(np.mean(metrics["avg_sample_cosine"])),
                    "mean_estimate_cosine": float(np.mean(metrics["mean_estimate_cosine"])),
                    "sample_variance": float(np.mean(metrics["sample_variance"])),
                    "batch_variance": float(np.mean(metrics["batch_variance"])),
                })

    return pd.DataFrame(rows)


def plot_frozen_estimator_statistics(stats_df):
    metrics = [
        ("avg_sample_cosine", "Average Sample Cosine", "Cosine"),
        ("mean_estimate_cosine", "Cosine of Mean Estimator", "Cosine"),
        ("sample_variance", "Per-Sample Variance to True Gradient", "Mean squared distance per parameter"),
        ("batch_variance", "Batch-Average Variance to True Gradient", "Mean squared distance per parameter"),
    ]
    perturbation_methods = [method for method in METHODS if method in {"np", "np_fan_in", "np_fixed", "wp"}]

    overall_df = stats_df[stats_df["layer_index"] == -1] if "layer_index" in stats_df.columns else stats_df
    fig, axes = plt.subplots(1, len(metrics), figsize=(24, 4), sharex=True)

    for method in perturbation_methods:
        method_df = overall_df[overall_df["method"] == method].sort_values("checkpoint_epoch")
        if len(method_df) == 0:
            continue
        x = method_df["checkpoint_epoch"].to_numpy()
        for axis, (column, title, ylabel) in zip(axes, metrics):
            axis.plot(x, method_df[column].to_numpy(), marker="o", color=METHOD_COLORS[method], label=METHOD_LABELS[method])
            axis.set_title(f"All layers | {title}")
            axis.set_xlabel("Checkpoint epoch")
            axis.set_ylabel(ylabel)
            axis.legend()

    fig.tight_layout()
    plt.show()

    if "layer_index" not in stats_df.columns:
        return

    layer_indices = sorted(layer_index for layer_index in stats_df["layer_index"].unique() if layer_index >= 0)
    if len(layer_indices) == 0:
        return

    fig, axes = plt.subplots(
        len(layer_indices),
        len(metrics),
        figsize=(6 * len(metrics), 3.8 * len(layer_indices)),
        sharex=True,
        squeeze=False,
    )

    for row, layer_index in enumerate(layer_indices):
        layer_df = stats_df[stats_df["layer_index"] == layer_index]
        component_label = layer_df["component_label"].iloc[0]

        for col, (column, title, ylabel) in enumerate(metrics):
            axis = axes[row, col]
            for method in perturbation_methods:
                method_df = layer_df[layer_df["method"] == method].sort_values("checkpoint_epoch")
                if len(method_df) == 0:
                    continue
                axis.plot(
                    method_df["checkpoint_epoch"].to_numpy(),
                    method_df[column].to_numpy(),
                    marker="o",
                    color=METHOD_COLORS[method],
                    label=METHOD_LABELS[method],
                )
            axis.set_title(f"{component_label} | {title}")
            axis.set_xlabel("Checkpoint epoch")
            axis.set_ylabel(ylabel)
            if col == len(metrics) - 1:
                axis.legend(fontsize=8)

    fig.tight_layout()
    plt.show()


def analyze_frozen_backprop_sigma_grid(
    checkpoint_states,
    data,
    dimensions,
    device,
    method_sigma_grid,
    num_perturbations=50,
    batch_size=128,
):
    analysis_dataset = TensorDataset(data["x_train"], data["y_train"])
    analysis_loader = DataLoader(
        analysis_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=0,
        pin_memory=(device.type == "cuda"),
    )

    rows = []
    methods = list(method_sigma_grid.keys())

    for checkpoint_epoch, state_dict in checkpoint_states.items():
        model = make_model(dimensions, require_grad=True, device=device)
        model.load_state_dict(state_dict)

        batch_metrics = {
            (method, sigma): {
                "avg_sample_cosine": [],
                "mean_estimate_cosine": [],
                "sample_variance": [],
                "batch_variance": [],
            }
            for method in methods
            for sigma in method_sigma_grid[method]
        }

        for batch in analysis_loader:
            if len(batch) == 3:
                xb, yb, _ = batch
            else:
                xb, yb = batch
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)
            true_update = true_gradient_vector(model, xb, yb)

            for method in methods:
                for sigma in method_sigma_grid[method]:
                    estimates = [
                        perturbation_gradient_estimate_vector(method, model, xb, yb, sigma)
                        for _ in range(num_perturbations)
                    ]
                    estimate_matrix = torch.stack(estimates, dim=0)
                    mean_estimate = estimate_matrix.mean(dim=0)

                    avg_sample_cosine = float(
                        sum(cosine_similarity_safe(estimate, true_update) for estimate in estimates) / num_perturbations
                    )
                    mean_estimate_cosine = cosine_similarity_safe(mean_estimate, true_update)
                    sample_variance, batch_variance = variance_against_true_gradient(estimate_matrix, true_update)

                    metrics = batch_metrics[(method, sigma)]
                    metrics["avg_sample_cosine"].append(avg_sample_cosine)
                    metrics["mean_estimate_cosine"].append(mean_estimate_cosine)
                    metrics["sample_variance"].append(sample_variance)
                    metrics["batch_variance"].append(batch_variance)

        checkpoint_fraction = checkpoint_epoch / max(checkpoint_states.keys())
        for method in methods:
            for sigma in method_sigma_grid[method]:
                metrics = batch_metrics[(method, sigma)]
                rows.append({
                    "checkpoint_epoch": checkpoint_epoch,
                    "checkpoint_fraction": checkpoint_fraction,
                    "method": method,
                    "sigma": float(sigma),
                    "avg_sample_cosine": float(np.mean(metrics["avg_sample_cosine"])),
                    "mean_estimate_cosine": float(np.mean(metrics["mean_estimate_cosine"])),
                    "sample_variance": float(np.mean(metrics["sample_variance"])),
                    "batch_variance": float(np.mean(metrics["batch_variance"])),
                })

    return pd.DataFrame(rows)


def plot_frozen_sigma_search_results(stats_df):
    metrics = [
        ("avg_sample_cosine", "Average Sample Cosine", "Cosine"),
        ("mean_estimate_cosine", "Cosine of Mean Estimator", "Cosine"),
        ("sample_variance", "Per-Sample Variance to True Gradient", "Mean squared distance per parameter"),
        ("batch_variance", "Batch-Average Variance to True Gradient", "Mean squared distance per parameter"),
    ]
    checkpoint_epochs = sorted(stats_df["checkpoint_epoch"].unique())

    for method in [method for method in METHODS if method in set(stats_df["method"])] :
        method_df = stats_df[stats_df["method"] == method]
        fig, axes = plt.subplots(
            len(checkpoint_epochs),
            len(metrics),
            figsize=(5 * len(metrics), 3.8 * len(checkpoint_epochs)),
            squeeze=False,
        )

        for row, checkpoint_epoch in enumerate(checkpoint_epochs):
            subset = method_df[method_df["checkpoint_epoch"] == checkpoint_epoch].sort_values("sigma")
            sigma_labels = [f"{sigma:.4g}" for sigma in subset["sigma"].to_numpy()]

            for col, (column, title, ylabel) in enumerate(metrics):
                axis = axes[row, col]
                axis.bar(sigma_labels, subset[column].to_numpy(), color=METHOD_COLORS[method])
                axis.set_title(f"epoch {checkpoint_epoch} | {title}")
                axis.set_xlabel("sigma")
                axis.set_ylabel(ylabel)
                axis.tick_params(axis="x", rotation=45)

        fig.suptitle(f"{METHOD_LABELS[method]} sigma search", y=1.02)
        fig.tight_layout()
        plt.show()


def build_grid(space):
    keys = list(space.keys())
    values = [space[key] for key in keys]
    return [dict(zip(keys, combo)) for combo in itertools.product(*values)]


def run_sweep(search_spaces, data, dimensions, sweep_epochs, seeds, device):
    results = []
    flat_records = []
    total_runs = sum(len(configs) * len(seeds) for configs in search_spaces.values())
    run_idx = 0

    print(f"Starting sweep with total_runs={total_runs}, device={device}")
    for method in METHODS:
        configs = search_spaces[method]
        for config in configs:
            for seed in seeds:
                run_idx += 1
                sigma_str = f", sigma={config['sigma']:.4g}" if "sigma" in config else ""
                print(f"\n=== Run {run_idx}/{total_runs} | {method} | lr={config['lr']:.4g}{sigma_str} | seed={seed} ===")
                result = train_one_run(
                    method=method,
                    run_config=config,
                    data=data,
                    dimensions=dimensions,
                    epochs=sweep_epochs,
                    seed=seed,
                    device=device,
                    print_every_epoch=1,
                )
                results.append(result)
                flat_record = {k: v for k, v in result.items() if k not in {"history", "state_dict"}}
                flat_record["seed"] = seed
                flat_records.append(flat_record)

    df = pd.DataFrame(flat_records)
    if len(df) > 0:
        df = df.sort_values(
            ["method", "final_test_acc", "best_test_acc", "final_test_loss"],
            ascending=[True, False, False, True],
        ).reset_index(drop=True)
    return results, df


def summarize_top_configs(df, top_k=5):
    if len(df) == 0:
        return df
    frames = []
    for method, group in df.groupby("method"):
        frames.append(group.head(top_k))
    return pd.concat(frames, ignore_index=True)


def select_best_configs(df):
    rows = []
    good = df[df["diverged"] == False]
    for method, group in good.groupby("method"):
        best = group.sort_values(
            ["final_test_acc", "best_test_acc", "final_test_loss"],
            ascending=[False, False, True],
        ).iloc[0]
        rows.append(best)
    return pd.DataFrame(rows).reset_index(drop=True)


def run_best_config_comparison(best_df, data, dimensions, final_epochs, seed, device):
    comparison_results = {}
    for row in best_df.itertuples(index=False):
        config = {"lr": float(row.lr)}
        if not pd.isna(row.sigma):
            config["sigma"] = float(row.sigma)
        print(
            f"\n### Final run | {row.method} | lr={config['lr']:.4g}" +
            (f", sigma={config['sigma']:.4g}" if 'sigma' in config else "")
        )
        comparison_results[row.method] = train_one_run(
            method=row.method,
            run_config=config,
            data=data,
            dimensions=dimensions,
            epochs=final_epochs,
            seed=seed,
            device=device,
            print_every_epoch=1,
        )
    return comparison_results


def results_table(results_by_method):
    rows = []
    for method in METHODS:
        if method not in results_by_method:
            continue
        result = results_by_method[method]
        rows.append(
            {
                "method": method,
                "final_train_loss": result["final_train_loss"],
                "final_train_acc": result["final_train_acc"],
                "final_test_loss": result["final_test_loss"],
                "final_test_acc": result["final_test_acc"],
                "best_test_loss": result["best_test_loss"],
                "best_test_acc": result["best_test_acc"],
                "diverged": result["diverged"],
                "duration_sec": result["duration_sec"],
            }
        )
    return pd.DataFrame(rows)


def plot_training_histories(results_by_method):
    fig, axes = plt.subplots(3, 1, figsize=(10, 11), sharex=True)
    for method in METHODS:
        if method not in results_by_method:
            continue
        result = results_by_method[method]
        history = result["history"]
        axes[0].plot(history["epoch"], history["train_loss"], label=f"{METHOD_LABELS[method]} train", color=METHOD_COLORS[method])
        axes[0].plot(history["epoch"], history["test_loss"], linestyle="--", label=f"{METHOD_LABELS[method]} test", color=METHOD_COLORS[method])
        axes[1].plot(history["epoch"], history["train_acc"], label=f"{METHOD_LABELS[method]} train", color=METHOD_COLORS[method])
        axes[1].plot(history["epoch"], history["test_acc"], linestyle="--", label=f"{METHOD_LABELS[method]} test", color=METHOD_COLORS[method])
        axes[2].plot(history["epoch"], history["weight_norm"], label=METHOD_LABELS[method], color=METHOD_COLORS[method])
    axes[0].set_title("Loss")
    axes[0].set_ylabel("MSE")
    axes[0].legend(ncol=2)
    axes[1].set_title("Accuracy")
    axes[1].set_ylabel("Accuracy")
    axes[1].set_ylim(0.0, 1.0)
    axes[1].legend(ncol=2)
    axes[2].set_title("Weight Norm")
    axes[2].set_ylabel("L2 norm")
    axes[2].set_xlabel("Epoch")
    axes[2].legend(ncol=2)
    fig.tight_layout()
    plt.show()

# %%
# Default Colab-friendly setup.
# If you want a faster first pass, reduce TRAIN_LIMIT_SWEEP or SWEEP_EPOCHS.

#METHODS = ["bp", "np", "np_fan_in", "np_fixed", "wp"]
METHODS = ["wp"]

NUM_CLASSES = 10
DIMENSIONS = (32 * 32 * 3, 512, 256, NUM_CLASSES)
BATCH_SIZE = 128
EVAL_BATCH_SIZE = 1024
TRAIN_LIMIT_SWEEP = 20000
TRAIN_EVAL_LIMIT = 4000
TEST_LIMIT = 5000
SWEEP_EPOCHS = 8
FINAL_EPOCHS = 20
SWEEP_SEEDS = [0]
NUM_WORKERS = 0

SEARCH_SPACES = {
    "bp": build_grid({"lr": [0.2]}),
    "np": build_grid({"lr": [0.17/6, 0.18/6, 0.19/6], "sigma": [0.016, 0.0175, 0.01875]}),
    "np_fan_in": build_grid({"lr": [0.15/6, 0.16/6, 0.17/6], "sigma": [0.005, 0.0055, 0.006]}),
    "np_fixed": build_grid({"lr": [0.085/6, 0.09/6, 0.095/6], "sigma": [0.165, 0.19, 0.215]}),
    "wp": build_grid({"lr": [0.033/6, 0.036/6, 0.039/6], "sigma": [0.011, 0.0125, 0.015]}),
}



data = load_cifar10(
    train_limit=TRAIN_LIMIT_SWEEP,
    test_limit=TEST_LIMIT,
    train_eval_limit=TRAIN_EVAL_LIMIT,
    batch_size=BATCH_SIZE,
    eval_batch_size=EVAL_BATCH_SIZE,
    seed=0,
    mean_center_only=True,
    num_workers=NUM_WORKERS,
)

print(
    f"train_size={data['train_size']}, train_eval_size={data['train_eval_size']}, "
    f"test_size={data['test_size']}, dims={DIMENSIONS}, batch_size={BATCH_SIZE}, device={device}"
)
print({method: len(configs) for method, configs in SEARCH_SPACES.items()})
# Out:
# 100%|██████████| 170M/170M [00:06<00:00, 25.8MB/s]
# train_size=20000, train_eval_size=4000, test_size=5000, dims=(3072, 512, 256, 10), batch_size=128, device=cuda
# {'bp': 1, 'np': 9, 'np_fan_in': 9, 'np_fixed': 9, 'wp': 9}

# %%
# Run the modest default sweep.
# This should be manageable on a Colab GPU, but you can always reduce SWEEP_EPOCHS or the search spaces.

sweep_results, sweep_df = run_sweep(
    search_spaces=SEARCH_SPACES,
    data=data,
    dimensions=DIMENSIONS,
    sweep_epochs=SWEEP_EPOCHS,
    seeds=SWEEP_SEEDS,
    device=device,
)

display(summarize_top_configs(sweep_df, top_k=5))

best_configs_df = select_best_configs(sweep_df)
display(best_configs_df)
# Out:
# Starting sweep with total_runs=37, device=cuda
#
# === Run 1/37 | wp | lr=0.0055, sigma=0.011 | seed=0 ===
#     epoch  1/8 | wp | lr=0.0055, sigma=0.011 | train_loss=0.0956, train_acc=0.0950, test_loss=0.0958, test_acc=0.0934
#     epoch  2/8 | wp | lr=0.0055, sigma=0.011 | train_loss=0.0925, train_acc=0.1350, test_loss=0.0927, test_acc=0.1230
#     epoch  3/8 | wp | lr=0.0055, sigma=0.011 | train_loss=0.0903, train_acc=0.1750, test_loss=0.0905, test_acc=0.1644
#     epoch  4/8 | wp | lr=0.0055, sigma=0.011 | train_loss=0.0895, train_acc=0.1792, test_loss=0.0897, test_acc=0.1678
#     epoch  5/8 | wp | lr=0.0055, sigma=0.011 | train_loss=0.0889, train_acc=0.1815, test_loss=0.0891, test_acc=0.1768
#     epoch  6/8 | wp | lr=0.0055, sigma=0.011 | train_loss=0.0887, train_acc=0.1880, test_loss=0.0887, test_acc=0.1884
#     epoch  7/8 | wp | lr=0.0055, sigma=0.011 | train_loss=0.0880, train_acc=0.2080, test_loss=0.0882, test_acc=0.2052
#     epoch  8/8 | wp | lr=0.0055, sigma=0.011 | train_loss=0.0879, train_acc=0.1990, test_loss=0.0880, test_acc=0.2080
#
# === Run 2/37 | wp | lr=0.0055, sigma=0.0125 | seed=0 ===
#     epoch  1/8 | wp | lr=0.0055, sigma=0.0125 | train_loss=0.0955, train_acc=0.0975, test_loss=0.0957, test_acc=0.0910
#     epoch  2/8 | wp | lr=0.0055, sigma=0.0125 | train_loss=0.0924, train_acc=0.1365, test_loss=0.0927, test_acc=0.1240
#     epoch  3/8 | wp | lr=0.0055, sigma=0.0125 | train_loss=0.0903, train_acc=0.1740, test_loss=0.0906, test_acc=0.1632
#     epoch  4/8 | wp | lr=0.0055, sigma=0.0125 | train_loss=0.0896, train_acc=0.1777, test_loss=0.0898, test_acc=0.1788
#     epoch  5/8 | wp | lr=0.0055, sigma=0.0125 | train_loss=0.0890, train_acc=0.1807, test_loss=0.0891, test_acc=0.1788
#     epoch  6/8 | wp | lr=0.0055, sigma=0.0125 | train_loss=0.0887, train_acc=0.1895, test_loss=0.0887, test_acc=0.1816
#     epoch  7/8 | wp | lr=0.0055, sigma=0.0125 | train_loss=0.0881, train_acc=0.2008, test_loss=0.0882, test_acc=0.1986
#     epoch  8/8 | wp | lr=0.0055, sigma=0.0125 | train_loss=0.0880, train_acc=0.1950, test_loss=0.0881, test_acc=0.2000
#
# === Run 3/37 | wp | lr=0.0055, sigma=0.015 | seed=0 ===
#     epoch  1/8 | wp | lr=0.0055, sigma=0.015 | train_loss=0.0954, train_acc=0.0973, test_loss=0.0956, test_acc=0.0922
#     epoch  2/8 | wp | lr=0.0055, sigma=0.015 | train_loss=0.0923, train_acc=0.1348, test_loss=0.0926, test_acc=0.1258
#     epoch  3/8 | wp | lr=0.0055, sigma=0.015 | train_loss=0.0904, train_acc=0.1688, test_loss=0.0906, test_acc=0.1624
#     epoch  4/8 | wp | lr=0.0055, sigma=0.015 | train_loss=0.0897, train_acc=0.1750, test_loss=0.0899, test_acc=0.1768
#     epoch  5/8 | wp | lr=0.0055, sigma=0.015 | train_loss=0.0892, train_acc=0.1805, test_loss=0.0893, test_acc=0.1772
#     epoch  6/8 | wp | lr=0.0055, sigma=0.015 | train_loss=0.0889, train_acc=0.1840, test_loss=0.0890, test_acc=0.1796
#     epoch  7/8 | wp | lr=0.0055, sigma=0.015 | train_loss=0.0883, train_acc=0.1925, test_loss=0.0884, test_acc=0.1934
#     epoch  8/8 | wp | lr=0.0055, sigma=0.015 | train_loss=0.0882, train_acc=0.1875, test_loss=0.0883, test_acc=0.1928
#
# === Run 4/37 | wp | lr=0.006, sigma=0.011 | seed=0 ===
#     epoch  1/8 | wp | lr=0.006, sigma=0.011 | train_loss=0.0952, train_acc=0.0965, test_loss=0.0954, test_acc=0.0942
#     epoch  2/8 | wp | lr=0.006, sigma=0.011 | train_loss=0.0921, train_acc=0.1398, test_loss=0.0923, test_acc=0.1290
#     epoch  3/8 | wp | lr=0.006, sigma=0.011 | train_loss=0.0900, train_acc=0.1770, test_loss=0.0902, test_acc=0.1700
#     epoch  4/8 | wp | lr=0.006, sigma=0.011 | train_loss=0.0892, train_acc=0.1800, test_loss=0.0894, test_acc=0.1740
#     epoch  5/8 | wp | lr=0.006, sigma=0.011 | train_loss=0.0887, train_acc=0.1805, test_loss=0.0888, test_acc=0.1804
#     epoch  6/8 | wp | lr=0.006, sigma=0.011 | train_loss=0.0885, train_acc=0.1878, test_loss=0.0885, test_acc=0.1904
#     epoch  7/8 | wp | lr=0.006, sigma=0.011 | train_loss=0.0878, train_acc=0.2120, test_loss=0.0880, test_acc=0.2138
#     epoch  8/8 | wp | lr=0.006, sigma=0.011 | train_loss=0.0879, train_acc=0.2050, test_loss=0.0880, test_acc=0.2064
#
# === Run 5/37 | wp | lr=0.006, sigma=0.0125 | seed=0 ===
#     epoch  1/8 | wp | lr=0.006, sigma=0.0125 | train_loss=0.0951, train_acc=0.0963, test_loss=0.0953, test_acc=0.0930
#     epoch  2/8 | wp | lr=0.006, sigma=0.0125 | train_loss=0.0920, train_acc=0.1405, test_loss=0.0922, test_acc=0.1278
#     epoch  3/8 | wp | lr=0.006, sigma=0.0125 | train_loss=0.0900, train_acc=0.1775, test_loss=0.0902, test_acc=0.1678
#     epoch  4/8 | wp | lr=0.006, sigma=0.0125 | train_loss=0.0893, train_acc=0.1800, test_loss=0.0895, test_acc=0.1780
#     epoch  5/8 | wp | lr=0.006, sigma=0.0125 | train_loss=0.0888, train_acc=0.1830, test_loss=0.0889, test_acc=0.1812
#     epoch  6/8 | wp | lr=0.006, sigma=0.0125 | train_loss=0.0885, train_acc=0.1893, test_loss=0.0886, test_acc=0.1898
#     epoch  7/8 | wp | lr=0.006, sigma=0.0125 | train_loss=0.0879, train_acc=0.2067, test_loss=0.0881, test_acc=0.2028
#     epoch  8/8 | wp | lr=0.006, sigma=0.0125 | train_loss=0.0879, train_acc=0.1948, test_loss=0.0880, test_acc=0.2018
#
# === Run 6/37 | wp | lr=0.006, sigma=0.015 | seed=0 ===
#     epoch  1/8 | wp | lr=0.006, sigma=0.015 | train_loss=0.0950, train_acc=0.0970, test_loss=0.0952, test_acc=0.0928
#     epoch  2/8 | wp | lr=0.006, sigma=0.015 | train_loss=0.0920, train_acc=0.1385, test_loss=0.0922, test_acc=0.1286
#     epoch  3/8 | wp | lr=0.006, sigma=0.015 | train_loss=0.0901, train_acc=0.1742, test_loss=0.0903, test_acc=0.1664
#     epoch  4/8 | wp | lr=0.006, sigma=0.015 | train_loss=0.0895, train_acc=0.1780, test_loss=0.0896, test_acc=0.1822
#     epoch  5/8 | wp | lr=0.006, sigma=0.015 | train_loss=0.0890, train_acc=0.1810, test_loss=0.0891, test_acc=0.1840
#     epoch  6/8 | wp | lr=0.006, sigma=0.015 | train_loss=0.0887, train_acc=0.1860, test_loss=0.0888, test_acc=0.1834
#     epoch  7/8 | wp | lr=0.006, sigma=0.015 | train_loss=0.0881, train_acc=0.1980, test_loss=0.0883, test_acc=0.1914
#     epoch  8/8 | wp | lr=0.006, sigma=0.015 | train_loss=0.0881, train_acc=0.1888, test_loss=0.0882, test_acc=0.1926
#
# === Run 7/37 | wp | lr=0.0065, sigma=0.011 | seed=0 ===
#     epoch  1/8 | wp | lr=0.0065, sigma=0.011 | train_loss=0.0949, train_acc=0.0968, test_loss=0.0951, test_acc=0.0958
#     epoch  2/8 | wp | lr=0.0065, sigma=0.011 | train_loss=0.0917, train_acc=0.1432, test_loss=0.0919, test_acc=0.1322
#     epoch  3/8 | wp | lr=0.0065, sigma=0.011 | train_loss=0.0896, train_acc=0.1757, test_loss=0.0898, test_acc=0.1712
#     epoch  4/8 | wp | lr=0.0065, sigma=0.011 | train_loss=0.0889, train_acc=0.1847, test_loss=0.0891, test_acc=0.1700
#     epoch  5/8 | wp | lr=0.0065, sigma=0.011 | train_loss=0.0886, train_acc=0.1850, test_loss=0.0887, test_acc=0.1860
#     epoch  6/8 | wp | lr=0.0065, sigma=0.011 | train_loss=0.0884, train_acc=0.1888, test_loss=0.0884, test_acc=0.1942
#     epoch  7/8 | wp | lr=0.0065, sigma=0.011 | train_loss=0.0877, train_acc=0.2107, test_loss=0.0880, test_acc=0.2156
#     epoch  8/8 | wp | lr=0.0065, sigma=0.011 | train_loss=0.0881, train_acc=0.2075, test_loss=0.0883, test_acc=0.2114
#
# === Run 8/37 | wp | lr=0.0065, sigma=0.0125 | seed=0 ===
#     epoch  1/8 | wp | lr=0.0065, sigma=0.0125 | train_loss=0.0948, train_acc=0.0983, test_loss=0.0950, test_acc=0.0940
#     epoch  2/8 | wp | lr=0.0065, sigma=0.0125 | train_loss=0.0916, train_acc=0.1430, test_loss=0.0919, test_acc=0.1304
#     epoch  3/8 | wp | lr=0.0065, sigma=0.0125 | train_loss=0.0897, train_acc=0.1762, test_loss=0.0899, test_acc=0.1698
#     epoch  4/8 | wp | lr=0.0065, sigma=0.0125 | train_loss=0.0890, train_acc=0.1800, test_loss=0.0892, test_acc=0.1806
#     epoch  5/8 | wp | lr=0.0065, sigma=0.0125 | train_loss=0.0886, train_acc=0.1815, test_loss=0.0887, test_acc=0.1818
#     epoch  6/8 | wp | lr=0.0065, sigma=0.0125 | train_loss=0.0884, train_acc=0.1885, test_loss=0.0884, test_acc=0.1892
#     epoch  7/8 | wp | lr=0.0065, sigma=0.0125 | train_loss=0.0877, train_acc=0.2100, test_loss=0.0880, test_acc=0.2090
#     epoch  8/8 | wp | lr=0.0065, sigma=0.0125 | train_loss=0.0878, train_acc=0.2045, test_loss=0.0880, test_acc=0.2044
#
# === Run 9/37 | wp | lr=0.0065, sigma=0.015 | seed=0 ===
#     epoch  1/8 | wp | lr=0.0065, sigma=0.015 | train_loss=0.0946, train_acc=0.0990, test_loss=0.0948, test_acc=0.0938
#     epoch  2/8 | wp | lr=0.0065, sigma=0.015 | train_loss=0.0916, train_acc=0.1415, test_loss=0.0918, test_acc=0.1332
#     epoch  3/8 | wp | lr=0.0065, sigma=0.015 | train_loss=0.0898, train_acc=0.1762, test_loss=0.0900, test_acc=0.1694
#     epoch  4/8 | wp | lr=0.0065, sigma=0.015 | train_loss=0.0892, train_acc=0.1770, test_loss=0.0894, test_acc=0.1860
#     epoch  5/8 | wp | lr=0.0065, sigma=0.015 | train_loss=0.0888, train_acc=0.1832, test_loss=0.0889, test_acc=0.1846
#     epoch  6/8 | wp | lr=0.0065, sigma=0.015 | train_loss=0.0886, train_acc=0.1872, test_loss=0.0886, test_acc=0.1840
#     epoch  7/8 | wp | lr=0.0065, sigma=0.015 | train_loss=0.0879, train_acc=0.2010, test_loss=0.0881, test_acc=0.1984
#     epoch  8/8 | wp | lr=0.0065, sigma=0.015 | train_loss=0.0880, train_acc=0.1998, test_loss=0.0881, test_acc=0.1968
#   method      lr   sigma  epochs_completed  final_train_loss  final_train_acc  \
# 0     wp  0.0065  0.0110                 8          0.088050          0.20750
# 1     wp  0.0055  0.0110                 8          0.087908          0.19900
# 2     wp  0.0060  0.0110                 8          0.087855          0.20500
# 3     wp  0.0065  0.0125                 8          0.087825          0.20450
# 4     wp  0.0060  0.0125                 8          0.087880          0.19475
#
#    final_test_loss  final_test_acc  best_test_loss  best_test_acc  diverged  \
# 0         0.088259          0.2114        0.088023         0.2156     False
# 1         0.087982          0.2080        0.087982         0.2080     False
# 2         0.087991          0.2064        0.087991         0.2138     False
# 3         0.087994          0.2044        0.087977         0.2090     False
# 4         0.087986          0.2018        0.087986         0.2028     False
#
#    duration_sec  seed
# 0     13.176237     0
# 1     13.371300     0
# 2     13.210406     0
# 3     12.983671     0
# 4     13.292938     0
#   method      lr  sigma  epochs_completed  final_train_loss  final_train_acc  \
# 0     wp  0.0065  0.011                 8           0.08805           0.2075
#
#    final_test_loss  final_test_acc  best_test_loss  best_test_acc  diverged  \
# 0         0.088259          0.2114        0.088023         0.2156     False
#
#    duration_sec  seed
# 0     13.176237     0

# %%
# Run a deeper comparison on the best config per method.
# You can increase FINAL_EPOCHS if the sweep already identified a promising region.
FINAL_EPOCHS = 50
deep_results = run_best_config_comparison(
    best_df=best_configs_df,
    data=data,
    dimensions=DIMENSIONS,
    final_epochs=FINAL_EPOCHS,
    seed=0,
    device=device,
)

display(results_table(deep_results))
plot_training_histories(deep_results)
plot_layer_output_norm_histories(deep_results)
# Out:
# ### Final run | bp | lr=0.2
#     epoch  1/50 | bp | lr=0.2 | train_loss=0.0818, train_acc=0.3297, test_loss=0.0822, test_acc=0.3196
#     epoch  2/50 | bp | lr=0.2 | train_loss=0.0784, train_acc=0.3678, test_loss=0.0792, test_acc=0.3622
#     epoch  3/50 | bp | lr=0.2 | train_loss=0.0762, train_acc=0.3975, test_loss=0.0774, test_acc=0.3872
#     epoch  4/50 | bp | lr=0.2 | train_loss=0.0747, train_acc=0.4250, test_loss=0.0760, test_acc=0.4054
#     epoch  5/50 | bp | lr=0.2 | train_loss=0.0733, train_acc=0.4370, test_loss=0.0750, test_acc=0.4112
#     epoch  6/50 | bp | lr=0.2 | train_loss=0.0722, train_acc=0.4545, test_loss=0.0740, test_acc=0.4264
#     epoch  7/50 | bp | lr=0.2 | train_loss=0.0711, train_acc=0.4627, test_loss=0.0734, test_acc=0.4344
#     epoch  8/50 | bp | lr=0.2 | train_loss=0.0703, train_acc=0.4753, test_loss=0.0728, test_acc=0.4460
#     epoch  9/50 | bp | lr=0.2 | train_loss=0.0694, train_acc=0.4963, test_loss=0.0722, test_acc=0.4490
#     epoch 10/50 | bp | lr=0.2 | train_loss=0.0685, train_acc=0.5090, test_loss=0.0717, test_acc=0.4560
#     epoch 11/50 | bp | lr=0.2 | train_loss=0.0679, train_acc=0.5130, test_loss=0.0713, test_acc=0.4592
#     epoch 12/50 | bp | lr=0.2 | train_loss=0.0671, train_acc=0.5195, test_loss=0.0710, test_acc=0.4608
#     epoch 13/50 | bp | lr=0.2 | train_loss=0.0665, train_acc=0.5345, test_loss=0.0707, test_acc=0.4690
#     epoch 14/50 | bp | lr=0.2 | train_loss=0.0658, train_acc=0.5383, test_loss=0.0704, test_acc=0.4676
#     epoch 15/50 | bp | lr=0.2 | train_loss=0.0650, train_acc=0.5405, test_loss=0.0703, test_acc=0.4628
#     epoch 16/50 | bp | lr=0.2 | train_loss=0.0642, train_acc=0.5535, test_loss=0.0698, test_acc=0.4700
#     epoch 17/50 | bp | lr=0.2 | train_loss=0.0637, train_acc=0.5565, test_loss=0.0696, test_acc=0.4744
#     epoch 18/50 | bp | lr=0.2 | train_loss=0.0630, train_acc=0.5645, test_loss=0.0692, test_acc=0.4730
#     epoch 19/50 | bp | lr=0.2 | train_loss=0.0621, train_acc=0.5835, test_loss=0.0690, test_acc=0.4800
#     epoch 20/50 | bp | lr=0.2 | train_loss=0.0617, train_acc=0.5843, test_loss=0.0688, test_acc=0.4844
#     epoch 21/50 | bp | lr=0.2 | train_loss=0.0610, train_acc=0.5988, test_loss=0.0688, test_acc=0.4846
#     epoch 22/50 | bp | lr=0.2 | train_loss=0.0602, train_acc=0.5933, test_loss=0.0685, test_acc=0.4846
#     epoch 23/50 | bp | lr=0.2 | train_loss=0.0596, train_acc=0.6075, test_loss=0.0683, test_acc=0.4912
#     epoch 24/50 | bp | lr=0.2 | train_loss=0.0592, train_acc=0.6128, test_loss=0.0685, test_acc=0.4920
#     epoch 25/50 | bp | lr=0.2 | train_loss=0.0583, train_acc=0.6278, test_loss=0.0682, test_acc=0.4894
#     epoch 26/50 | bp | lr=0.2 | train_loss=0.0585, train_acc=0.6082, test_loss=0.0684, test_acc=0.4910
#     epoch 27/50 | bp | lr=0.2 | train_loss=0.0579, train_acc=0.6230, test_loss=0.0688, test_acc=0.4852
#     epoch 28/50 | bp | lr=0.2 | train_loss=0.0578, train_acc=0.6298, test_loss=0.0687, test_acc=0.4916
#     epoch 29/50 | bp | lr=0.2 | train_loss=0.0569, train_acc=0.6362, test_loss=0.0682, test_acc=0.4912
#     epoch 30/50 | bp | lr=0.2 | train_loss=0.0557, train_acc=0.6420, test_loss=0.0680, test_acc=0.4974
#     epoch 31/50 | bp | lr=0.2 | train_loss=0.0552, train_acc=0.6535, test_loss=0.0680, test_acc=0.4940
#     epoch 32/50 | bp | lr=0.2 | train_loss=0.0548, train_acc=0.6565, test_loss=0.0685, test_acc=0.4904
#     epoch 33/50 | bp | lr=0.2 | train_loss=0.0535, train_acc=0.6665, test_loss=0.0677, test_acc=0.4990
#     epoch 34/50 | bp | lr=0.2 | train_loss=0.0530, train_acc=0.6770, test_loss=0.0681, test_acc=0.4980
#     epoch 35/50 | bp | lr=0.2 | train_loss=0.0525, train_acc=0.6943, test_loss=0.0682, test_acc=0.4964
#     epoch 36/50 | bp | lr=0.2 | train_loss=0.0530, train_acc=0.6750, test_loss=0.0697, test_acc=0.4842
#     epoch 37/50 | bp | lr=0.2 | train_loss=0.0510, train_acc=0.7073, test_loss=0.0678, test_acc=0.5018
#     epoch 38/50 | bp | lr=0.2 | train_loss=0.0502, train_acc=0.7165, test_loss=0.0677, test_acc=0.5046
#     epoch 39/50 | bp | lr=0.2 | train_loss=0.0499, train_acc=0.7315, test_loss=0.0681, test_acc=0.4974
#     epoch 40/50 | bp | lr=0.2 | train_loss=0.0502, train_acc=0.7095, test_loss=0.0689, test_acc=0.5026
#     epoch 41/50 | bp | lr=0.2 | train_loss=0.0500, train_acc=0.7087, test_loss=0.0695, test_acc=0.4910
#     epoch 42/50 | bp | lr=0.2 | train_loss=0.0537, train_acc=0.6773, test_loss=0.0732, test_acc=0.4678
#     epoch 43/50 | bp | lr=0.2 | train_loss=0.0484, train_acc=0.7410, test_loss=0.0693, test_acc=0.4900
#     epoch 44/50 | bp | lr=0.2 | train_loss=0.0464, train_acc=0.7562, test_loss=0.0681, test_acc=0.5044
#     epoch 45/50 | bp | lr=0.2 | train_loss=0.0466, train_acc=0.7635, test_loss=0.0692, test_acc=0.4982
#     epoch 46/50 | bp | lr=0.2 | train_loss=0.0488, train_acc=0.7432, test_loss=0.0718, test_acc=0.4860
#     epoch 47/50 | bp | lr=0.2 | train_loss=0.0460, train_acc=0.7652, test_loss=0.0696, test_acc=0.5016
#     epoch 48/50 | bp | lr=0.2 | train_loss=0.0466, train_acc=0.7515, test_loss=0.0717, test_acc=0.4886
#     epoch 49/50 | bp | lr=0.2 | train_loss=0.0498, train_acc=0.7300, test_loss=0.0745, test_acc=0.4762
#     epoch 50/50 | bp | lr=0.2 | train_loss=0.0452, train_acc=0.7735, test_loss=0.0716, test_acc=0.4888
#
# ### Final run | np | lr=0.01333, sigma=0.015
#     epoch  1/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0914, train_acc=0.1547, test_loss=0.0916, test_acc=0.1402
#     epoch  2/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0891, train_acc=0.1650, test_loss=0.0892, test_acc=0.1616
#     epoch  3/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0884, train_acc=0.2040, test_loss=0.0884, test_acc=0.1954
#     epoch  4/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0877, train_acc=0.2080, test_loss=0.0878, test_acc=0.2028
#     epoch  5/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0871, train_acc=0.2240, test_loss=0.0872, test_acc=0.2198
#     epoch  6/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0866, train_acc=0.2415, test_loss=0.0867, test_acc=0.2446
#     epoch  7/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0863, train_acc=0.2707, test_loss=0.0865, test_acc=0.2610
#     epoch  8/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0858, train_acc=0.2530, test_loss=0.0859, test_acc=0.2422
#     epoch  9/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0856, train_acc=0.2670, test_loss=0.0857, test_acc=0.2592
#     epoch 10/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0852, train_acc=0.2700, test_loss=0.0854, test_acc=0.2668
#     epoch 11/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0851, train_acc=0.2725, test_loss=0.0852, test_acc=0.2772
#     epoch 12/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0848, train_acc=0.2752, test_loss=0.0848, test_acc=0.2840
#     epoch 13/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0846, train_acc=0.2825, test_loss=0.0847, test_acc=0.2926
#     epoch 14/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0840, train_acc=0.2945, test_loss=0.0841, test_acc=0.2944
#     epoch 15/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0837, train_acc=0.3105, test_loss=0.0839, test_acc=0.3042
#     epoch 16/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0836, train_acc=0.3003, test_loss=0.0837, test_acc=0.3000
#     epoch 17/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0837, train_acc=0.2878, test_loss=0.0838, test_acc=0.2872
#     epoch 18/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0834, train_acc=0.2963, test_loss=0.0835, test_acc=0.3022
#     epoch 19/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0834, train_acc=0.2838, test_loss=0.0834, test_acc=0.2916
#     epoch 20/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0832, train_acc=0.2995, test_loss=0.0833, test_acc=0.2990
#     epoch 21/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0828, train_acc=0.3140, test_loss=0.0830, test_acc=0.3100
#     epoch 22/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0829, train_acc=0.3100, test_loss=0.0831, test_acc=0.3108
#     epoch 23/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0827, train_acc=0.3202, test_loss=0.0830, test_acc=0.3248
#     epoch 24/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0823, train_acc=0.3167, test_loss=0.0826, test_acc=0.3214
#     epoch 25/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0823, train_acc=0.3157, test_loss=0.0825, test_acc=0.3118
#     epoch 26/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0823, train_acc=0.3132, test_loss=0.0825, test_acc=0.3174
#     epoch 27/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0821, train_acc=0.3172, test_loss=0.0823, test_acc=0.3218
#     epoch 28/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0818, train_acc=0.3295, test_loss=0.0821, test_acc=0.3142
#     epoch 29/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0819, train_acc=0.3172, test_loss=0.0822, test_acc=0.3152
#     epoch 30/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0821, train_acc=0.2958, test_loss=0.0822, test_acc=0.2988
#     epoch 31/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0817, train_acc=0.3240, test_loss=0.0819, test_acc=0.3234
#     epoch 32/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0817, train_acc=0.3322, test_loss=0.0820, test_acc=0.3374
#     epoch 33/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0817, train_acc=0.3232, test_loss=0.0819, test_acc=0.3332
#     epoch 34/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0815, train_acc=0.3337, test_loss=0.0817, test_acc=0.3434
#     epoch 35/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0821, train_acc=0.3048, test_loss=0.0823, test_acc=0.3132
#     epoch 36/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0815, train_acc=0.3167, test_loss=0.0817, test_acc=0.3254
#     epoch 37/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0814, train_acc=0.3130, test_loss=0.0817, test_acc=0.3188
#     epoch 38/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0820, train_acc=0.3207, test_loss=0.0824, test_acc=0.3222
#     epoch 39/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0813, train_acc=0.3232, test_loss=0.0817, test_acc=0.3266
#     epoch 40/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0813, train_acc=0.3365, test_loss=0.0817, test_acc=0.3304
#     epoch 41/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0815, train_acc=0.3180, test_loss=0.0818, test_acc=0.3200
#     epoch 42/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0814, train_acc=0.3252, test_loss=0.0818, test_acc=0.3210
#     epoch 43/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0813, train_acc=0.3302, test_loss=0.0818, test_acc=0.3276
#     epoch 44/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0813, train_acc=0.3272, test_loss=0.0818, test_acc=0.3322
#     epoch 45/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0812, train_acc=0.3155, test_loss=0.0817, test_acc=0.3226
#     epoch 46/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0819, train_acc=0.3257, test_loss=0.0826, test_acc=0.3224
#     epoch 47/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0821, train_acc=0.3028, test_loss=0.0825, test_acc=0.3040
#     epoch 48/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0816, train_acc=0.3257, test_loss=0.0819, test_acc=0.3248
#     epoch 49/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0819, train_acc=0.3212, test_loss=0.0824, test_acc=0.3168
#     epoch 50/50 | np | lr=0.01333, sigma=0.015 | train_loss=0.0814, train_acc=0.3290, test_loss=0.0820, test_acc=0.3280
#
# ### Final run | np_fan_in | lr=0.01, sigma=0.005
#     epoch  1/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0927, train_acc=0.1445, test_loss=0.0928, test_acc=0.1348
#     epoch  2/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0906, train_acc=0.1583, test_loss=0.0907, test_acc=0.1514
#     epoch  3/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0900, train_acc=0.1678, test_loss=0.0900, test_acc=0.1740
#     epoch  4/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0893, train_acc=0.1857, test_loss=0.0893, test_acc=0.1760
#     epoch  5/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0888, train_acc=0.1842, test_loss=0.0888, test_acc=0.1856
#     epoch  6/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0882, train_acc=0.2172, test_loss=0.0882, test_acc=0.2110
#     epoch  7/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0878, train_acc=0.2330, test_loss=0.0880, test_acc=0.2240
#     epoch  8/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0872, train_acc=0.2220, test_loss=0.0873, test_acc=0.2246
#     epoch  9/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0870, train_acc=0.2400, test_loss=0.0871, test_acc=0.2374
#     epoch 10/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0866, train_acc=0.2390, test_loss=0.0867, test_acc=0.2354
#     epoch 11/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0865, train_acc=0.2412, test_loss=0.0866, test_acc=0.2490
#     epoch 12/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0863, train_acc=0.2595, test_loss=0.0863, test_acc=0.2632
#     epoch 13/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0860, train_acc=0.2665, test_loss=0.0861, test_acc=0.2632
#     epoch 14/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0856, train_acc=0.2750, test_loss=0.0858, test_acc=0.2700
#     epoch 15/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0853, train_acc=0.2835, test_loss=0.0855, test_acc=0.2796
#     epoch 16/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0851, train_acc=0.2845, test_loss=0.0852, test_acc=0.2796
#     epoch 17/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0853, train_acc=0.2833, test_loss=0.0854, test_acc=0.2752
#     epoch 18/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0851, train_acc=0.2858, test_loss=0.0852, test_acc=0.2840
#     epoch 19/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0849, train_acc=0.2762, test_loss=0.0849, test_acc=0.2794
#     epoch 20/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0848, train_acc=0.2807, test_loss=0.0848, test_acc=0.2804
#     epoch 21/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0844, train_acc=0.2973, test_loss=0.0845, test_acc=0.2926
#     epoch 22/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0845, train_acc=0.2802, test_loss=0.0845, test_acc=0.2870
#     epoch 23/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0841, train_acc=0.2970, test_loss=0.0842, test_acc=0.2958
#     epoch 24/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0840, train_acc=0.2933, test_loss=0.0841, test_acc=0.2962
#     epoch 25/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0838, train_acc=0.2955, test_loss=0.0838, test_acc=0.2912
#     epoch 26/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0836, train_acc=0.2955, test_loss=0.0838, test_acc=0.2996
#     epoch 27/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0836, train_acc=0.3080, test_loss=0.0837, test_acc=0.3048
#     epoch 28/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0833, train_acc=0.2998, test_loss=0.0834, test_acc=0.2988
#     epoch 29/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0833, train_acc=0.3162, test_loss=0.0835, test_acc=0.3064
#     epoch 30/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0834, train_acc=0.3025, test_loss=0.0836, test_acc=0.2988
#     epoch 31/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0830, train_acc=0.3113, test_loss=0.0831, test_acc=0.3116
#     epoch 32/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0830, train_acc=0.3170, test_loss=0.0832, test_acc=0.3196
#     epoch 33/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0830, train_acc=0.3075, test_loss=0.0831, test_acc=0.3080
#     epoch 34/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0829, train_acc=0.3085, test_loss=0.0830, test_acc=0.3200
#     epoch 35/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0832, train_acc=0.2945, test_loss=0.0833, test_acc=0.3040
#     epoch 36/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0826, train_acc=0.3083, test_loss=0.0828, test_acc=0.3188
#     epoch 37/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0827, train_acc=0.3113, test_loss=0.0828, test_acc=0.3162
#     epoch 38/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0829, train_acc=0.3053, test_loss=0.0832, test_acc=0.3176
#     epoch 39/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0827, train_acc=0.3095, test_loss=0.0830, test_acc=0.3154
#     epoch 40/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0827, train_acc=0.3105, test_loss=0.0829, test_acc=0.3116
#     epoch 41/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0828, train_acc=0.2980, test_loss=0.0828, test_acc=0.3008
#     epoch 42/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0830, train_acc=0.3053, test_loss=0.0831, test_acc=0.3072
#     epoch 43/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0824, train_acc=0.3142, test_loss=0.0825, test_acc=0.3148
#     epoch 44/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0824, train_acc=0.3130, test_loss=0.0827, test_acc=0.3216
#     epoch 45/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0820, train_acc=0.3265, test_loss=0.0823, test_acc=0.3264
#     epoch 46/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0831, train_acc=0.3152, test_loss=0.0836, test_acc=0.3108
#     epoch 47/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0823, train_acc=0.3008, test_loss=0.0826, test_acc=0.3070
#     epoch 48/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0827, train_acc=0.3093, test_loss=0.0830, test_acc=0.3194
#     epoch 49/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0825, train_acc=0.3127, test_loss=0.0829, test_acc=0.3124
#     epoch 50/50 | np_fan_in | lr=0.01, sigma=0.005 | train_loss=0.0819, train_acc=0.3232, test_loss=0.0823, test_acc=0.3262
#
# ### Final run | np_fixed | lr=0.005, sigma=0.1
#     epoch  1/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0960, train_acc=0.1200, test_loss=0.0962, test_acc=0.1012
#     epoch  2/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0928, train_acc=0.1305, test_loss=0.0930, test_acc=0.1180
#     epoch  3/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0913, train_acc=0.1475, test_loss=0.0914, test_acc=0.1370
#     epoch  4/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0904, train_acc=0.1580, test_loss=0.0904, test_acc=0.1538
#     epoch  5/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0899, train_acc=0.1715, test_loss=0.0899, test_acc=0.1630
#     epoch  6/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0891, train_acc=0.1847, test_loss=0.0891, test_acc=0.1852
#     epoch  7/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0888, train_acc=0.1832, test_loss=0.0890, test_acc=0.1794
#     epoch  8/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0883, train_acc=0.1928, test_loss=0.0884, test_acc=0.1880
#     epoch  9/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0879, train_acc=0.2087, test_loss=0.0878, test_acc=0.2100
#     epoch 10/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0875, train_acc=0.2102, test_loss=0.0875, test_acc=0.2152
#     epoch 11/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0873, train_acc=0.2125, test_loss=0.0874, test_acc=0.2194
#     epoch 12/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0871, train_acc=0.2275, test_loss=0.0872, test_acc=0.2312
#     epoch 13/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0868, train_acc=0.2328, test_loss=0.0869, test_acc=0.2362
#     epoch 14/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0865, train_acc=0.2385, test_loss=0.0867, test_acc=0.2370
#     epoch 15/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0862, train_acc=0.2532, test_loss=0.0864, test_acc=0.2498
#     epoch 16/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0860, train_acc=0.2470, test_loss=0.0862, test_acc=0.2436
#     epoch 17/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0860, train_acc=0.2572, test_loss=0.0862, test_acc=0.2500
#     epoch 18/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0858, train_acc=0.2570, test_loss=0.0859, test_acc=0.2536
#     epoch 19/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0859, train_acc=0.2560, test_loss=0.0859, test_acc=0.2518
#     epoch 20/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0858, train_acc=0.2455, test_loss=0.0857, test_acc=0.2546
#     epoch 21/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0854, train_acc=0.2585, test_loss=0.0853, test_acc=0.2586
#     epoch 22/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0857, train_acc=0.2512, test_loss=0.0856, test_acc=0.2466
#     epoch 23/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0850, train_acc=0.2645, test_loss=0.0851, test_acc=0.2640
#     epoch 24/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0850, train_acc=0.2757, test_loss=0.0851, test_acc=0.2748
#     epoch 25/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0850, train_acc=0.2762, test_loss=0.0851, test_acc=0.2760
#     epoch 26/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0848, train_acc=0.2672, test_loss=0.0849, test_acc=0.2678
#     epoch 27/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0846, train_acc=0.2910, test_loss=0.0846, test_acc=0.2826
#     epoch 28/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0844, train_acc=0.2747, test_loss=0.0845, test_acc=0.2724
#     epoch 29/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0845, train_acc=0.2925, test_loss=0.0846, test_acc=0.2790
#     epoch 30/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0846, train_acc=0.2757, test_loss=0.0847, test_acc=0.2724
#     epoch 31/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0844, train_acc=0.2825, test_loss=0.0844, test_acc=0.2852
#     epoch 32/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0844, train_acc=0.2898, test_loss=0.0845, test_acc=0.2868
#     epoch 33/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0842, train_acc=0.2818, test_loss=0.0843, test_acc=0.2742
#     epoch 34/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0841, train_acc=0.2830, test_loss=0.0842, test_acc=0.2888
#     epoch 35/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0844, train_acc=0.2632, test_loss=0.0845, test_acc=0.2784
#     epoch 36/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0841, train_acc=0.2812, test_loss=0.0840, test_acc=0.2854
#     epoch 37/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0840, train_acc=0.2828, test_loss=0.0841, test_acc=0.2876
#     epoch 38/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0841, train_acc=0.2838, test_loss=0.0844, test_acc=0.2850
#     epoch 39/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0840, train_acc=0.2898, test_loss=0.0841, test_acc=0.2884
#     epoch 40/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0844, train_acc=0.2850, test_loss=0.0845, test_acc=0.2872
#     epoch 41/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0840, train_acc=0.2742, test_loss=0.0840, test_acc=0.2822
#     epoch 42/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0846, train_acc=0.2790, test_loss=0.0847, test_acc=0.2722
#     epoch 43/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0836, train_acc=0.2863, test_loss=0.0837, test_acc=0.2886
#     epoch 44/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0836, train_acc=0.2923, test_loss=0.0838, test_acc=0.2892
#     epoch 45/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0832, train_acc=0.2935, test_loss=0.0835, test_acc=0.3044
#     epoch 46/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0837, train_acc=0.2963, test_loss=0.0842, test_acc=0.2896
#     epoch 47/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0840, train_acc=0.2835, test_loss=0.0843, test_acc=0.2794
#     epoch 48/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0835, train_acc=0.2938, test_loss=0.0837, test_acc=0.3006
#     epoch 49/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0837, train_acc=0.2948, test_loss=0.0840, test_acc=0.2936
#     epoch 50/50 | np_fixed | lr=0.005, sigma=0.1 | train_loss=0.0828, train_acc=0.3120, test_loss=0.0833, test_acc=0.3118
#
# ### Final run | wp | lr=0.001667, sigma=0.015
#     epoch  1/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0993, train_acc=0.1042, test_loss=0.0996, test_acc=0.0924
#     epoch  2/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0975, train_acc=0.1098, test_loss=0.0978, test_acc=0.0976
#     epoch  3/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0959, train_acc=0.1165, test_loss=0.0962, test_acc=0.1030
#     epoch  4/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0949, train_acc=0.1197, test_loss=0.0951, test_acc=0.1058
#     epoch  5/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0940, train_acc=0.1288, test_loss=0.0942, test_acc=0.1128
#     epoch  6/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0931, train_acc=0.1333, test_loss=0.0933, test_acc=0.1188
#     epoch  7/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0924, train_acc=0.1410, test_loss=0.0925, test_acc=0.1264
#     epoch  8/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0918, train_acc=0.1460, test_loss=0.0919, test_acc=0.1356
#     epoch  9/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0913, train_acc=0.1560, test_loss=0.0914, test_acc=0.1478
#     epoch 10/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0909, train_acc=0.1562, test_loss=0.0910, test_acc=0.1502
#     epoch 11/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0905, train_acc=0.1562, test_loss=0.0906, test_acc=0.1530
#     epoch 12/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0902, train_acc=0.1605, test_loss=0.0904, test_acc=0.1580
#     epoch 13/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0900, train_acc=0.1588, test_loss=0.0901, test_acc=0.1630
#     epoch 14/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0898, train_acc=0.1673, test_loss=0.0899, test_acc=0.1662
#     epoch 15/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0896, train_acc=0.1695, test_loss=0.0897, test_acc=0.1710
#     epoch 16/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0894, train_acc=0.1698, test_loss=0.0895, test_acc=0.1704
#     epoch 17/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0893, train_acc=0.1690, test_loss=0.0894, test_acc=0.1748
#     epoch 18/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0891, train_acc=0.1767, test_loss=0.0892, test_acc=0.1748
#     epoch 19/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0890, train_acc=0.1837, test_loss=0.0891, test_acc=0.1832
#     epoch 20/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0889, train_acc=0.1772, test_loss=0.0890, test_acc=0.1806
#     epoch 21/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0888, train_acc=0.1822, test_loss=0.0888, test_acc=0.1888
#     epoch 22/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0887, train_acc=0.1878, test_loss=0.0887, test_acc=0.1884
#     epoch 23/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0886, train_acc=0.1935, test_loss=0.0886, test_acc=0.1918
#     epoch 24/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0884, train_acc=0.2013, test_loss=0.0885, test_acc=0.2014
#     epoch 25/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0883, train_acc=0.2057, test_loss=0.0884, test_acc=0.2012
#     epoch 26/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0882, train_acc=0.2087, test_loss=0.0883, test_acc=0.2028
#     epoch 27/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0881, train_acc=0.2175, test_loss=0.0881, test_acc=0.2136
#     epoch 28/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0879, train_acc=0.2205, test_loss=0.0880, test_acc=0.2162
#     epoch 29/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0879, train_acc=0.2245, test_loss=0.0879, test_acc=0.2192
#     epoch 30/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0878, train_acc=0.2230, test_loss=0.0878, test_acc=0.2234
#     epoch 31/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0878, train_acc=0.2285, test_loss=0.0878, test_acc=0.2252
#     epoch 32/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0878, train_acc=0.2303, test_loss=0.0878, test_acc=0.2248
#     epoch 33/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0877, train_acc=0.2298, test_loss=0.0877, test_acc=0.2248
#     epoch 34/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0877, train_acc=0.2270, test_loss=0.0877, test_acc=0.2280
#     epoch 35/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0875, train_acc=0.2310, test_loss=0.0876, test_acc=0.2284
#     epoch 36/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0875, train_acc=0.2298, test_loss=0.0875, test_acc=0.2298
#     epoch 37/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0874, train_acc=0.2280, test_loss=0.0874, test_acc=0.2324
#     epoch 38/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0873, train_acc=0.2315, test_loss=0.0874, test_acc=0.2348
#     epoch 39/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0872, train_acc=0.2273, test_loss=0.0873, test_acc=0.2310
#     epoch 40/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0871, train_acc=0.2335, test_loss=0.0872, test_acc=0.2370
#     epoch 41/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0870, train_acc=0.2285, test_loss=0.0871, test_acc=0.2370
#     epoch 42/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0869, train_acc=0.2263, test_loss=0.0870, test_acc=0.2350
#     epoch 43/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0869, train_acc=0.2343, test_loss=0.0869, test_acc=0.2424
#     epoch 44/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0868, train_acc=0.2355, test_loss=0.0868, test_acc=0.2428
#     epoch 45/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0867, train_acc=0.2347, test_loss=0.0867, test_acc=0.2448
#     epoch 46/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0867, train_acc=0.2360, test_loss=0.0867, test_acc=0.2404
#     epoch 47/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0867, train_acc=0.2367, test_loss=0.0867, test_acc=0.2418
#     epoch 48/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0866, train_acc=0.2370, test_loss=0.0866, test_acc=0.2398
#     epoch 49/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0866, train_acc=0.2392, test_loss=0.0866, test_acc=0.2418
#     epoch 50/50 | wp | lr=0.001667, sigma=0.015 | train_loss=0.0865, train_acc=0.2460, test_loss=0.0865, test_acc=0.2466
#       method  final_train_loss  final_train_acc  final_test_loss  \
# 0         bp          0.045173          0.77350         0.071573
# 1         np          0.081438          0.32900         0.081978
# 2  np_fan_in          0.081892          0.32325         0.082295
# 3   np_fixed          0.082844          0.31200         0.083278
# 4         wp          0.086514          0.24600         0.086522
#
#    final_test_acc  best_test_loss  best_test_acc  diverged  duration_sec
# 0          0.4888        0.067667         0.5046     False     32.620586
# 1          0.3280        0.081691         0.3434     False     39.613240
# 2          0.3262        0.082295         0.3264     False     38.010522
# 3          0.3118        0.083278         0.3118     False     38.200852
# 4          0.2466        0.086522         0.2466     False     82.788950

# %%
# Optional single-config runner.
# Edit RUN_CONFIGS and rerun this cell if you want to test one chosen setup.
METHODS = ["bp", "np", "np_fan_in", "np_fixed", "wp"]


RUN_EPOCHS = 100
RUN_SEED = 0
RUN_PRINT_EVERY_EPOCH = 1

RUN_CONFIGS = {
    "bp": {"lr": 0.1},
    "np": {"lr": (0.18/6)*0.4, "sigma": 0.0175},
    "np_fan_in": {"lr": (0.15/6)*0.4, "sigma": 0.0055},
    "np_fixed": {"lr": (0.09/6)*0.4, "sigma": 0.19},
    "wp": {"lr": (0.036/6)*0.4, "sigma": 0.0125},
}

single_results = {}

print(
    f"Running {len(RUN_CONFIGS)} config(s) | "
    f"epochs={RUN_EPOCHS}, seed={RUN_SEED}, dims={DIMENSIONS}, device={device}"
)

for method in METHODS:
    if method not in RUN_CONFIGS:
        continue
    config = RUN_CONFIGS[method]
    sigma_str = f", sigma={config['sigma']:.4g}" if "sigma" in config else ""
    print()
    print(f"### Final run | {method} | lr={config['lr']:.4g}{sigma_str}")
    single_results[method] = train_one_run(
        method=method,
        run_config=config,
        data=data,
        dimensions=DIMENSIONS,
        epochs=RUN_EPOCHS,
        seed=RUN_SEED,
        device=device,
        print_every_epoch=RUN_PRINT_EVERY_EPOCH,
    )

display(results_table(single_results))
plot_training_histories(single_results)
plot_layer_output_norm_histories(single_results)
# Out:
# Running 5 config(s) | epochs=100, seed=0, dims=(3072, 512, 256, 10), device=cuda
#
# ### Final run | bp | lr=0.1
#     epoch  1/100 | bp | lr=0.1 | train_loss=0.0846, train_acc=0.2953, test_loss=0.0848, test_acc=0.2838
#     epoch  2/100 | bp | lr=0.1 | train_loss=0.0818, train_acc=0.3310, test_loss=0.0821, test_acc=0.3254
#     epoch  3/100 | bp | lr=0.1 | train_loss=0.0797, train_acc=0.3598, test_loss=0.0804, test_acc=0.3530
#     epoch  4/100 | bp | lr=0.1 | train_loss=0.0783, train_acc=0.3777, test_loss=0.0791, test_acc=0.3672
#     epoch  5/100 | bp | lr=0.1 | train_loss=0.0771, train_acc=0.3882, test_loss=0.0781, test_acc=0.3766
#     epoch  6/100 | bp | lr=0.1 | train_loss=0.0761, train_acc=0.3960, test_loss=0.0772, test_acc=0.3860
#     epoch  7/100 | bp | lr=0.1 | train_loss=0.0753, train_acc=0.4060, test_loss=0.0765, test_acc=0.3960
#     epoch  8/100 | bp | lr=0.1 | train_loss=0.0745, train_acc=0.4218, test_loss=0.0759, test_acc=0.4044
#     epoch  9/100 | bp | lr=0.1 | train_loss=0.0738, train_acc=0.4343, test_loss=0.0753, test_acc=0.4090
#     epoch 10/100 | bp | lr=0.1 | train_loss=0.0732, train_acc=0.4387, test_loss=0.0748, test_acc=0.4182
#     epoch 11/100 | bp | lr=0.1 | train_loss=0.0726, train_acc=0.4472, test_loss=0.0743, test_acc=0.4240
#     epoch 12/100 | bp | lr=0.1 | train_loss=0.0720, train_acc=0.4570, test_loss=0.0739, test_acc=0.4280
#     epoch 13/100 | bp | lr=0.1 | train_loss=0.0714, train_acc=0.4713, test_loss=0.0735, test_acc=0.4352
#     epoch 14/100 | bp | lr=0.1 | train_loss=0.0710, train_acc=0.4715, test_loss=0.0732, test_acc=0.4374
#     epoch 15/100 | bp | lr=0.1 | train_loss=0.0704, train_acc=0.4745, test_loss=0.0729, test_acc=0.4420
#     epoch 16/100 | bp | lr=0.1 | train_loss=0.0700, train_acc=0.4860, test_loss=0.0726, test_acc=0.4470
#     epoch 17/100 | bp | lr=0.1 | train_loss=0.0696, train_acc=0.4875, test_loss=0.0723, test_acc=0.4502
#     epoch 18/100 | bp | lr=0.1 | train_loss=0.0692, train_acc=0.4948, test_loss=0.0721, test_acc=0.4496
#     epoch 19/100 | bp | lr=0.1 | train_loss=0.0687, train_acc=0.5040, test_loss=0.0718, test_acc=0.4572
#     epoch 20/100 | bp | lr=0.1 | train_loss=0.0683, train_acc=0.5065, test_loss=0.0716, test_acc=0.4574
#     epoch 21/100 | bp | lr=0.1 | train_loss=0.0678, train_acc=0.5175, test_loss=0.0713, test_acc=0.4602
#     epoch 22/100 | bp | lr=0.1 | train_loss=0.0674, train_acc=0.5152, test_loss=0.0711, test_acc=0.4612
#     epoch 23/100 | bp | lr=0.1 | train_loss=0.0670, train_acc=0.5258, test_loss=0.0709, test_acc=0.4648
#     epoch 24/100 | bp | lr=0.1 | train_loss=0.0667, train_acc=0.5302, test_loss=0.0708, test_acc=0.4668
#     epoch 25/100 | bp | lr=0.1 | train_loss=0.0663, train_acc=0.5335, test_loss=0.0706, test_acc=0.4662
#     epoch 26/100 | bp | lr=0.1 | train_loss=0.0661, train_acc=0.5333, test_loss=0.0704, test_acc=0.4650
#     epoch 27/100 | bp | lr=0.1 | train_loss=0.0657, train_acc=0.5375, test_loss=0.0704, test_acc=0.4664
#     epoch 28/100 | bp | lr=0.1 | train_loss=0.0654, train_acc=0.5455, test_loss=0.0701, test_acc=0.4682
#     epoch 29/100 | bp | lr=0.1 | train_loss=0.0650, train_acc=0.5525, test_loss=0.0699, test_acc=0.4732
#     epoch 30/100 | bp | lr=0.1 | train_loss=0.0645, train_acc=0.5587, test_loss=0.0697, test_acc=0.4742
#     epoch 31/100 | bp | lr=0.1 | train_loss=0.0643, train_acc=0.5555, test_loss=0.0697, test_acc=0.4716
#     epoch 32/100 | bp | lr=0.1 | train_loss=0.0638, train_acc=0.5643, test_loss=0.0696, test_acc=0.4732
#     epoch 33/100 | bp | lr=0.1 | train_loss=0.0634, train_acc=0.5673, test_loss=0.0693, test_acc=0.4768
#     epoch 34/100 | bp | lr=0.1 | train_loss=0.0631, train_acc=0.5753, test_loss=0.0693, test_acc=0.4794
#     epoch 35/100 | bp | lr=0.1 | train_loss=0.0628, train_acc=0.5763, test_loss=0.0692, test_acc=0.4800
#     epoch 36/100 | bp | lr=0.1 | train_loss=0.0625, train_acc=0.5727, test_loss=0.0693, test_acc=0.4770
#     epoch 37/100 | bp | lr=0.1 | train_loss=0.0621, train_acc=0.5793, test_loss=0.0689, test_acc=0.4816
#     epoch 38/100 | bp | lr=0.1 | train_loss=0.0617, train_acc=0.5883, test_loss=0.0687, test_acc=0.4804
#     epoch 39/100 | bp | lr=0.1 | train_loss=0.0614, train_acc=0.5913, test_loss=0.0687, test_acc=0.4816
#     epoch 40/100 | bp | lr=0.1 | train_loss=0.0613, train_acc=0.5917, test_loss=0.0688, test_acc=0.4840
#     epoch 41/100 | bp | lr=0.1 | train_loss=0.0608, train_acc=0.5940, test_loss=0.0686, test_acc=0.4816
#     epoch 42/100 | bp | lr=0.1 | train_loss=0.0608, train_acc=0.5975, test_loss=0.0687, test_acc=0.4838
#     epoch 43/100 | bp | lr=0.1 | train_loss=0.0601, train_acc=0.6038, test_loss=0.0684, test_acc=0.4844
#     epoch 44/100 | bp | lr=0.1 | train_loss=0.0596, train_acc=0.6108, test_loss=0.0681, test_acc=0.4904
#     epoch 45/100 | bp | lr=0.1 | train_loss=0.0593, train_acc=0.6152, test_loss=0.0682, test_acc=0.4902
#     epoch 46/100 | bp | lr=0.1 | train_loss=0.0590, train_acc=0.6185, test_loss=0.0681, test_acc=0.4898
#     epoch 47/100 | bp | lr=0.1 | train_loss=0.0588, train_acc=0.6262, test_loss=0.0681, test_acc=0.4920
#     epoch 48/100 | bp | lr=0.1 | train_loss=0.0584, train_acc=0.6285, test_loss=0.0682, test_acc=0.4920
#     epoch 49/100 | bp | lr=0.1 | train_loss=0.0581, train_acc=0.6285, test_loss=0.0680, test_acc=0.4938
#     epoch 50/100 | bp | lr=0.1 | train_loss=0.0577, train_acc=0.6352, test_loss=0.0680, test_acc=0.4942
#     epoch 51/100 | bp | lr=0.1 | train_loss=0.0575, train_acc=0.6318, test_loss=0.0680, test_acc=0.4898
#     epoch 52/100 | bp | lr=0.1 | train_loss=0.0569, train_acc=0.6458, test_loss=0.0679, test_acc=0.4966
#     epoch 53/100 | bp | lr=0.1 | train_loss=0.0568, train_acc=0.6390, test_loss=0.0678, test_acc=0.4956
#     epoch 54/100 | bp | lr=0.1 | train_loss=0.0564, train_acc=0.6478, test_loss=0.0678, test_acc=0.4964
#     epoch 55/100 | bp | lr=0.1 | train_loss=0.0559, train_acc=0.6525, test_loss=0.0677, test_acc=0.4966
#     epoch 56/100 | bp | lr=0.1 | train_loss=0.0560, train_acc=0.6540, test_loss=0.0678, test_acc=0.4962
#     epoch 57/100 | bp | lr=0.1 | train_loss=0.0553, train_acc=0.6637, test_loss=0.0678, test_acc=0.5008
#     epoch 58/100 | bp | lr=0.1 | train_loss=0.0550, train_acc=0.6717, test_loss=0.0677, test_acc=0.4992
#     epoch 59/100 | bp | lr=0.1 | train_loss=0.0546, train_acc=0.6673, test_loss=0.0677, test_acc=0.4992
#     epoch 60/100 | bp | lr=0.1 | train_loss=0.0544, train_acc=0.6737, test_loss=0.0674, test_acc=0.5032
#     epoch 61/100 | bp | lr=0.1 | train_loss=0.0538, train_acc=0.6855, test_loss=0.0676, test_acc=0.5038
#     epoch 62/100 | bp | lr=0.1 | train_loss=0.0536, train_acc=0.6783, test_loss=0.0676, test_acc=0.5044
#     epoch 63/100 | bp | lr=0.1 | train_loss=0.0532, train_acc=0.6847, test_loss=0.0674, test_acc=0.5008
#     epoch 64/100 | bp | lr=0.1 | train_loss=0.0529, train_acc=0.6847, test_loss=0.0673, test_acc=0.5018
#     epoch 65/100 | bp | lr=0.1 | train_loss=0.0530, train_acc=0.6853, test_loss=0.0679, test_acc=0.4942
#     epoch 66/100 | bp | lr=0.1 | train_loss=0.0522, train_acc=0.7007, test_loss=0.0674, test_acc=0.5076
#     epoch 67/100 | bp | lr=0.1 | train_loss=0.0520, train_acc=0.7063, test_loss=0.0676, test_acc=0.5070
#     epoch 68/100 | bp | lr=0.1 | train_loss=0.0518, train_acc=0.7055, test_loss=0.0675, test_acc=0.5062
#     epoch 69/100 | bp | lr=0.1 | train_loss=0.0515, train_acc=0.7010, test_loss=0.0678, test_acc=0.5076
#     epoch 70/100 | bp | lr=0.1 | train_loss=0.0508, train_acc=0.7025, test_loss=0.0675, test_acc=0.5066
#     epoch 71/100 | bp | lr=0.1 | train_loss=0.0503, train_acc=0.7165, test_loss=0.0674, test_acc=0.5072
#     epoch 72/100 | bp | lr=0.1 | train_loss=0.0504, train_acc=0.7157, test_loss=0.0678, test_acc=0.5042
#     epoch 73/100 | bp | lr=0.1 | train_loss=0.0498, train_acc=0.7195, test_loss=0.0675, test_acc=0.5058
#     epoch 74/100 | bp | lr=0.1 | train_loss=0.0496, train_acc=0.7285, test_loss=0.0677, test_acc=0.5014
#     epoch 75/100 | bp | lr=0.1 | train_loss=0.0491, train_acc=0.7375, test_loss=0.0678, test_acc=0.5082
#     epoch 76/100 | bp | lr=0.1 | train_loss=0.0485, train_acc=0.7365, test_loss=0.0674, test_acc=0.5124
#     epoch 77/100 | bp | lr=0.1 | train_loss=0.0487, train_acc=0.7378, test_loss=0.0682, test_acc=0.5008
#     epoch 78/100 | bp | lr=0.1 | train_loss=0.0481, train_acc=0.7392, test_loss=0.0677, test_acc=0.5100
#     epoch 79/100 | bp | lr=0.1 | train_loss=0.0475, train_acc=0.7520, test_loss=0.0675, test_acc=0.5096
#     epoch 80/100 | bp | lr=0.1 | train_loss=0.0472, train_acc=0.7510, test_loss=0.0677, test_acc=0.5080
#     epoch 81/100 | bp | lr=0.1 | train_loss=0.0468, train_acc=0.7588, test_loss=0.0679, test_acc=0.5090
#     epoch 82/100 | bp | lr=0.1 | train_loss=0.0465, train_acc=0.7562, test_loss=0.0681, test_acc=0.5072
#     epoch 83/100 | bp | lr=0.1 | train_loss=0.0460, train_acc=0.7650, test_loss=0.0676, test_acc=0.5078
#     epoch 84/100 | bp | lr=0.1 | train_loss=0.0462, train_acc=0.7685, test_loss=0.0684, test_acc=0.5062
#     epoch 85/100 | bp | lr=0.1 | train_loss=0.0453, train_acc=0.7708, test_loss=0.0678, test_acc=0.5120
#     epoch 86/100 | bp | lr=0.1 | train_loss=0.0460, train_acc=0.7522, test_loss=0.0692, test_acc=0.5002
#     epoch 87/100 | bp | lr=0.1 | train_loss=0.0465, train_acc=0.7510, test_loss=0.0704, test_acc=0.4912
#     epoch 88/100 | bp | lr=0.1 | train_loss=0.0451, train_acc=0.7732, test_loss=0.0687, test_acc=0.5024
#     epoch 89/100 | bp | lr=0.1 | train_loss=0.0441, train_acc=0.7840, test_loss=0.0683, test_acc=0.5096
#     epoch 90/100 | bp | lr=0.1 | train_loss=0.0434, train_acc=0.7960, test_loss=0.0683, test_acc=0.5098
#     epoch 91/100 | bp | lr=0.1 | train_loss=0.0430, train_acc=0.7933, test_loss=0.0679, test_acc=0.5080
#     epoch 92/100 | bp | lr=0.1 | train_loss=0.0427, train_acc=0.8067, test_loss=0.0683, test_acc=0.5110
#     epoch 93/100 | bp | lr=0.1 | train_loss=0.0434, train_acc=0.7980, test_loss=0.0691, test_acc=0.5086
#     epoch 94/100 | bp | lr=0.1 | train_loss=0.0443, train_acc=0.7943, test_loss=0.0704, test_acc=0.5000
#     epoch 95/100 | bp | lr=0.1 | train_loss=0.0425, train_acc=0.7975, test_loss=0.0691, test_acc=0.5040
#     epoch 96/100 | bp | lr=0.1 | train_loss=0.0418, train_acc=0.8153, test_loss=0.0691, test_acc=0.5066
#     epoch 97/100 | bp | lr=0.1 | train_loss=0.0416, train_acc=0.8007, test_loss=0.0694, test_acc=0.5038
#     epoch 98/100 | bp | lr=0.1 | train_loss=0.0423, train_acc=0.8097, test_loss=0.0705, test_acc=0.5060
#     epoch 99/100 | bp | lr=0.1 | train_loss=0.0407, train_acc=0.8187, test_loss=0.0694, test_acc=0.5040
#     epoch 100/100 | bp | lr=0.1 | train_loss=0.0402, train_acc=0.8277, test_loss=0.0695, test_acc=0.5058
#
# ### Final run | np | lr=0.012, sigma=0.0175
#     epoch  1/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0920, train_acc=0.1475, test_loss=0.0921, test_acc=0.1326
#     epoch  2/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0897, train_acc=0.1613, test_loss=0.0898, test_acc=0.1568
#     epoch  3/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0890, train_acc=0.1857, test_loss=0.0891, test_acc=0.1836
#     epoch  4/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0884, train_acc=0.1970, test_loss=0.0884, test_acc=0.1902
#     epoch  5/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0878, train_acc=0.2013, test_loss=0.0878, test_acc=0.2032
#     epoch  6/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0873, train_acc=0.2285, test_loss=0.0873, test_acc=0.2344
#     epoch  7/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0870, train_acc=0.2532, test_loss=0.0871, test_acc=0.2502
#     epoch  8/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0864, train_acc=0.2407, test_loss=0.0866, test_acc=0.2368
#     epoch  9/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0863, train_acc=0.2550, test_loss=0.0864, test_acc=0.2560
#     epoch 10/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0858, train_acc=0.2555, test_loss=0.0859, test_acc=0.2566
#     epoch 11/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0857, train_acc=0.2532, test_loss=0.0858, test_acc=0.2650
#     epoch 12/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0854, train_acc=0.2642, test_loss=0.0854, test_acc=0.2678
#     epoch 13/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0852, train_acc=0.2725, test_loss=0.0853, test_acc=0.2766
#     epoch 14/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0848, train_acc=0.2797, test_loss=0.0849, test_acc=0.2780
#     epoch 15/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0845, train_acc=0.2940, test_loss=0.0846, test_acc=0.2946
#     epoch 16/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0843, train_acc=0.2905, test_loss=0.0843, test_acc=0.2850
#     epoch 17/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0844, train_acc=0.2787, test_loss=0.0844, test_acc=0.2798
#     epoch 18/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0842, train_acc=0.2855, test_loss=0.0842, test_acc=0.2892
#     epoch 19/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0840, train_acc=0.2742, test_loss=0.0840, test_acc=0.2802
#     epoch 20/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0839, train_acc=0.2797, test_loss=0.0839, test_acc=0.2838
#     epoch 21/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0835, train_acc=0.3015, test_loss=0.0836, test_acc=0.3014
#     epoch 22/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0835, train_acc=0.2930, test_loss=0.0837, test_acc=0.3014
#     epoch 23/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0833, train_acc=0.3080, test_loss=0.0835, test_acc=0.3098
#     epoch 24/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0831, train_acc=0.3030, test_loss=0.0832, test_acc=0.3058
#     epoch 25/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0831, train_acc=0.2913, test_loss=0.0831, test_acc=0.2998
#     epoch 26/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0829, train_acc=0.2923, test_loss=0.0830, test_acc=0.2998
#     epoch 27/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0827, train_acc=0.3023, test_loss=0.0828, test_acc=0.3084
#     epoch 28/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0825, train_acc=0.3170, test_loss=0.0827, test_acc=0.3088
#     epoch 29/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0824, train_acc=0.3103, test_loss=0.0826, test_acc=0.3114
#     epoch 30/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0824, train_acc=0.2955, test_loss=0.0824, test_acc=0.2970
#     epoch 31/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0822, train_acc=0.3083, test_loss=0.0823, test_acc=0.3076
#     epoch 32/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0823, train_acc=0.3262, test_loss=0.0825, test_acc=0.3258
#     epoch 33/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0823, train_acc=0.3085, test_loss=0.0824, test_acc=0.3204
#     epoch 34/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0822, train_acc=0.3155, test_loss=0.0823, test_acc=0.3202
#     epoch 35/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0824, train_acc=0.3035, test_loss=0.0825, test_acc=0.3120
#     epoch 36/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0821, train_acc=0.2978, test_loss=0.0822, test_acc=0.3112
#     epoch 37/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0818, train_acc=0.3073, test_loss=0.0821, test_acc=0.3172
#     epoch 38/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0822, train_acc=0.3020, test_loss=0.0825, test_acc=0.3108
#     epoch 39/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0818, train_acc=0.3125, test_loss=0.0820, test_acc=0.3154
#     epoch 40/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0819, train_acc=0.3145, test_loss=0.0821, test_acc=0.3170
#     epoch 41/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0819, train_acc=0.3070, test_loss=0.0821, test_acc=0.3088
#     epoch 42/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0817, train_acc=0.3157, test_loss=0.0820, test_acc=0.3110
#     epoch 43/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0818, train_acc=0.3085, test_loss=0.0821, test_acc=0.3158
#     epoch 44/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0814, train_acc=0.3245, test_loss=0.0817, test_acc=0.3236
#     epoch 45/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0816, train_acc=0.3197, test_loss=0.0820, test_acc=0.3246
#     epoch 46/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0817, train_acc=0.3287, test_loss=0.0820, test_acc=0.3222
#     epoch 47/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0816, train_acc=0.3023, test_loss=0.0819, test_acc=0.2998
#     epoch 48/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0814, train_acc=0.3187, test_loss=0.0817, test_acc=0.3200
#     epoch 49/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0817, train_acc=0.3170, test_loss=0.0820, test_acc=0.3182
#     epoch 50/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0815, train_acc=0.3237, test_loss=0.0818, test_acc=0.3298
#     epoch 51/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0815, train_acc=0.3250, test_loss=0.0818, test_acc=0.3278
#     epoch 52/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0817, train_acc=0.3132, test_loss=0.0818, test_acc=0.3190
#     epoch 53/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0817, train_acc=0.3225, test_loss=0.0820, test_acc=0.3216
#     epoch 54/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0813, train_acc=0.3337, test_loss=0.0817, test_acc=0.3320
#     epoch 55/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0814, train_acc=0.3192, test_loss=0.0817, test_acc=0.3240
#     epoch 56/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0812, train_acc=0.3190, test_loss=0.0814, test_acc=0.3252
#     epoch 57/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0814, train_acc=0.3205, test_loss=0.0817, test_acc=0.3266
#     epoch 58/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0812, train_acc=0.3200, test_loss=0.0814, test_acc=0.3240
#     epoch 59/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0814, train_acc=0.3125, test_loss=0.0816, test_acc=0.3186
#     epoch 60/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0812, train_acc=0.3267, test_loss=0.0815, test_acc=0.3288
#     epoch 61/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0814, train_acc=0.3090, test_loss=0.0816, test_acc=0.3228
#     epoch 62/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0808, train_acc=0.3227, test_loss=0.0812, test_acc=0.3238
#     epoch 63/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0811, train_acc=0.3180, test_loss=0.0813, test_acc=0.3202
#     epoch 64/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0812, train_acc=0.3210, test_loss=0.0814, test_acc=0.3288
#     epoch 65/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0808, train_acc=0.3222, test_loss=0.0810, test_acc=0.3244
#     epoch 66/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0809, train_acc=0.3245, test_loss=0.0811, test_acc=0.3270
#     epoch 67/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0806, train_acc=0.3222, test_loss=0.0809, test_acc=0.3278
#     epoch 68/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0809, train_acc=0.3197, test_loss=0.0811, test_acc=0.3186
#     epoch 69/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0811, train_acc=0.3275, test_loss=0.0814, test_acc=0.3250
#     epoch 70/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0809, train_acc=0.3250, test_loss=0.0811, test_acc=0.3242
#     epoch 71/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0810, train_acc=0.3300, test_loss=0.0811, test_acc=0.3286
#     epoch 72/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0808, train_acc=0.3307, test_loss=0.0809, test_acc=0.3284
#     epoch 73/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0812, train_acc=0.3300, test_loss=0.0813, test_acc=0.3270
#     epoch 74/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0807, train_acc=0.3270, test_loss=0.0808, test_acc=0.3228
#     epoch 75/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0808, train_acc=0.3257, test_loss=0.0809, test_acc=0.3276
#     epoch 76/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0805, train_acc=0.3260, test_loss=0.0806, test_acc=0.3330
#     epoch 77/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0808, train_acc=0.3222, test_loss=0.0808, test_acc=0.3260
#     epoch 78/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0808, train_acc=0.3240, test_loss=0.0810, test_acc=0.3294
#     epoch 79/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0807, train_acc=0.3255, test_loss=0.0808, test_acc=0.3270
#     epoch 80/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0805, train_acc=0.3315, test_loss=0.0806, test_acc=0.3386
#     epoch 81/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0806, train_acc=0.3312, test_loss=0.0808, test_acc=0.3348
#     epoch 82/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0805, train_acc=0.3282, test_loss=0.0806, test_acc=0.3290
#     epoch 83/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0802, train_acc=0.3347, test_loss=0.0804, test_acc=0.3368
#     epoch 84/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0805, train_acc=0.3350, test_loss=0.0808, test_acc=0.3274
#     epoch 85/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0805, train_acc=0.3287, test_loss=0.0806, test_acc=0.3296
#     epoch 86/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0803, train_acc=0.3350, test_loss=0.0805, test_acc=0.3346
#     epoch 87/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0802, train_acc=0.3265, test_loss=0.0804, test_acc=0.3298
#     epoch 88/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0803, train_acc=0.3317, test_loss=0.0805, test_acc=0.3292
#     epoch 89/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0800, train_acc=0.3377, test_loss=0.0803, test_acc=0.3302
#     epoch 90/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0801, train_acc=0.3417, test_loss=0.0806, test_acc=0.3378
#     epoch 91/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0800, train_acc=0.3412, test_loss=0.0803, test_acc=0.3408
#     epoch 92/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0802, train_acc=0.3305, test_loss=0.0803, test_acc=0.3316
#     epoch 93/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0801, train_acc=0.3438, test_loss=0.0804, test_acc=0.3470
#     epoch 94/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0800, train_acc=0.3453, test_loss=0.0804, test_acc=0.3402
#     epoch 95/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0802, train_acc=0.3355, test_loss=0.0805, test_acc=0.3320
#     epoch 96/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0804, train_acc=0.3412, test_loss=0.0808, test_acc=0.3420
#     epoch 97/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0802, train_acc=0.3453, test_loss=0.0806, test_acc=0.3444
#     epoch 98/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0801, train_acc=0.3407, test_loss=0.0806, test_acc=0.3376
#     epoch 99/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0800, train_acc=0.3390, test_loss=0.0805, test_acc=0.3340
#     epoch 100/100 | np | lr=0.012, sigma=0.0175 | train_loss=0.0801, train_acc=0.3392, test_loss=0.0805, test_acc=0.3422
#
# ### Final run | np_fan_in | lr=0.01, sigma=0.0055
#     epoch  1/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0928, train_acc=0.1470, test_loss=0.0929, test_acc=0.1376
#     epoch  2/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0908, train_acc=0.1545, test_loss=0.0909, test_acc=0.1510
#     epoch  3/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0903, train_acc=0.1660, test_loss=0.0903, test_acc=0.1714
#     epoch  4/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0896, train_acc=0.1835, test_loss=0.0896, test_acc=0.1752
#     epoch  5/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0892, train_acc=0.1857, test_loss=0.0892, test_acc=0.1846
#     epoch  6/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0885, train_acc=0.2130, test_loss=0.0885, test_acc=0.2092
#     epoch  7/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0881, train_acc=0.2315, test_loss=0.0883, test_acc=0.2218
#     epoch  8/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0875, train_acc=0.2218, test_loss=0.0876, test_acc=0.2230
#     epoch  9/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0873, train_acc=0.2367, test_loss=0.0874, test_acc=0.2352
#     epoch 10/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0869, train_acc=0.2313, test_loss=0.0870, test_acc=0.2306
#     epoch 11/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0868, train_acc=0.2395, test_loss=0.0869, test_acc=0.2436
#     epoch 12/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0866, train_acc=0.2547, test_loss=0.0866, test_acc=0.2574
#     epoch 13/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0863, train_acc=0.2642, test_loss=0.0864, test_acc=0.2632
#     epoch 14/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0859, train_acc=0.2735, test_loss=0.0861, test_acc=0.2674
#     epoch 15/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0857, train_acc=0.2810, test_loss=0.0858, test_acc=0.2760
#     epoch 16/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0854, train_acc=0.2820, test_loss=0.0855, test_acc=0.2770
#     epoch 17/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0856, train_acc=0.2797, test_loss=0.0857, test_acc=0.2700
#     epoch 18/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0854, train_acc=0.2805, test_loss=0.0855, test_acc=0.2808
#     epoch 19/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0852, train_acc=0.2712, test_loss=0.0852, test_acc=0.2786
#     epoch 20/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0851, train_acc=0.2775, test_loss=0.0851, test_acc=0.2774
#     epoch 21/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0847, train_acc=0.2940, test_loss=0.0848, test_acc=0.2914
#     epoch 22/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0847, train_acc=0.2757, test_loss=0.0848, test_acc=0.2834
#     epoch 23/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0844, train_acc=0.2935, test_loss=0.0845, test_acc=0.2958
#     epoch 24/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0843, train_acc=0.2875, test_loss=0.0844, test_acc=0.2920
#     epoch 25/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0841, train_acc=0.2883, test_loss=0.0841, test_acc=0.2864
#     epoch 26/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0839, train_acc=0.2898, test_loss=0.0840, test_acc=0.2966
#     epoch 27/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0838, train_acc=0.2988, test_loss=0.0839, test_acc=0.3024
#     epoch 28/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0835, train_acc=0.2983, test_loss=0.0837, test_acc=0.2954
#     epoch 29/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0835, train_acc=0.3127, test_loss=0.0837, test_acc=0.3016
#     epoch 30/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0835, train_acc=0.3013, test_loss=0.0837, test_acc=0.2998
#     epoch 31/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0831, train_acc=0.3053, test_loss=0.0833, test_acc=0.3074
#     epoch 32/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0833, train_acc=0.3167, test_loss=0.0834, test_acc=0.3142
#     epoch 33/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0833, train_acc=0.3070, test_loss=0.0834, test_acc=0.3090
#     epoch 34/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0832, train_acc=0.3073, test_loss=0.0833, test_acc=0.3174
#     epoch 35/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0834, train_acc=0.2930, test_loss=0.0835, test_acc=0.3034
#     epoch 36/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0829, train_acc=0.3023, test_loss=0.0830, test_acc=0.3120
#     epoch 37/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0828, train_acc=0.3083, test_loss=0.0830, test_acc=0.3126
#     epoch 38/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0831, train_acc=0.3018, test_loss=0.0834, test_acc=0.3146
#     epoch 39/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0830, train_acc=0.3073, test_loss=0.0832, test_acc=0.3130
#     epoch 40/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0829, train_acc=0.3073, test_loss=0.0831, test_acc=0.3110
#     epoch 41/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0829, train_acc=0.2985, test_loss=0.0830, test_acc=0.3008
#     epoch 42/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0830, train_acc=0.2973, test_loss=0.0831, test_acc=0.3016
#     epoch 43/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0827, train_acc=0.3080, test_loss=0.0827, test_acc=0.3122
#     epoch 44/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0825, train_acc=0.3162, test_loss=0.0827, test_acc=0.3196
#     epoch 45/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0823, train_acc=0.3232, test_loss=0.0825, test_acc=0.3252
#     epoch 46/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0828, train_acc=0.3137, test_loss=0.0833, test_acc=0.3126
#     epoch 47/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0823, train_acc=0.3008, test_loss=0.0826, test_acc=0.3050
#     epoch 48/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0828, train_acc=0.3080, test_loss=0.0830, test_acc=0.3162
#     epoch 49/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0826, train_acc=0.3073, test_loss=0.0829, test_acc=0.3080
#     epoch 50/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0821, train_acc=0.3242, test_loss=0.0824, test_acc=0.3246
#     epoch 51/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0822, train_acc=0.3080, test_loss=0.0825, test_acc=0.3200
#     epoch 52/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0827, train_acc=0.3078, test_loss=0.0828, test_acc=0.3256
#     epoch 53/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0828, train_acc=0.3000, test_loss=0.0829, test_acc=0.3024
#     epoch 54/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0822, train_acc=0.3222, test_loss=0.0825, test_acc=0.3258
#     epoch 55/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0829, train_acc=0.3095, test_loss=0.0833, test_acc=0.3130
#     epoch 56/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0828, train_acc=0.3030, test_loss=0.0830, test_acc=0.3014
#     epoch 57/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0823, train_acc=0.3115, test_loss=0.0827, test_acc=0.3172
#     epoch 58/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0827, train_acc=0.2960, test_loss=0.0830, test_acc=0.2962
#     epoch 59/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0840, train_acc=0.2953, test_loss=0.0843, test_acc=0.2950
#     epoch 60/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0828, train_acc=0.3177, test_loss=0.0832, test_acc=0.3168
#     epoch 61/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0825, train_acc=0.3205, test_loss=0.0827, test_acc=0.3244
#     epoch 62/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0841, train_acc=0.3075, test_loss=0.0848, test_acc=0.3062
#     epoch 63/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0851, train_acc=0.3068, test_loss=0.0857, test_acc=0.3028
#     epoch 64/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0832, train_acc=0.2990, test_loss=0.0835, test_acc=0.3032
#     epoch 65/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0838, train_acc=0.2920, test_loss=0.0840, test_acc=0.2952
#     epoch 66/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0825, train_acc=0.3093, test_loss=0.0827, test_acc=0.2996
#     epoch 67/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0838, train_acc=0.2945, test_loss=0.0838, test_acc=0.2986
#     epoch 68/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0877, train_acc=0.2667, test_loss=0.0878, test_acc=0.2580
#     epoch 69/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0840, train_acc=0.3113, test_loss=0.0844, test_acc=0.3136
#     epoch 70/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0821, train_acc=0.3265, test_loss=0.0824, test_acc=0.3250
#     epoch 71/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0867, train_acc=0.3068, test_loss=0.0872, test_acc=0.2986
#     epoch 72/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0827, train_acc=0.3038, test_loss=0.0829, test_acc=0.3064
#     epoch 73/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0842, train_acc=0.3247, test_loss=0.0846, test_acc=0.3202
#     epoch 74/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0836, train_acc=0.3030, test_loss=0.0837, test_acc=0.3060
#     epoch 75/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0828, train_acc=0.3177, test_loss=0.0830, test_acc=0.3164
#     epoch 76/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0846, train_acc=0.3210, test_loss=0.0850, test_acc=0.3250
#     epoch 77/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0841, train_acc=0.3000, test_loss=0.0843, test_acc=0.3116
#     epoch 78/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.1026, train_acc=0.2645, test_loss=0.1038, test_acc=0.2572
#     epoch 79/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0854, train_acc=0.2555, test_loss=0.0856, test_acc=0.2614
#     epoch 80/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0845, train_acc=0.3125, test_loss=0.0847, test_acc=0.3078
#     epoch 81/100 | np_fan_in | lr=0.01, sigma=0.0055 | train_loss=0.0829, train_acc=0.3207, test_loss=0.0830, test_acc=0.3250
#     diverged at epoch 82/100 | train_loss=nan, test_loss=nan, test_acc=0.1028
#
# ### Final run | np_fixed | lr=0.006, sigma=0.19
#     epoch  1/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0948, train_acc=0.1298, test_loss=0.0950, test_acc=0.1096
#     epoch  2/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0923, train_acc=0.1442, test_loss=0.0924, test_acc=0.1408
#     epoch  3/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0916, train_acc=0.1460, test_loss=0.0916, test_acc=0.1510
#     epoch  4/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0910, train_acc=0.1462, test_loss=0.0909, test_acc=0.1434
#     epoch  5/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0906, train_acc=0.1520, test_loss=0.0905, test_acc=0.1474
#     epoch  6/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0898, train_acc=0.1693, test_loss=0.0898, test_acc=0.1712
#     epoch  7/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0894, train_acc=0.1787, test_loss=0.0896, test_acc=0.1692
#     epoch  8/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0888, train_acc=0.1913, test_loss=0.0889, test_acc=0.1866
#     epoch  9/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0884, train_acc=0.2085, test_loss=0.0884, test_acc=0.2046
#     epoch 10/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0881, train_acc=0.2102, test_loss=0.0881, test_acc=0.2122
#     epoch 11/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0879, train_acc=0.2055, test_loss=0.0880, test_acc=0.2062
#     epoch 12/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0877, train_acc=0.2200, test_loss=0.0878, test_acc=0.2200
#     epoch 13/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0871, train_acc=0.2303, test_loss=0.0874, test_acc=0.2306
#     epoch 14/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0868, train_acc=0.2303, test_loss=0.0870, test_acc=0.2314
#     epoch 15/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0866, train_acc=0.2490, test_loss=0.0867, test_acc=0.2498
#     epoch 16/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0864, train_acc=0.2502, test_loss=0.0865, test_acc=0.2428
#     epoch 17/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0865, train_acc=0.2487, test_loss=0.0866, test_acc=0.2432
#     epoch 18/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0861, train_acc=0.2530, test_loss=0.0862, test_acc=0.2532
#     epoch 19/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0862, train_acc=0.2547, test_loss=0.0862, test_acc=0.2534
#     epoch 20/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0861, train_acc=0.2530, test_loss=0.0860, test_acc=0.2618
#     epoch 21/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0855, train_acc=0.2685, test_loss=0.0855, test_acc=0.2662
#     epoch 22/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0859, train_acc=0.2532, test_loss=0.0857, test_acc=0.2528
#     epoch 23/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0853, train_acc=0.2652, test_loss=0.0853, test_acc=0.2674
#     epoch 24/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0852, train_acc=0.2662, test_loss=0.0853, test_acc=0.2706
#     epoch 25/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0851, train_acc=0.2677, test_loss=0.0850, test_acc=0.2772
#     epoch 26/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0849, train_acc=0.2767, test_loss=0.0851, test_acc=0.2716
#     epoch 27/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0848, train_acc=0.2823, test_loss=0.0847, test_acc=0.2824
#     epoch 28/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0847, train_acc=0.2710, test_loss=0.0847, test_acc=0.2736
#     epoch 29/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0845, train_acc=0.2865, test_loss=0.0847, test_acc=0.2862
#     epoch 30/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0847, train_acc=0.2692, test_loss=0.0847, test_acc=0.2798
#     epoch 31/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0844, train_acc=0.2820, test_loss=0.0844, test_acc=0.2922
#     epoch 32/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0845, train_acc=0.2777, test_loss=0.0845, test_acc=0.2776
#     epoch 33/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0844, train_acc=0.2868, test_loss=0.0845, test_acc=0.2840
#     epoch 34/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0842, train_acc=0.2898, test_loss=0.0843, test_acc=0.2908
#     epoch 35/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0847, train_acc=0.2642, test_loss=0.0847, test_acc=0.2780
#     epoch 36/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0843, train_acc=0.2775, test_loss=0.0841, test_acc=0.2914
#     epoch 37/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0841, train_acc=0.2860, test_loss=0.0842, test_acc=0.2944
#     epoch 38/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0845, train_acc=0.2807, test_loss=0.0846, test_acc=0.2878
#     epoch 39/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0843, train_acc=0.2812, test_loss=0.0844, test_acc=0.2888
#     epoch 40/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0844, train_acc=0.2807, test_loss=0.0844, test_acc=0.2866
#     epoch 41/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0840, train_acc=0.2795, test_loss=0.0840, test_acc=0.2848
#     epoch 42/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0841, train_acc=0.2722, test_loss=0.0842, test_acc=0.2660
#     epoch 43/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0839, train_acc=0.2833, test_loss=0.0840, test_acc=0.2884
#     epoch 44/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0836, train_acc=0.2983, test_loss=0.0838, test_acc=0.3010
#     epoch 45/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0836, train_acc=0.3030, test_loss=0.0838, test_acc=0.3052
#     epoch 46/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0839, train_acc=0.2940, test_loss=0.0842, test_acc=0.2948
#     epoch 47/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0838, train_acc=0.2797, test_loss=0.0841, test_acc=0.2884
#     epoch 48/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0834, train_acc=0.2988, test_loss=0.0836, test_acc=0.2968
#     epoch 49/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0839, train_acc=0.2833, test_loss=0.0841, test_acc=0.2806
#     epoch 50/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0833, train_acc=0.2993, test_loss=0.0835, test_acc=0.2984
#     epoch 51/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0832, train_acc=0.2995, test_loss=0.0834, test_acc=0.3026
#     epoch 52/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0836, train_acc=0.2903, test_loss=0.0837, test_acc=0.3038
#     epoch 53/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0840, train_acc=0.2963, test_loss=0.0842, test_acc=0.2984
#     epoch 54/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0833, train_acc=0.2983, test_loss=0.0837, test_acc=0.3022
#     epoch 55/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0836, train_acc=0.2865, test_loss=0.0841, test_acc=0.2856
#     epoch 56/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0833, train_acc=0.2940, test_loss=0.0837, test_acc=0.2960
#     epoch 57/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0834, train_acc=0.2893, test_loss=0.0837, test_acc=0.2930
#     epoch 58/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0837, train_acc=0.2858, test_loss=0.0837, test_acc=0.2926
#     epoch 59/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0841, train_acc=0.2795, test_loss=0.0844, test_acc=0.2808
#     epoch 60/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0833, train_acc=0.3028, test_loss=0.0835, test_acc=0.3084
#     epoch 61/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0831, train_acc=0.3008, test_loss=0.0834, test_acc=0.3104
#     epoch 62/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0839, train_acc=0.2918, test_loss=0.0844, test_acc=0.3038
#     epoch 63/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0845, train_acc=0.2933, test_loss=0.0848, test_acc=0.2926
#     epoch 64/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0835, train_acc=0.2875, test_loss=0.0836, test_acc=0.2918
#     epoch 65/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0833, train_acc=0.3010, test_loss=0.0833, test_acc=0.3040
#     epoch 66/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0842, train_acc=0.3113, test_loss=0.0843, test_acc=0.2984
#     epoch 67/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0845, train_acc=0.2900, test_loss=0.0845, test_acc=0.2880
#     epoch 68/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0861, train_acc=0.2665, test_loss=0.0861, test_acc=0.2704
#     epoch 69/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0853, train_acc=0.2998, test_loss=0.0856, test_acc=0.3052
#     epoch 70/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0841, train_acc=0.2960, test_loss=0.0844, test_acc=0.2970
#     epoch 71/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0861, train_acc=0.2855, test_loss=0.0863, test_acc=0.2922
#     epoch 72/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0836, train_acc=0.2958, test_loss=0.0838, test_acc=0.3076
#     epoch 73/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0836, train_acc=0.3023, test_loss=0.0838, test_acc=0.2920
#     epoch 74/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0834, train_acc=0.2965, test_loss=0.0835, test_acc=0.2970
#     epoch 75/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0839, train_acc=0.2963, test_loss=0.0842, test_acc=0.3028
#     epoch 76/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0840, train_acc=0.3040, test_loss=0.0842, test_acc=0.3076
#     epoch 77/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0841, train_acc=0.2943, test_loss=0.0842, test_acc=0.2938
#     epoch 78/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0916, train_acc=0.2823, test_loss=0.0923, test_acc=0.2774
#     epoch 79/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0857, train_acc=0.2775, test_loss=0.0862, test_acc=0.2848
#     epoch 80/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0850, train_acc=0.2898, test_loss=0.0853, test_acc=0.2884
#     epoch 81/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0838, train_acc=0.3100, test_loss=0.0842, test_acc=0.2992
#     epoch 82/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0855, train_acc=0.3030, test_loss=0.0862, test_acc=0.2916
#     epoch 83/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0871, train_acc=0.2920, test_loss=0.0874, test_acc=0.2828
#     epoch 84/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0911, train_acc=0.2657, test_loss=0.0916, test_acc=0.2628
#     epoch 85/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0837, train_acc=0.3023, test_loss=0.0840, test_acc=0.3018
#     epoch 86/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0885, train_acc=0.2722, test_loss=0.0887, test_acc=0.2662
#     epoch 87/100 | np_fixed | lr=0.006, sigma=0.19 | train_loss=0.0863, train_acc=0.3033, test_loss=0.0869, test_acc=0.3010
#     diverged at epoch 88/100 | train_loss=nan, test_loss=nan, test_acc=0.1028
#
# ### Final run | wp | lr=0.0024, sigma=0.0125
#     epoch  1/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0986, train_acc=0.1035, test_loss=0.0989, test_acc=0.0958
#     epoch  2/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0966, train_acc=0.1013, test_loss=0.0969, test_acc=0.0942
#     epoch  3/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0948, train_acc=0.1165, test_loss=0.0950, test_acc=0.1036
#     epoch  4/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0934, train_acc=0.1340, test_loss=0.0935, test_acc=0.1166
#     epoch  5/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0923, train_acc=0.1360, test_loss=0.0925, test_acc=0.1270
#     epoch  6/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0916, train_acc=0.1442, test_loss=0.0918, test_acc=0.1362
#     epoch  7/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0908, train_acc=0.1522, test_loss=0.0910, test_acc=0.1424
#     epoch  8/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0904, train_acc=0.1603, test_loss=0.0905, test_acc=0.1482
#     epoch  9/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0899, train_acc=0.1658, test_loss=0.0901, test_acc=0.1534
#     epoch 10/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0895, train_acc=0.1752, test_loss=0.0896, test_acc=0.1572
#     epoch 11/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0892, train_acc=0.1885, test_loss=0.0893, test_acc=0.1698
#     epoch 12/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0888, train_acc=0.1980, test_loss=0.0890, test_acc=0.1802
#     epoch 13/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0885, train_acc=0.2080, test_loss=0.0887, test_acc=0.1918
#     epoch 14/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0884, train_acc=0.1995, test_loss=0.0886, test_acc=0.1908
#     epoch 15/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0882, train_acc=0.1958, test_loss=0.0884, test_acc=0.1942
#     epoch 16/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0880, train_acc=0.2122, test_loss=0.0881, test_acc=0.2014
#     epoch 17/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0879, train_acc=0.2117, test_loss=0.0880, test_acc=0.2018
#     epoch 18/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0878, train_acc=0.2090, test_loss=0.0879, test_acc=0.2032
#     epoch 19/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0876, train_acc=0.2110, test_loss=0.0878, test_acc=0.2048
#     epoch 20/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0876, train_acc=0.2253, test_loss=0.0877, test_acc=0.2068
#     epoch 21/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0875, train_acc=0.2195, test_loss=0.0876, test_acc=0.2040
#     epoch 22/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0874, train_acc=0.2193, test_loss=0.0876, test_acc=0.2024
#     epoch 23/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0873, train_acc=0.2255, test_loss=0.0874, test_acc=0.2162
#     epoch 24/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0872, train_acc=0.2318, test_loss=0.0872, test_acc=0.2186
#     epoch 25/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0869, train_acc=0.2380, test_loss=0.0870, test_acc=0.2274
#     epoch 26/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0867, train_acc=0.2397, test_loss=0.0868, test_acc=0.2396
#     epoch 27/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0867, train_acc=0.2360, test_loss=0.0867, test_acc=0.2332
#     epoch 28/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0866, train_acc=0.2372, test_loss=0.0866, test_acc=0.2326
#     epoch 29/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0864, train_acc=0.2467, test_loss=0.0864, test_acc=0.2416
#     epoch 30/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0864, train_acc=0.2407, test_loss=0.0864, test_acc=0.2348
#     epoch 31/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0863, train_acc=0.2505, test_loss=0.0863, test_acc=0.2504
#     epoch 32/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0862, train_acc=0.2430, test_loss=0.0862, test_acc=0.2472
#     epoch 33/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0861, train_acc=0.2480, test_loss=0.0861, test_acc=0.2538
#     epoch 34/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0859, train_acc=0.2542, test_loss=0.0860, test_acc=0.2538
#     epoch 35/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0859, train_acc=0.2467, test_loss=0.0860, test_acc=0.2420
#     epoch 36/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0858, train_acc=0.2550, test_loss=0.0859, test_acc=0.2466
#     epoch 37/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0858, train_acc=0.2510, test_loss=0.0859, test_acc=0.2474
#     epoch 38/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0857, train_acc=0.2485, test_loss=0.0858, test_acc=0.2472
#     epoch 39/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0857, train_acc=0.2557, test_loss=0.0858, test_acc=0.2456
#     epoch 40/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0855, train_acc=0.2557, test_loss=0.0856, test_acc=0.2468
#     epoch 41/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0855, train_acc=0.2475, test_loss=0.0856, test_acc=0.2458
#     epoch 42/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0854, train_acc=0.2500, test_loss=0.0855, test_acc=0.2502
#     epoch 43/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0854, train_acc=0.2580, test_loss=0.0854, test_acc=0.2552
#     epoch 44/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0854, train_acc=0.2557, test_loss=0.0855, test_acc=0.2514
#     epoch 45/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0854, train_acc=0.2625, test_loss=0.0855, test_acc=0.2550
#     epoch 46/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0854, train_acc=0.2500, test_loss=0.0853, test_acc=0.2574
#     epoch 47/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0854, train_acc=0.2527, test_loss=0.0854, test_acc=0.2588
#     epoch 48/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0853, train_acc=0.2627, test_loss=0.0853, test_acc=0.2624
#     epoch 49/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0854, train_acc=0.2615, test_loss=0.0854, test_acc=0.2610
#     epoch 50/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0852, train_acc=0.2650, test_loss=0.0852, test_acc=0.2668
#     epoch 51/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0852, train_acc=0.2595, test_loss=0.0852, test_acc=0.2690
#     epoch 52/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0853, train_acc=0.2680, test_loss=0.0853, test_acc=0.2632
#     epoch 53/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0851, train_acc=0.2615, test_loss=0.0852, test_acc=0.2640
#     epoch 54/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0851, train_acc=0.2585, test_loss=0.0851, test_acc=0.2732
#     epoch 55/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0850, train_acc=0.2680, test_loss=0.0851, test_acc=0.2726
#     epoch 56/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0849, train_acc=0.2640, test_loss=0.0850, test_acc=0.2650
#     epoch 57/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0850, train_acc=0.2555, test_loss=0.0850, test_acc=0.2622
#     epoch 58/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0850, train_acc=0.2557, test_loss=0.0849, test_acc=0.2676
#     epoch 59/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0850, train_acc=0.2590, test_loss=0.0850, test_acc=0.2678
#     epoch 60/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0851, train_acc=0.2530, test_loss=0.0850, test_acc=0.2632
#     epoch 61/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0851, train_acc=0.2545, test_loss=0.0850, test_acc=0.2682
#     epoch 62/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0851, train_acc=0.2572, test_loss=0.0850, test_acc=0.2672
#     epoch 63/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0852, train_acc=0.2592, test_loss=0.0853, test_acc=0.2722
#     epoch 64/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0852, train_acc=0.2540, test_loss=0.0852, test_acc=0.2658
#     epoch 65/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0855, train_acc=0.2437, test_loss=0.0854, test_acc=0.2580
#     epoch 66/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0853, train_acc=0.2527, test_loss=0.0853, test_acc=0.2604
#     epoch 67/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0854, train_acc=0.2482, test_loss=0.0854, test_acc=0.2550
#     epoch 68/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0855, train_acc=0.2530, test_loss=0.0856, test_acc=0.2586
#     epoch 69/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0856, train_acc=0.2535, test_loss=0.0857, test_acc=0.2568
#     epoch 70/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0858, train_acc=0.2550, test_loss=0.0859, test_acc=0.2530
#     epoch 71/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0857, train_acc=0.2487, test_loss=0.0858, test_acc=0.2486
#     epoch 72/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0855, train_acc=0.2535, test_loss=0.0858, test_acc=0.2594
#     epoch 73/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0855, train_acc=0.2505, test_loss=0.0857, test_acc=0.2606
#     epoch 74/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0855, train_acc=0.2530, test_loss=0.0858, test_acc=0.2528
#     epoch 75/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0855, train_acc=0.2552, test_loss=0.0858, test_acc=0.2554
#     epoch 76/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0855, train_acc=0.2500, test_loss=0.0858, test_acc=0.2530
#     epoch 77/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0856, train_acc=0.2545, test_loss=0.0859, test_acc=0.2556
#     epoch 78/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0858, train_acc=0.2535, test_loss=0.0860, test_acc=0.2480
#     epoch 79/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0860, train_acc=0.2477, test_loss=0.0860, test_acc=0.2518
#     epoch 80/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0861, train_acc=0.2542, test_loss=0.0861, test_acc=0.2548
#     epoch 81/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0862, train_acc=0.2532, test_loss=0.0863, test_acc=0.2616
#     epoch 82/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0861, train_acc=0.2597, test_loss=0.0861, test_acc=0.2660
#     epoch 83/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0863, train_acc=0.2540, test_loss=0.0863, test_acc=0.2574
#     epoch 84/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0863, train_acc=0.2547, test_loss=0.0863, test_acc=0.2608
#     epoch 85/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0864, train_acc=0.2570, test_loss=0.0865, test_acc=0.2568
#     epoch 86/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0865, train_acc=0.2567, test_loss=0.0867, test_acc=0.2578
#     epoch 87/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0868, train_acc=0.2557, test_loss=0.0869, test_acc=0.2520
#     epoch 88/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0870, train_acc=0.2485, test_loss=0.0871, test_acc=0.2440
#     epoch 89/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0875, train_acc=0.2510, test_loss=0.0875, test_acc=0.2484
#     epoch 90/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0874, train_acc=0.2455, test_loss=0.0872, test_acc=0.2472
#     epoch 91/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0876, train_acc=0.2490, test_loss=0.0872, test_acc=0.2550
#     epoch 92/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0878, train_acc=0.2487, test_loss=0.0875, test_acc=0.2418
#     epoch 93/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0877, train_acc=0.2535, test_loss=0.0873, test_acc=0.2574
#     epoch 94/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0879, train_acc=0.2500, test_loss=0.0879, test_acc=0.2492
#     epoch 95/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0879, train_acc=0.2537, test_loss=0.0878, test_acc=0.2526
#     epoch 96/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0884, train_acc=0.2470, test_loss=0.0884, test_acc=0.2424
#     epoch 97/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0885, train_acc=0.2480, test_loss=0.0885, test_acc=0.2504
#     epoch 98/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0889, train_acc=0.2480, test_loss=0.0886, test_acc=0.2500
#     epoch 99/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0894, train_acc=0.2455, test_loss=0.0892, test_acc=0.2422
#     epoch 100/100 | wp | lr=0.0024, sigma=0.0125 | train_loss=0.0894, train_acc=0.2492, test_loss=0.0891, test_acc=0.2494
#       method  final_train_loss  final_train_acc  final_test_loss  \
# 0         bp          0.040217          0.82775         0.069489
# 1         np          0.080064          0.33925         0.080523
# 2  np_fan_in               NaN          0.10025              NaN
# 3   np_fixed               NaN          0.10025              NaN
# 4         wp          0.089400          0.24925         0.089136
#
#    final_test_acc  best_test_loss  best_test_acc  diverged  duration_sec
# 0          0.5058        0.067326         0.5124     False     26.113683
# 1          0.3422        0.080273         0.3470     False     42.535869
# 2          0.1028        0.082401         0.3258      True     34.076134
# 3          0.1028        0.083343         0.3104      True     36.052951
# 4          0.2494        0.084872         0.2732     False    119.466215

# %% [markdown]
# # Frozen-Backprop Estimator Analysis
#
# Train only backprop, freeze the weights after 1/3, 2/3, and 3/3 of training, then evaluate perturbation estimators on a full epoch of batches.
# For each batch and method, sample 50 perturbations, compute the average sample cosine to the true gradient, the cosine of the mean estimator, and the sample variance around the mean estimator.

# %%
# Frozen-backprop estimator analysis.
# Uses the same sigma values as the current hand-picked final run, but no learning rate.

ANALYSIS_EPOCHS = FINAL_EPOCHS
ANALYSIS_SEED = 0
ANALYSIS_BP_LR = 0.1
ANALYSIS_NUM_PERTURBATIONS = 10
ANALYSIS_BATCH_SIZE = BATCH_SIZE
ANALYSIS_CHECKPOINT_EPOCHS = sorted({max(1, ANALYSIS_EPOCHS // 3), max(1, (2 * ANALYSIS_EPOCHS) // 3), ANALYSIS_EPOCHS})
ANALYSIS_METHOD_SIGMAS = {
    "np": 0.0175,
    "np_fan_in": 0.0055,
    "np_fixed": 0.19,
    "wp": 0.0125,
}

print(
    f"Running frozen estimator analysis | epochs={ANALYSIS_EPOCHS}, seed={ANALYSIS_SEED}, "
    f"bp_lr={ANALYSIS_BP_LR}, checkpoints={ANALYSIS_CHECKPOINT_EPOCHS}, "
    f"num_perturbations={ANALYSIS_NUM_PERTURBATIONS}, batch_size={ANALYSIS_BATCH_SIZE}"
)
print(ANALYSIS_METHOD_SIGMAS)

checkpoint_states = train_backprop_checkpoint_states(
    data=data,
    dimensions=DIMENSIONS,
    epochs=ANALYSIS_EPOCHS,
    seed=ANALYSIS_SEED,
    device=device,
    lr=ANALYSIS_BP_LR,
    checkpoint_epochs=ANALYSIS_CHECKPOINT_EPOCHS,
    print_every_epoch=max(1, ANALYSIS_EPOCHS // 10),
)

frozen_stats_df = analyze_frozen_backprop_estimators(
    checkpoint_states=checkpoint_states,
    data=data,
    dimensions=DIMENSIONS,
    device=device,
    method_sigmas=ANALYSIS_METHOD_SIGMAS,
    num_perturbations=ANALYSIS_NUM_PERTURBATIONS,
    batch_size=ANALYSIS_BATCH_SIZE,
)

display(frozen_stats_df.sort_values(["layer_index", "checkpoint_epoch", "method"]).reset_index(drop=True))
plot_frozen_estimator_statistics(frozen_stats_df)
# Out:
# Running frozen estimator analysis | epochs=20, seed=0, bp_lr=0.1, checkpoints=[6, 13, 20], num_perturbations=10, batch_size=128
# {'np': 0.0175, 'np_fan_in': 0.0055, 'np_fixed': 0.19, 'wp': 0.0125}
#     bp checkpoint training epoch    1/20 | train_loss=0.0846, train_acc=0.2925, test_loss=0.0847, test_acc=0.2888
#     bp checkpoint training epoch    2/20 | train_loss=0.0818, train_acc=0.3300, test_loss=0.0821, test_acc=0.3190
#     bp checkpoint training epoch    4/20 | train_loss=0.0783, train_acc=0.3740, test_loss=0.0791, test_acc=0.3606
#     bp checkpoint training epoch    6/20 | train_loss=0.0762, train_acc=0.3970, test_loss=0.0772, test_acc=0.3848
#     bp checkpoint training epoch    8/20 | train_loss=0.0746, train_acc=0.4240, test_loss=0.0760, test_acc=0.4066
#     bp checkpoint training epoch   10/20 | train_loss=0.0732, train_acc=0.4387, test_loss=0.0748, test_acc=0.4192
#     bp checkpoint training epoch   12/20 | train_loss=0.0720, train_acc=0.4595, test_loss=0.0739, test_acc=0.4294
#     bp checkpoint training epoch   13/20 | train_loss=0.0715, train_acc=0.4640, test_loss=0.0735, test_acc=0.4336
#     bp checkpoint training epoch   14/20 | train_loss=0.0710, train_acc=0.4695, test_loss=0.0732, test_acc=0.4432
#     bp checkpoint training epoch   16/20 | train_loss=0.0700, train_acc=0.4893, test_loss=0.0726, test_acc=0.4452
#     bp checkpoint training epoch   18/20 | train_loss=0.0692, train_acc=0.4980, test_loss=0.0721, test_acc=0.4532
#     bp checkpoint training epoch   20/20 | train_loss=0.0683, train_acc=0.5082, test_loss=0.0716, test_acc=0.4566
# /tmp/ipykernel_947/3594577182.py:262: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   return float(torch.dot(a, b) / (a_norm * b_norm + eps))
#     checkpoint_epoch  checkpoint_fraction     method   sigma component  \
# 0                  6                 0.30         np  0.0175       all
# 1                  6                 0.30  np_fan_in  0.0055       all
# 2                  6                 0.30   np_fixed  0.1900       all
# 3                  6                 0.30         wp  0.0125       all
# 4                 13                 0.65         np  0.0175       all
# 5                 13                 0.65  np_fan_in  0.0055       all
# 6                 13                 0.65   np_fixed  0.1900       all
# 7                 13                 0.65         wp  0.0125       all
# 8                 20                 1.00         np  0.0175       all
# 9                 20                 1.00  np_fan_in  0.0055       all
# 10                20                 1.00   np_fixed  0.1900       all
# 11                20                 1.00         wp  0.0125       all
# 12                 6                 0.30         np  0.0175   layer_1
# 13                 6                 0.30  np_fan_in  0.0055   layer_1
# 14                 6                 0.30   np_fixed  0.1900   layer_1
# 15                 6                 0.30         wp  0.0125   layer_1
# 16                13                 0.65         np  0.0175   layer_1
# 17                13                 0.65  np_fan_in  0.0055   layer_1
# 18                13                 0.65   np_fixed  0.1900   layer_1
# 19                13                 0.65         wp  0.0125   layer_1
# 20                20                 1.00         np  0.0175   layer_1
# 21                20                 1.00  np_fan_in  0.0055   layer_1
# 22                20                 1.00   np_fixed  0.1900   layer_1
# 23                20                 1.00         wp  0.0125   layer_1
# 24                 6                 0.30         np  0.0175   layer_2
# 25                 6                 0.30  np_fan_in  0.0055   layer_2
# 26                 6                 0.30   np_fixed  0.1900   layer_2
# 27                 6                 0.30         wp  0.0125   layer_2
# 28                13                 0.65         np  0.0175   layer_2
# 29                13                 0.65  np_fan_in  0.0055   layer_2
# 30                13                 0.65   np_fixed  0.1900   layer_2
# 31                13                 0.65         wp  0.0125   layer_2
# 32                20                 1.00         np  0.0175   layer_2
# 33                20                 1.00  np_fan_in  0.0055   layer_2
# 34                20                 1.00   np_fixed  0.1900   layer_2
# 35                20                 1.00         wp  0.0125   layer_2
# 36                 6                 0.30         np  0.0175   layer_3
# 37                 6                 0.30  np_fan_in  0.0055   layer_3
# 38                 6                 0.30   np_fixed  0.1900   layer_3
# 39                 6                 0.30         wp  0.0125   layer_3
# 40                13                 0.65         np  0.0175   layer_3
# 41                13                 0.65  np_fan_in  0.0055   layer_3
# 42                13                 0.65   np_fixed  0.1900   layer_3
# 43                13                 0.65         wp  0.0125   layer_3
# 44                20                 1.00         np  0.0175   layer_3
# 45                20                 1.00  np_fan_in  0.0055   layer_3
# 46                20                 1.00   np_fixed  0.1900   layer_3
# 47                20                 1.00         wp  0.0125   layer_3
#
#    component_label  layer_index  avg_sample_cosine  mean_estimate_cosine  \
# 0       All layers           -1           0.013526              0.042783
# 1       All layers           -1           0.011756              0.037066
# 2       All layers           -1           0.006235              0.019708
# 3       All layers           -1           0.000242              0.000771
# 4       All layers           -1           0.015150              0.048029
# 5       All layers           -1           0.015967              0.050084
# 6       All layers           -1           0.007870              0.025126
# 7       All layers           -1           0.000315              0.001000
# 8       All layers           -1           0.010668              0.033713
# 9       All layers           -1           0.008696              0.027353
# 10      All layers           -1           0.005929              0.018767
# 11      All layers           -1           0.000239              0.000758
# 12         Layer 1            0           0.011173              0.035475
# 13         Layer 1            0           0.009447              0.029912
# 14         Layer 1            0           0.004369              0.013787
# 15         Layer 1            0           0.000169              0.000539
# 16         Layer 1            0           0.011785              0.037526
# 17         Layer 1            0           0.011973              0.037842
# 18         Layer 1            0           0.005279              0.016991
# 19         Layer 1            0           0.000249              0.000787
# 20         Layer 1            0           0.011393              0.036257
# 21         Layer 1            0           0.010387              0.033006
# 22         Layer 1            0           0.005018              0.015900
# 23         Layer 1            0           0.000195              0.000621
# 24         Layer 2            1           0.010285              0.032578
# 25         Layer 2            1           0.008087              0.025598
# 26         Layer 2            1           0.010855              0.034358
# 27         Layer 2            1           0.000371              0.001179
# 28         Layer 2            1           0.014776              0.046957
# 29         Layer 2            1           0.015188              0.047554
# 30         Layer 2            1           0.015978              0.050454
# 31         Layer 2            1           0.000491              0.001587
# 32         Layer 2            1           0.005785              0.018169
# 33         Layer 2            1           0.003554              0.011194
# 34         Layer 2            1           0.010068              0.031440
# 35         Layer 2            1           0.000440              0.001388
# 36         Layer 3            2           0.075623              0.218377
# 37         Layer 3            2           0.100995              0.233681
# 38         Layer 3            2           0.125072              0.292955
# 39         Layer 3            2           0.004092              0.013000
# 40         Layer 3            2           0.082984              0.234368
# 41         Layer 3            2           0.123327              0.262903
# 42         Layer 3            2           0.155076              0.326535
# 43         Layer 3            2           0.004088              0.012929
# 44         Layer 3            2           0.036975              0.101612
# 45         Layer 3            2           0.025893              0.050206
# 46         Layer 3            2           0.063635              0.132212
# 47         Layer 3            2           0.002249              0.007193
#
#     sample_variance  batch_variance
# 0          0.000006    6.063875e-07
# 1          0.000007    7.111999e-07
# 2          0.000029    2.905991e-06
# 3          0.020449    2.044805e-03
# 4          0.000009    9.550900e-07
# 5          0.000010    1.037266e-06
# 6          0.000033    3.277869e-06
# 7          0.030696    3.069493e-03
# 8          0.000011    1.160261e-06
# 9          0.000012    1.218295e-06
# 10         0.000035    3.557067e-06
# 11         0.036716    3.671506e-03
# 12         0.000004    4.317810e-07
# 13         0.000005    5.023100e-07
# 14         0.000030    2.993581e-06
# 15         0.020449    2.044848e-03
# 16         0.000007    6.771345e-07
# 17         0.000007    7.084419e-07
# 18         0.000034    3.357962e-06
# 19         0.030696    3.069496e-03
# 20         0.000008    8.215146e-07
# 21         0.000008    8.163926e-07
# 22         0.000036    3.631134e-06
# 23         0.036716    3.671685e-03
# 24         0.000026    2.591567e-06
# 25         0.000031    3.117344e-06
# 26         0.000018    1.846998e-06
# 27         0.020449    2.044343e-03
# 28         0.000040    4.098013e-06
# 29         0.000047    4.776443e-06
# 30         0.000023    2.278015e-06
# 31         0.030703    3.069401e-03
# 32         0.000049    4.980661e-06
# 33         0.000056    5.786187e-06
# 34         0.000026    2.611890e-06
# 35         0.036717    3.669307e-03
# 36         0.000052    6.058499e-06
# 37         0.000032    5.640485e-06
# 38         0.000020    3.397488e-06
# 39         0.020441    2.042280e-03
# 40         0.000085    1.051722e-05
# 41         0.000055    1.127257e-05
# 42         0.000026    5.337124e-06
# 43         0.030691    3.072111e-03
# 44         0.000101    1.331979e-05
# 45         0.000067    1.384506e-05
# 46         0.000030    6.511141e-06
# 47         0.036695    3.673972e-03

# %% [markdown]
# # Frozen-Backprop Sigma Search
#
# Run the same frozen-backprop repeated-perturbation analysis as above, but sweep only over `sigma` for each perturbation method.
# The plots are grouped per method, with one row per checkpoint epoch and separate bar panels for average sample cosine, cosine of the mean estimator, and sample variance.

# %%
# Frozen-backprop sigma search.
# Reuses the repeated-perturbation estimator procedure, but sweeps only over sigma.

SIGMA_SEARCH_EPOCHS = FINAL_EPOCHS
SIGMA_SEARCH_SEED = 0
SIGMA_SEARCH_BP_LR = 0.1
SIGMA_SEARCH_NUM_PERTURBATIONS = 10
SIGMA_SEARCH_BATCH_SIZE = BATCH_SIZE
SIGMA_SEARCH_CHECKPOINT_EPOCHS = sorted({max(1, SIGMA_SEARCH_EPOCHS // 3), max(1, (2 * SIGMA_SEARCH_EPOCHS) // 3), SIGMA_SEARCH_EPOCHS})
SIGMA_SEARCH_METHOD_SIGMA_GRID = {
    "np": [
        0.0175,
        0.01875,
        0.02,
    ],
    "np_fan_in": [
        0.0045,
        0.005,
        0.0055,
    ],
    "np_fixed": [
        0.165,
        0.19,
        0.215,
    ],
    "wp": [
        0.015,
        0.0175,
        0.02,
    ]
}

print(
    f"Running frozen sigma search | epochs={SIGMA_SEARCH_EPOCHS}, seed={SIGMA_SEARCH_SEED}, "
    f"bp_lr={SIGMA_SEARCH_BP_LR}, checkpoints={SIGMA_SEARCH_CHECKPOINT_EPOCHS}, "
    f"num_perturbations={SIGMA_SEARCH_NUM_PERTURBATIONS}, batch_size={SIGMA_SEARCH_BATCH_SIZE}"
)
print(SIGMA_SEARCH_METHOD_SIGMA_GRID)

if "checkpoint_states" in globals() and sorted(checkpoint_states.keys()) == SIGMA_SEARCH_CHECKPOINT_EPOCHS:
    sigma_search_checkpoint_states = checkpoint_states
else:
    sigma_search_checkpoint_states = train_backprop_checkpoint_states(
        data=data,
        dimensions=DIMENSIONS,
        epochs=SIGMA_SEARCH_EPOCHS,
        seed=SIGMA_SEARCH_SEED,
        device=device,
        lr=SIGMA_SEARCH_BP_LR,
        checkpoint_epochs=SIGMA_SEARCH_CHECKPOINT_EPOCHS,
        print_every_epoch=max(1, SIGMA_SEARCH_EPOCHS // 10),
    )

sigma_search_df = analyze_frozen_backprop_sigma_grid(
    checkpoint_states=sigma_search_checkpoint_states,
    data=data,
    dimensions=DIMENSIONS,
    device=device,
    method_sigma_grid=SIGMA_SEARCH_METHOD_SIGMA_GRID,
    num_perturbations=SIGMA_SEARCH_NUM_PERTURBATIONS,
    batch_size=SIGMA_SEARCH_BATCH_SIZE,
)

display(sigma_search_df.sort_values(["method", "checkpoint_epoch", "sigma"]).reset_index(drop=True))
plot_frozen_sigma_search_results(sigma_search_df)
# Out:
# Running frozen sigma search | epochs=20, seed=0, bp_lr=0.1, checkpoints=[6, 13, 20], num_perturbations=10, batch_size=128
# {'np': [0.0175, 0.01875, 0.02], 'np_fan_in': [0.0045, 0.0055, 0.0065], 'np_fixed': [0.165, 0.19, 0.215], 'wp': [0.015, 0.0175, 0.02]}
#     bp checkpoint training epoch    1/20 | train_loss=0.0846, train_acc=0.2925, test_loss=0.0847, test_acc=0.2886
#     bp checkpoint training epoch    2/20 | train_loss=0.0818, train_acc=0.3297, test_loss=0.0821, test_acc=0.3192
#     bp checkpoint training epoch    4/20 | train_loss=0.0783, train_acc=0.3745, test_loss=0.0791, test_acc=0.3612
#     bp checkpoint training epoch    6/20 | train_loss=0.0762, train_acc=0.3967, test_loss=0.0772, test_acc=0.3848
#     bp checkpoint training epoch    8/20 | train_loss=0.0746, train_acc=0.4245, test_loss=0.0760, test_acc=0.4072
#     bp checkpoint training epoch   10/20 | train_loss=0.0732, train_acc=0.4390, test_loss=0.0748, test_acc=0.4198
#     bp checkpoint training epoch   12/20 | train_loss=0.0720, train_acc=0.4585, test_loss=0.0739, test_acc=0.4294
#     bp checkpoint training epoch   13/20 | train_loss=0.0715, train_acc=0.4632, test_loss=0.0735, test_acc=0.4338
#     bp checkpoint training epoch   14/20 | train_loss=0.0710, train_acc=0.4690, test_loss=0.0732, test_acc=0.4428
#     bp checkpoint training epoch   16/20 | train_loss=0.0700, train_acc=0.4890, test_loss=0.0726, test_acc=0.4448
#     bp checkpoint training epoch   18/20 | train_loss=0.0692, train_acc=0.4983, test_loss=0.0721, test_acc=0.4538
#     bp checkpoint training epoch   20/20 | train_loss=0.0683, train_acc=0.5065, test_loss=0.0716, test_acc=0.4562
#     checkpoint_epoch  checkpoint_fraction     method    sigma  \
# 0                  6                 0.30         np  0.01750
# 1                  6                 0.30         np  0.01875
# 2                  6                 0.30         np  0.02000
# 3                 13                 0.65         np  0.01750
# 4                 13                 0.65         np  0.01875
# 5                 13                 0.65         np  0.02000
# 6                 20                 1.00         np  0.01750
# 7                 20                 1.00         np  0.01875
# 8                 20                 1.00         np  0.02000
# 9                  6                 0.30  np_fan_in  0.00450
# 10                 6                 0.30  np_fan_in  0.00550
# 11                 6                 0.30  np_fan_in  0.00650
# 12                13                 0.65  np_fan_in  0.00450
# 13                13                 0.65  np_fan_in  0.00550
# 14                13                 0.65  np_fan_in  0.00650
# 15                20                 1.00  np_fan_in  0.00450
# 16                20                 1.00  np_fan_in  0.00550
# 17                20                 1.00  np_fan_in  0.00650
# 18                 6                 0.30   np_fixed  0.16500
# 19                 6                 0.30   np_fixed  0.19000
# 20                 6                 0.30   np_fixed  0.21500
# 21                13                 0.65   np_fixed  0.16500
# 22                13                 0.65   np_fixed  0.19000
# 23                13                 0.65   np_fixed  0.21500
# 24                20                 1.00   np_fixed  0.16500
# 25                20                 1.00   np_fixed  0.19000
# 26                20                 1.00   np_fixed  0.21500
# 27                 6                 0.30         wp  0.01500
# 28                 6                 0.30         wp  0.01750
# 29                 6                 0.30         wp  0.02000
# 30                13                 0.65         wp  0.01500
# 31                13                 0.65         wp  0.01750
# 32                13                 0.65         wp  0.02000
# 33                20                 1.00         wp  0.01500
# 34                20                 1.00         wp  0.01750
# 35                20                 1.00         wp  0.02000
#
#     avg_sample_cosine  mean_estimate_cosine  sample_variance  batch_variance
# 0            0.013194              0.041788         0.000006    6.028016e-07
# 1            0.013294              0.042053         0.000006    5.740380e-07
# 2            0.012901              0.040963         0.000006    5.644675e-07
# 3            0.015797              0.049981         0.000009    9.536539e-07
# 4            0.015249              0.048320         0.000009    9.220225e-07
# 5            0.015963              0.050248         0.000009    9.048351e-07
# 6            0.010523              0.033254         0.000011    1.155963e-06
# 7            0.009872              0.031213         0.000011    1.128209e-06
# 8            0.010131              0.031948         0.000011    1.130038e-06
# 9            0.012084              0.038199         0.000008    7.635565e-07
# 10           0.012075              0.038177         0.000007    7.095669e-07
# 11           0.011912              0.037399         0.000007    7.267952e-07
# 12           0.014695              0.046379         0.000011    1.082016e-06
# 13           0.016329              0.051386         0.000010    1.027664e-06
# 14           0.015956              0.049882         0.000010    1.080286e-06
# 15           0.010438              0.032983         0.000012    1.260517e-06
# 16           0.008911              0.027917         0.000012    1.219330e-06
# 17           0.007130              0.022352         0.000013    1.306313e-06
# 18           0.005607              0.017785         0.000029    2.893607e-06
# 19           0.005943              0.018940         0.000029    2.913779e-06
# 20           0.005819              0.018491         0.000030    2.955505e-06
# 21           0.007186              0.022879         0.000033    3.309623e-06
# 22           0.007857              0.024915         0.000033    3.289289e-06
# 23           0.007169              0.022691         0.000033    3.352349e-06
# 24           0.006772              0.021495         0.000036    3.570894e-06
# 25           0.005749              0.018244         0.000035    3.502932e-06
# 26           0.006109              0.019189         0.000036    3.647803e-06
# 27           0.000285              0.000907         0.015527    1.552724e-03
# 28           0.000274              0.000866         0.013172    1.317349e-03
# 29           0.000300              0.000953         0.012250    1.224900e-03
# 30           0.000285              0.000901         0.024005    2.400305e-03
# 31           0.000356              0.001140         0.020821    2.081984e-03
# 32           0.000332              0.001059         0.019765    1.976512e-03
# 33           0.000262              0.000834         0.028718    2.872295e-03
# 34           0.000237              0.000757         0.025296    2.529739e-03
# 35           0.000184              0.000586         0.024101    2.409959e-03
